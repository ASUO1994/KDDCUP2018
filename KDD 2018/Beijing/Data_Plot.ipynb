# %%
import pandas
import matplotlib.pyplot as plt
def dataset(mode): #mode取weather或air
    root = '/home/lifuzhen/KDD2018/'+mode+'.csv'
    data = pandas.read_csv(root)
    return data

# %%
mode = 'beijing_17_18_aq' #air day Figure
air = dataset(mode)
air = air.fillna(0)

# %%
mode = 'beijing_17_18_meo' #weather month Figure
weather = dataset(mode)
weather = weather.fillna(0)
weather.loc[weather['wind_speed']==999999,'wind_speed'] = weather['wind_speed'].median()
weather.loc[weather['wind_direction']==999999,'wind_direction'] = weather['wind_direction'].median()
weather.loc[weather['wind_direction']==999017,'wind_direction'] = 0
weather.loc[weather['temperature']==999999,'temperature'] = weather['temperature'].median()
weather.loc[weather['humidity']==999999,'humidity'] = weather['humidity'].median()
weather.loc[weather['pressure']==999999,'pressure'] = weather['pressure'].median()

# %%
# mode = 'beijing_17_18_aq' #air day Figure
# air = dataset(mode)
# air = air.fillna(0)
for i in range(0,100):
    plt.plot(range(0,24),air['PM2.5'][10+i*24:34+i*24]/1004,label = 'PM2.5')
    plt.plot(range(0,24),air['PM10'][10+i*24:34+i*24]/1500,label = 'PM10')
    plt.plot(range(0,24),air['NO2'][10+i*24:34+i*24]/300,label = 'NO2')
    plt.plot(range(0,24),air['CO'][10+i*24:34+i*24]/15,label = 'CO')
    plt.plot(range(0,24),air['O3'][10+i*24:34+i*24]/504,label = 'O3')
    plt.plot(range(0,24),air['SO2'][10+i*24:34+i*24]/307,label = 'SO2')
    plt.legend()
    plt.savefig('/home/lifuzhen/KDD2018/Figures/air/day/'+format(i)+'.jpg')
    plt.close()

# %%
# mode = 'beijing_17_18_aq' #air week Figure
# air = dataset(mode)
# air = air.fillna(0)
for i in range(0,50):
    plt.plot(range(0,168),air['PM2.5'][10+i*168:178+i*168]/1004,label = 'PM2.5')
    plt.plot(range(0,168),air['PM10'][10+i*168:178+i*168]/1500,label = 'PM10')
    plt.plot(range(0,168),air['NO2'][10+i*168:178+i*168]/300,label = 'NO2')
    plt.plot(range(0,168),air['CO'][10+i*168:178+i*168]/15,label = 'CO')
    plt.plot(range(0,168),air['O3'][10+i*168:178+i*168]/504,label = 'O3')
    plt.plot(range(0,168),air['SO2'][10+i*168:178+i*168]/307,label = 'SO2')
    plt.legend()
    plt.savefig('/home/lifuzhen/KDD2018/Figures/air/week/'+format(i)+'.jpg')
    plt.close()

# %%
# mode = 'beijing_17_18_aq' #air month Figure
# air = dataset(mode)
# air = air.fillna(0)
n_month = 0
j = 0
for i in range(0,12):
#     j = j + 1
    while int(air['utc_time'][j].split('-')[1]) == i + 1:
        j = j + 1
    plt.plot(range(0 , j - n_month),air['PM2.5'][n_month:j ]/1004,label='PM2.5')
    plt.plot(range(0 , j - n_month),air['PM10'][n_month:j ]/1500,label='PM10')
    plt.plot(range(0 , j - n_month),air['NO2'][n_month:j ]/300,label='NO2')
    plt.plot(range(0 , j - n_month),air['CO'][n_month:j ]/15,label='CO')
    plt.plot(range(0 , j - n_month),air['O3'][n_month:j ]/504,label='O3')
    plt.plot(range(0 , j - n_month),air['SO2'][n_month:j ]/307,label='SO2')
    plt.legend()
    n_month = j
    plt.savefig('/home/lifuzhen/KDD2018/Figures/air/month/'+format(i)+'.jpg')
    plt.close()
j - n_month
# Out:
# 0

# %%
# mode = 'beijing_17_18_meo' #weather day Figure
# weather = dataset(mode)
# weather = weather.fillna(0)
for i in range(0,100):
    plt.plot(range(0,24),weather['temperature'][8+i*24:32+i*24],label = 'temperature')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/day/temperature/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,24),weather['pressure'][8+i*24:32+i*24],label = 'pressure')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/day/pressure/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,24),weather['humidity'][8+i*24:32+i*24],label = 'humidity')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/day/humidity/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,24),weather['wind_direction'][8+i*24:32+i*24],label = 'wind_direction')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/day/wind_direction/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,24),weather['wind_speed'][8+i*24:32+i*24],label = 'wind_speed')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/day/wind_speed/'+format(i)+'.jpg')
    plt.close()

# %%
# mode = 'beijing_17_18_meo' #weather week Figure
# weather = dataset(mode)
# weather = weather.fillna(0)
for i in range(0,50):
    plt.plot(range(0,168),weather['temperature'][8+i*168:176+i*168],label = 'temperature')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/week/temperature/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,168),weather['pressure'][8+i*168:176+i*168],label = 'pressure')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/week/pressure/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,168),weather['humidity'][8+i*168:176+i*168],label = 'humidity')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/week/humidity/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,168),weather['wind_direction'][8+i*168:176+i*168],label = 'wind_direction')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/week/wind_direction/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,168),weather['wind_speed'][8+i*168:176+i*168],label = 'wind_speed')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/week/wind_speed/'+format(i)+'.jpg')
    plt.close()

# %%
# mode = 'beijing_17_18_meo' #weather month Figure
# weather = dataset(mode)
# weather = weather.fillna(0)
# weather.loc[weather['wind_speed']==999999,'wind_speed'] = weather['wind_speed'].median()
# weather.loc[weather['wind_direction']==999999,'wind_direction'] = weather['wind_direction'].median()
# weather.loc[weather['wind_direction']==999017,'wind_direction'] = 0
# weather.loc[weather['temperature']==999999,'temperature'] = weather['temperature'].median()
# weather.loc[weather['humidity']==999999,'humidity'] = weather['humidity'].median()
# weather.loc[weather['pressure']==999999,'pressure'] = weather['pressure'].median()
temperature = []
pressure = []
humidity = []
wind_direction = []
wind_speed = []
n_month = 0
j = 0 
for i in range(0,12):
    while int(weather['utc_time'][j].split('-')[1]) == i + 1:
#         weather.loc(weather['temperature'][j],'temperature') = sum(weather['temperature'][j:j+24])/24
#         weather.loc(weather['pressure'][j],'pressure') = sum(weather['pressure'][j:j+24])/24
#         weather.loc(weather['humidity'][j],'humidity') = sum(weather['humidity'][j:j+24])/24
#         weather.loc(weather['wind_direction'][j],'wind_direction') = sum(weather['wind_direction'][j:j+24])/24
#         weather.loc(weather['wind_speed'][j],'wind_speed') = sum(weather['wind_speed'][j:j+24])/24
        temperature.append(sum(weather['temperature'][j:j+24])/24)
        pressure.append(sum(weather['pressure'][j:j+24])/24)
        humidity.append(sum(weather['humidity'][j:j+24])/24)
        wind_direction.append(sum(weather['wind_direction'][j:j+24])/24)
        wind_speed.append(sum(weather['wind_speed'][j:j+24])/24)
        j = j + 1
    plt.plot(range(0,j - n_month),temperature[n_month:j],label = 'temperature')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/month/temperature/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,j - n_month),pressure[n_month:j],label = 'pressure')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/month/pressure/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,j - n_month),humidity[n_month:j],label = 'humidity')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/month/humidity/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,j - n_month),wind_direction[n_month:j],label = 'wind_direction')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/month/wind_direction/'+format(i)+'.jpg')
    plt.close()
    plt.plot(range(0,j - n_month),wind_speed[n_month:j],label = 'wind_speed')
    plt.savefig('/home/lifuzhen/KDD2018/Figures/weather/month/wind_speed/'+format(i)+'.jpg')
    n_month = j
    plt.close()
weather.describe()
# Out:
#            longitude       latitude    temperature       pressure  \
# count  158047.000000  158047.000000  158047.000000  158047.000000
# mean      116.395672      40.047275      12.874222    1001.514749
# std         0.395223       0.264798      12.079462      20.483894
# min       115.692222      39.718611     -21.300000     940.000000
# 25%       116.194167      39.847500       2.500000     994.200000
# 50%       116.290556      39.973889      13.800000    1005.600000
# 75%       116.626944      40.223333      23.200000    1016.900000
# max       117.117778      40.658889      40.300000    1039.700000
#
#             humidity  wind_direction     wind_speed
# count  158047.000000   158047.000000  158047.000000
# mean       50.620651      169.927718       1.882124
# std        26.049117      109.547479       1.360697
# min         4.000000        0.000000       0.000000
# 25%        27.000000       66.000000       0.900000
# 50%        48.000000      178.000000       1.500000
# 75%        73.000000      261.000000       2.500000
# max       100.000000      360.000000      15.400000

# %%
a = [1,2]
print(a[0:1])
# Out:
# [1]
