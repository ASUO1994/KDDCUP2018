# %%
import pandas
import numpy as np
import matplotlib.pyplot as plt



def dataset(mode): #mode取weather或air
    root = '/home/lifuzhen/KDD2018/'+mode+'.csv'
    data = pandas.read_csv(root)
    return data


mode = 'beijing_17_18_aq' #air day Figure
air = dataset(mode)
# print(air.describe())

gap_air = 24

PM10_miss = []
PM10_inter = []
index = 0
count = 0
for value in air['PM10']:

    if np.isnan(value):
        count += 1
        
    elif count != 0:
        PM10_miss.append(count)
        
        if count >= gap_air:
            PM10_inter.append(index - count)
            PM10_inter.append(index)
            
        count = 0
        
    index += 1

PM25_miss = []
PM25_inter = []
index = 0
count = 0
for value in air['PM2.5']:

    if np.isnan(value):
        count += 1
        
    elif count != 0:
        PM25_miss.append(count)
        
        if count >= gap_air:
            PM25_inter.append(index - count)
            PM25_inter.append(index)
            
        count = 0
        
    index += 1
    
NO2_miss = []
NO2_inter = []
index = 0
count = 0
for value in air['NO2']:

    if np.isnan(value):
        count += 1
        
    elif count != 0:
        NO2_miss.append(count)
        
        if count >= gap_air:
            NO2_inter.append(index - count)
            NO2_inter.append(index)
            
        count = 0
        
    index += 1

CO_miss = []
CO_inter = []
index = 0
count = 0
for value in air['CO']:

    if np.isnan(value):
        count += 1
        
    elif count != 0:
        CO_miss.append(count)
        
        if count >= gap_air:
            CO_inter.append(index - count)
            CO_inter.append(index)
            
        count = 0
        
    index += 1
    
O3_miss = []
O3_inter = []
index = 0
count = 0
for value in air['O3']:

    if np.isnan(value):
        count += 1
        
    elif count != 0:
        O3_miss.append(count)
        
        if count >= gap_air:
            O3_inter.append(index - count)
            O3_inter.append(index)
            
        count = 0
        
    index += 1
    
SO2_miss = []
SO2_inter = []
index = 0
count = 0
for value in air['SO2']:

    if np.isnan(value):
        count += 1
        
    elif count != 0:
        SO2_miss.append(count)
        
        if count >= gap_air:
            SO2_inter.append(index - count)
            SO2_inter.append(index)
            
        count = 0
        
    index += 1
    
PM10_inter.append(309327)
PM25_inter.append(309327)
NO2_inter.append(309327)
CO_inter.append(309327)
O3_inter.append(309327)
SO2_inter.append(309327)
print(max(PM10_miss))
print(PM10_inter)
# Out:
# 2100
# [17, 42, 94, 185, 987, 1033, 1763, 1827, 6059, 6105, 6304, 6398, 6461, 6552, 6760, 6795, 9014, 9039, 10586, 10611, 10876, 10992, 14947, 14978, 17774, 17812, 17852, 17933, 18121, 18153, 18758, 18808, 18902, 18944, 19475, 19507, 19534, 19592, 19874, 19907, 20294, 20322, 22520, 22581, 22844, 22869, 23852, 23882, 24076, 24121, 24259, 24314, 24532, 24567, 32758, 32792, 32962, 32994, 35630, 35704, 36088, 36115, 36537, 36583, 36686, 36717, 37222, 37268, 37303, 37362, 40617, 40644, 41606, 41643, 41848, 41881, 41883, 41931, 42028, 42056, 42057, 42094, 42299, 42336, 43610, 43648, 44430,
 177738, 177763, 177764, 177810, 177853, 177928, 178693, 178754, 178868, 178904, 179422, 179447, 179510, 179547, 179788, 179819, 180924, 180962, 183775, 183844, 184026, 184071, 184072, 184115, 184191, 184273, 185783, 185845, 186606, 186656, 186688, 186768, 186952, 187011, 187143, 187177, 187339, 187406, 187580, 187641, 187755, 187779, 188312, 188338, 188370, 188430, 191469, 191500, 191786, 191827, 192665, 192713, 192910, 193004, 193075, 193158, 193366, 193400, 195599, 195679, 196251, 196284, 196479, 196525, 196635, 196672, 197195, 197219, 197277, 197318, 197570, 197599, 199540, 199574, 199591, 199620, 200864, 200908, 201551, 201583, 201803, 201831, 203561, 203600, 204736, 204781, 206162, 206197, 210457, 210490, 210683, 210717, 210 ...

# %%
left = 0
copy_PM10 = air['PM10'].copy()
for i in range(len(PM10_inter)):
    right = PM10_inter[i]
    copy_PM10[left : right] = copy_PM10[left : right].interpolate()
    left = right

left = 0
copy_PM25 = air['PM2.5'].copy()
for i in range(len(PM25_inter)):
    right = PM25_inter[i]
    copy_PM25[left : right] = copy_PM25[left : right].interpolate()
    left = right

left = 0
copy_NO2 = air['NO2'].copy()
for i in range(len(NO2_inter)):
    right = NO2_inter[i]
    copy_NO2[left : right] = copy_NO2[left : right].interpolate()
    left = right
    
left = 0
copy_CO = air['CO'].copy()
for i in range(len(CO_inter)):
    right = CO_inter[i]
    copy_CO[left : right] = copy_CO[left : right].interpolate()
    left = right
    
left = 0
copy_O3 = air['O3'].copy()
for i in range(len(O3_inter)):
    right = O3_inter[i]
    copy_O3[left : right] = copy_O3[left : right].interpolate()
    left = right
    
left = 0
copy_SO2 = air['SO2'].copy()
for i in range(len(SO2_inter)):
    right = SO2_inter[i]
    copy_SO2[left : right] = copy_SO2[left : right].interpolate()
    left = right
    
# copy_PM10.head(50)

# %%
copy_air = air[['stationId','utc_time']]
copy_air = pandas.concat([copy_air,copy_PM25,copy_PM10,copy_NO2,copy_CO,copy_O3,copy_SO2], axis= 1)
copy_air.dropna(thresh=7,inplace=True)
copy_air.to_csv('/home/lifuzhen/KDD2018/copy_air.csv', index = True)
copy_air.describe()
# Out:
#                PM2.5           PM10            NO2             CO  \
# count  298912.000000  281685.000000  299305.000000  281540.000000
# mean       58.755218      87.331969      45.670830       0.961500
# std        66.293036      87.142088      32.088004       0.994652
# min         2.000000       5.000000       1.000000       0.100000
# 25%        16.000000      36.000000      20.000000       0.400000
# 50%        39.000000      69.000000      39.000000       0.700000
# 75%        77.000000     113.000000      66.000000       1.200000
# max      1004.000000    3000.000000     300.000000      15.000000
#
#                   O3            SO2
# count  299147.000000  299115.000000
# mean       55.778577       8.967459
# std        53.854184      11.709873
# min         1.000000       1.000000
# 25%        12.000000       2.000000
# 50%        45.000000       5.000000
# 75%        79.000000      11.000000
# max       504.000000     307.000000
