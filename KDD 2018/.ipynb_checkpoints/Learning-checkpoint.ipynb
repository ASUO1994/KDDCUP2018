# %%
import pandas as pd
import numpy as np
beijing_train = np.array(pd.read_csv('/home/lifuzhen/KDD2018/Feature/beijing_train.csv'))[:,1:]
beijing_test = np.array(pd.read_csv('/home/lifuzhen/KDD2018/Feature/beijing_test.csv'))[:,1:]
London_train = np.array(pd.read_csv('/home/lifuzhen/KDD2018/Feature/London_train.csv'))[:,1:]
London_test = np.array(pd.read_csv('/home/lifuzhen/KDD2018/Feature/London_test.csv'))[:,1:]

# %% [markdown]
# * 1-aotizhongxin
# * 2-badaling
# * 3-beibuxinqu
# * 4-daxing
# * 5-dingling
# * 6-donggaocun
# * 7-dongsi
# * 8-dongsihuan
# * 9-fangshan
# * 10-fengtaihuayuan
# * 11-guanyuan
# * 12-gucheng
# * 13-huairou
# * 14-liulihe
# * 15-mentougou
# * 16-miyun
# * 17-miyunshuiku
# * 18-nansanhuan
# * 19-nongzhanguan
# * 20-pingchang
# * 21-pinggu
# * 22-qianmen
# * 23-shunyi
# * 24-tiantan
# * 25-tongzhou
# * 26-wanliu
# * 27-wanshouxigong
# * 28-xizhimenbei
# * 29-yanqin
# * 30-yizhuang
# * 31-yongdingmennei
# * 32-yongledian
# * 33-yufa
# * 34-yugang
# * 35-zhiwuyuan

# %%
# a = train_data[:,:4973]
# b = train_data[:,4973:4973+288]
# c = np.concatenate((a,b),axis = 1)
# print(a.shape)
# print(b.shape)
# print(c.shape)
a = [1,2,3]
a[-2:-1]
# Out:
# [2]

# %% [markdown]
# # PM2.5

# %%
import xgboost as xgb
from sklearn.cross_validation import train_test_split
from tqdm import tqdm

train_data, val_data = train_test_split(beijing_train, test_size = 0.3, random_state = 123)###随机数原始为1
# trainX = train_data[:, :-102]
# valX = val_data[:, :-102]

# trainX = beijing_train[:, :-105]
# valX = beijing_test[:, :-105]
# Out:
# /home/lifuzhen/virtual_pytorch_py3.5/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def sMAPE(preds, xgb_train):   
        s = 0
        label = xgb_train.get_label()
        length = len(label)
        for i in range(length):
            s += np.abs(preds[i] - label[i]) / ((np.abs(preds[i]) + np.abs(label[i])) / 2.)
        sMAPE = s/float(length)
        return 'sMAPE',float(sMAPE)

# %%
for i in tqdm(range(34)):
    trainX = np.concatenate((train_data[:,2*i:2*(i+1)],train_data[:,68:1485],train_data[:,1485+288*i:1485+288*(i+1)],train_data[:,-116:-102]),axis = 1)
    valX = np.concatenate((val_data[:,2*i:2*(i+1)],val_data[:,68:1485],val_data[:,1485+288*i:1485+288*(i+1)],val_data[:,-116:-102]),axis = 1)
    trainY = train_data[:, -102+3*i]
    valY = val_data[:, -102+3*i]
#     trainY = beijing_train[:, -105+3*i]
#     valY = beijing_test[:, -105+3*i]
    print(trainX.shape)
    print(valX.shape)

    params={
    'booster':'gbtree',
    'objective': 'reg:gamma', #多分类的问题
    # 'num_class':2, # 类别数，与 multisoftmax 并用
    'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':5, # 构建树的深度，越大越容易过拟合
    'lambda':100,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':0.9, # 随机采样训练样本
    'colsample_bytree':0.01, # 生成树时进行的列采样
    'min_child_weight':1, 
    # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
    #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
    #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
    'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
    'eta': 0.05, # 如同学习率
    'seed':1000,
    'nthread':-1,# cpu 线程数
#     'eval_metric': 'rmse'
    }

    plst = list(params.items())
    num_rounds = 5000 # 迭代次数
    xgb_train = xgb.DMatrix(trainX, label= trainY)
    xgb_val = xgb.DMatrix(valX, label= valY)
    watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
    #训练模型并保存
    # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
    model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=10,feval=sMAPE)
    model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing48_drop1/'+ str(i) +'_PM2.5.model') # 用于存储训练出的模型
#     model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing72/'+ str(i) +'_PM2.5.model') # 用于存储训练出的模型
#     model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing168/'+ str(i) +'_PM2.5.model') # 用于存储训练出的模型
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
# (3472, 1721)
# (1488, 1721)
# [0]	train-gamma-nloglik:96.9366	val-gamma-nloglik:97.0088	train-sMAPE:1.8726	val-sMAPE:1.86998
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [10]	train-gamma-nloglik:59.4311	val-gamma-nloglik:59.4751	train-sMAPE:1.80001	val-sMAPE:1.79618
# [20]	train-gamma-nloglik:36.8723	val-gamma-nloglik:36.8994	train-sMAPE:1.69368	val-sMAPE:1.68838
# [30]	train-gamma-nloglik:23.3761	val-gamma-nloglik:23.3929	train-sMAPE:1.54591	val-sMAPE:1.53912
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/home/lifuzhen/virtual_pytorch_py3.5/lib/python3.5/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/lifuzhen/virtual_pytorch_py3.5/lib/python3.5/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# [40]	train-gamma-nloglik:15.3687	val-gamma-nloglik:15.3797	train-sMAPE:1.36345	val-sMAPE:1.35783
# [50]	train-gamma-nloglik:10.68	val-gamma-nloglik:10.6888	train-sMAPE:1.17989	val-sMAPE:1.17872
# [60]	train-gamma-nloglik:7.98704	val-gamma-nloglik:7.9959	train-sMAPE:1.03765	val-sMAPE:1.03825
# [70]	train-gamma-nloglik:6.48533	val-gamma-nloglik:6.49362	train-sMAPE:0.950063	val-sMAPE:0.959723
# [330]	train-gamma-nloglik:4.53984	val-gamma-nloglik:4.63262	train-sMAPE:0.480391	val-sMAPE:0.593765
# [340]	train-gamma-nloglik:4.53371	val-gamma-nloglik:4.6273	train-sMAPE:0.47135	val-sMAPE:0.587455
# [350]	train-gamma-nloglik:4.52831	val-gamma-nloglik:4.62309	train-sMAPE:0.463562	val-sMAPE:0.58201
# [360]	train-gamma-nloglik:4.5237	val-gamma-nloglik:4.61978	train-sMAPE:0.456335	val-sMAPE:0.577389
# [370]	train-gamma-nloglik:4.51904	val-gamma-nloglik:4.6163	train-sMAPE:0.449285	val-sMAPE:0.572925
# [380]	train-gamma-nloglik:4.51476	val-gamma-nloglik:4.6126	train-sMAPE:0.442487	val-sMAPE:0.568605
# [390]	train-gamma-nloglik:4.51032	val-gamma-nloglik:4.60885	train-sMAPE:0.435556	val-sMAPE:0.564353
# [400]	train-gamma-nloglik:4.50619	val-gamma-nloglik:4.60578	train-sMAPE:0.428713	val-sMAPE:0.560245
# [410]	train-gamma-nloglik:4.50153	val-gamma-nloglik:4.60184	train-sMAPE:0.421174	val-sMAPE:0.55502
# [420]	train-gamma-nloglik:4.49718	val-gamma-nloglik:4.5983	train-sMAPE:0.413903	val-sMAPE:0.550381
# [430]	train-gamma-nloglik:4.49353	val-gamma-nloglik:4.59529	train-sMAPE:0.407687	val-sMAPE:0.546692
# [440]	train-gamma-nloglik:4.49033	val-gamma-nloglik:4.59271	train-sMAPE:0.402153	val-sMAPE:0.543399
# [450]	train-gamma-nloglik:4.48698	val-gamma-nloglik:4.58991	train-sMAPE:0.396691	val-sMAPE:0.539731
# [460]	train-gamma-nloglik:4.48353	val-gamma-nloglik:4.58707	train-sMAPE:0.390554	val-sMAPE:0.536187
# [470]	train-gamma-nloglik:4.48061	val-gamma-nloglik:4.58479	train-sMAPE:0.385475	val-sMAPE:0.532917
# [480]	train-gamma-nloglik:4.4777	val-gamma-nloglik:4.58278	train-sMAPE:0.380175	val-sMAPE:0.529988
# [490]	train-gamma-nloglik:4.47453	val-gamma-nloglik:4.58008	train-sMAPE:0.374412	val-sMAPE:0.52661
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-717a704f0bd8> in <module>()
#      37     #训练模型并保存
#      38     # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
# ---> 39     model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=10,feval=sMAPE)
#      40     model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing48_drop1/'+ str(i) +'_PM2.5.model') # 用于存储训练出的模型
#      41 #     model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing72/'+ str(i) +'_PM2.5.model') # 用于存储训练出的模型
#
# ~/virtual_pytorch_py3.5/lib/python3.5/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     202                            evals=evals,
#     203                            obj=obj, feval=feval,
# --> 204                            xgb_model=xgb_model, callbacks=callbacks)
#     205
#     206
#
# ~/virtual_pytorch_py3.5/lib/python3.5/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      82         # check evaluation result.
#      83         if len(evals) != 0:
# ---> 84             bst_eval_set = bst.eval_set(evals, i, feval)
#      85             if isinstance(bst_eval_set, STRING_TYPES):
#      86                 msg = bst_eval_set
#
# ~/virtual_pytorch_py3.5/lib/python3.5/site-packages/xgboost/core.py in eval_set(self, evals, iteration, feval)
#     961         if feval is not None:
#     962             for dmat, evname in evals:
# --> 963                 feval_ret = feval(self.predict(dmat), dmat)
#     964                 if isinstance(feval_ret, list):
#     965                     for name, val in feval_ret:
#
# <ipython-input-4-424a67ef7f90> in sMAPE(preds, xgb_train)
#       4         length = len(label)
#       5         for i in range(length):
# ----> 6             s += np.abs(preds[i] - label[i]) / ((np.abs(preds[i]) + np.abs(label[i])) / 2.)
#       7         sMAPE = s/float(length)
#       8         return 'sMAPE',float(sMAPE)
#
# KeyboardInterrupt:

# %% [markdown]
# # PM10

# %%
for i in tqdm(range(34)):
    trainX = np.concatenate((train_data[:,2*i:2*(i+1)],train_data[:,68:1485],train_data[:,1485+288*i:1485+288*(i+1)],train_data[:,-116:-102]),axis = 1)
    valX = np.concatenate((val_data[:,2*i:2*(i+1)],val_data[:,68:1485],val_data[:,1485+288*i:1485+288*(i+1)],val_data[:,-116:-102]),axis = 1)
    trainY = train_data[:, -102+3*i+1]
    valY = val_data[:, -102+3*i+1]
#     trainY = beijing_train[:, -105+3*i+1]
#     valY = beijing_test[:, -105+3*i+1]
    print(trainX.shape)
    print(valX.shape)

    params={
    'booster':'gbtree',
    'objective': 'reg:gamma', #多分类的问题
    # 'num_class':2, # 类别数，与 multisoftmax 并用
    'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':5, # 构建树的深度，越大越容易过拟合
    'lambda':100,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':0.9, # 随机采样训练样本
    'colsample_bytree':0.01, # 生成树时进行的列采样
    'min_child_weight':1, 
    # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
    #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
    #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
    'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
    'eta': 0.05, # 如同学习率
    'seed':1000,
    'nthread':-1,# cpu 线程数
#     'eval_metric': 'rmse'
    }

    plst = list(params.items())
    num_rounds = 5000 # 迭代次数
    xgb_train = xgb.DMatrix(trainX, label= trainY)
    xgb_val = xgb.DMatrix(valX, label= valY)
    watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
    #训练模型并保存
    # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
    model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=1000,feval=sMAPE)
    model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing48_drop1/'+ str(i) +'_PM10.model') # 用于存储训练出的模型
#     model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing72/'+ str(i) +'_PM10.model')
#     model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing168/'+ str(i) +'_PM10.model')

# %%
# i = 20
# trainY = train_data[:, -102+3*i+1]
# valY = val_data[:, -102+3*i+1]
# #     trainY = beijing_train[:, -105+3*i+1]
# #     valY = beijing_test[:, -105+3*i+1]
# print(trainX.shape)
# print(valX.shape)

# params={
# 'booster':'gbtree',
# 'objective': 'reg:linear', #多分类的问题
# # 'num_class':2, # 类别数，与 multisoftmax 并用
# 'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
# 'max_depth':4, # 构建树的深度，越大越容易过拟合
# 'lambda':1,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
# 'subsample':1, # 随机采样训练样本
# 'colsample_bytree':0.01, # 生成树时进行的列采样
# 'min_child_weight':1, 
# # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
# #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
# #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
# 'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
# 'eta': 0.05, # 如同学习率
# 'seed':1000,
# 'nthread':8,# cpu 线程数
# 'eval_metric': 'rmse'
# }

# plst = list(params.items())
# num_rounds = 2000 # 迭代次数
# xgb_train = xgb.DMatrix(trainX,  trainY)
# xgb_val = xgb.DMatrix(valX,  valY)
# watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
# #训练模型并保存
# # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
# model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50)
# #     model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing/'+ str(i) +'_PM10.model') # 用于存储训练出的模型
# model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing72/'+ str(i) +'_PM10.model')
# Out:
# (3494, 8245)
# (1498, 8245)
# [0]	train-rmse:102.737	val-rmse:89.7365
# Multiple eval metrics have been passed: 'val-rmse' will be used for early stopping.
#
# Will train until val-rmse hasn't improved in 50 rounds.
# [1]	train-rmse:99.5999	val-rmse:86.9237
# [2]	train-rmse:97.1512	val-rmse:84.2416
# [3]	train-rmse:94.363	val-rmse:81.8356
# [4]	train-rmse:92.2951	val-rmse:79.57
# [5]	train-rmse:90.245	val-rmse:77.374
# [6]	train-rmse:87.8097	val-rmse:75.0978
# [7]	train-rmse:85.5174	val-rmse:73.2543
# [8]	train-rmse:83.6684	val-rmse:71.6026
# [9]	train-rmse:81.6225	val-rmse:70.047
# [10]	train-rmse:79.8242	val-rmse:68.4456
# [11]	train-rmse:78.5462	val-rmse:67.1238
# [12]	train-rmse:76.8257	val-rmse:65.7985
# [13]	train-rmse:75.2064	val-rmse:64.6633
# [14]	train-rmse:74.033	val-rmse:63.3889
# [304]	train-rmse:23.9557	val-rmse:38.2498
# [305]	train-rmse:23.9367	val-rmse:38.2423
# [306]	train-rmse:23.8915	val-rmse:38.2282
# [307]	train-rmse:23.8191	val-rmse:38.2116
# [308]	train-rmse:23.7697	val-rmse:38.1957
# [309]	train-rmse:23.7246	val-rmse:38.1871
# [310]	train-rmse:23.6898	val-rmse:38.1576
# [311]	train-rmse:23.6278	val-rmse:38.1336
# [312]	train-rmse:23.5929	val-rmse:38.1112
# [313]	train-rmse:23.5619	val-rmse:38.0972
# [314]	train-rmse:23.4945	val-rmse:38.0539
# [315]	train-rmse:23.4333	val-rmse:38.0284
# [316]	train-rmse:23.4035	val-rmse:38.0136
# [317]	train-rmse:23.3591	val-rmse:37.984
# [318]	train-rmse:23.3194	val-rmse:37.9759
# [319]	train-rmse:23.2633	val-rmse:37.9525
# [320]	train-rmse:23.2022	val-rmse:37.9457
# [321]	train-rmse:23.1446	val-rmse:37.9369
# [322]	train-rmse:23.1065	val-rmse:37.9084
# [323]	train-rmse:23.0287	val-rmse:37.8889
# [324]	train-rmse:22.9971	val-rmse:37.8707
# [325]	train-rmse:22.9818	val-rmse:37.8714
# [326]	train-rmse:22.9356	val-rmse:37.8648
# [327]	train-rmse:22.9066	val-rmse:37.8541
# [328]	train-rmse:22.8618	val-rmse:37.8395
# [329]	train-rmse:22.8301	val-rmse:37.8284
# [330]	train-rmse:22.774	val-rmse:37.8112
# [331]	train-rmse:22.7505	val-rmse:37.8059
# [332]	train-rmse:22.7101	val-rmse:37.7797
# [333]	train-rmse:22.6536	val-rmse:37.7564
# [334]	train-rmse:22.6157	val-rmse:37.7323
# [335]	train-rmse:22.5844	val-rmse:37.717
# [336]	train-rmse:22.5274	val-rmse:37.7119
# [337]	train-rmse:22.4827	val-rmse:37.6844
# [338]	train-rmse:22.4626	val-rmse:37.6618
# [339]	train-rmse:22.4121	val-rmse:37.6448
# [340]	train-rmse:22.3396	val-rmse:37.6297
# [341]	train-rmse:22.3223	val-rmse:37.6253
# [342]	train-rmse:22.2851	val-rmse:37.6074
# [343]	train-rmse:22.2644	val-rmse:37.5977
# [344]	train-rmse:22.2366	val-rmse:37.5753
# [345]	train-rmse:22.1959	val-rmse:37.5674
# [346]	train-rmse:22.1546	val-rmse:37.5431
# [347]	train-rmse:22.1127	val-rmse:37.5303
# [348]	train-rmse:22.0704	val-rmse:37.5188
# [349]	train-rmse:22	val-rmse:37.4948
# [350]	train-rmse:21.9215	val-rmse:37.4743
# [351]	train-rmse:21.8962	val-rmse:37.471
# [352]	train-rmse:21.8609	val-rmse:37.4352
# [353]	train-rmse:21.8231	val-rmse:37.4292
# [354]	train-rmse:21.7735	val-rmse:37.4137
# [355]	train-rmse:21.7574	val-rmse:37.4059
# [356]	train-rmse:21.7053	val-rmse:37.3658
# [357]	train-rmse:21.6397	val-rmse:37.3172
# [358]	train-rmse:21.5815	val-rmse:37.2773
# [359]	train-rmse:21.5575	val-rmse:37.2785
# [360]	train-rmse:21.5009	val-rmse:37.2565
# [1979]	train-rmse:3.33033	val-rmse:32.0492
# [1980]	train-rmse:3.32668	val-rmse:32.0483
# [1981]	train-rmse:3.32462	val-rmse:32.0479
# [1982]	train-rmse:3.3234	val-rmse:32.0472
# [1983]	train-rmse:3.31805	val-rmse:32.0471
# [1984]	train-rmse:3.31342	val-rmse:32.0461
# [1985]	train-rmse:3.30911	val-rmse:32.0441
# [1986]	train-rmse:3.30798	val-rmse:32.0441
# [1987]	train-rmse:3.30516	val-rmse:32.0434
# [1988]	train-rmse:3.3004	val-rmse:32.0431
# [1989]	train-rmse:3.29732	val-rmse:32.0449
# [1990]	train-rmse:3.29577	val-rmse:32.0449
# [1991]	train-rmse:3.29036	val-rmse:32.0442
# [1992]	train-rmse:3.28547	val-rmse:32.0436
# [1993]	train-rmse:3.28006	val-rmse:32.0406
# [1994]	train-rmse:3.27782	val-rmse:32.0393
# [1995]	train-rmse:3.2763	val-rmse:32.0389
# [1996]	train-rmse:3.27436	val-rmse:32.0391
# [1997]	train-rmse:3.27135	val-rmse:32.038
# [1998]	train-rmse:3.26639	val-rmse:32.037
# [1999]	train-rmse:3.26063	val-rmse:32.037

# %% [markdown]
# # O3

# %%
for i in tqdm(range(34)):
    trainX = np.concatenate((train_data[:,2*i:2*(i+1)],train_data[:,68:1485],train_data[:,1485+288*i:1485+288*(i+1)],train_data[:,-116:-102]),axis = 1)
    valX = np.concatenate((val_data[:,2*i:2*(i+1)],val_data[:,68:1485],val_data[:,1485+288*i:1485+288*(i+1)],val_data[:,-116:-102]),axis = 1)
    trainY = train_data[:, -102+3*i+2]
    valY = val_data[:, -102+3*i+2]
#     trainY = beijing_train[:, -105+3*i+2]
#     valY = beijing_test[:, -105+3*i+2]
    print(trainX.shape)
    print(valX.shape)

    params={
    'booster':'gbtree',
    'objective': 'reg:gamma', #多分类的问题
    # 'num_class':2, # 类别数，与 multisoftmax 并用
    'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':5, # 构建树的深度，越大越容易过拟合
    'lambda':100,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':0.9, # 随机采样训练样本
    'colsample_bytree':0.01, # 生成树时进行的列采样
    'min_child_weight':1, 
    # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
    #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
    #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
    'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
    'eta': 0.05, # 如同学习率
    'seed':1000,
    'nthread':-1,# cpu 线程数
#     'eval_metric': 'rmse'
    }

    plst = list(params.items())
    num_rounds = 5000 # 迭代次数
    xgb_train = xgb.DMatrix(trainX, label= trainY)
    xgb_val = xgb.DMatrix(valX, label= valY)
    watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
    #训练模型并保存
    # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
    model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=1000,feval=sMAPE)
    model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing48_drop1/'+ str(i) +'_O3.model') # 用于存储训练出的模型
#     model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing72/'+ str(i) +'_O3.model')
#     model_PM10.save_model('/home/lifuzhen/KDD2018/model/beijing168/'+ str(i) +'_O3.model')

# %% [markdown]
# * 1.CD1
# * 2.BL0
# * 3.GR4
# * 4.MY7
# * 5.HV1
# * 6.GN3
# * 7.GR9
# * 8.LW2
# * 9.GN0
# * 10.KF1
# * 11.CD9
# * 12.ST5
# * 13.TH4

# %% [markdown]
# # PM2.5

# %%
import xgboost as xgb
train_data, val_data = train_test_split(London_train, test_size = 0.3, random_state = 1)
# trainX = train_data[:, :-26]
# valX = val_data[:, :-26]

# trainX = London_train[:, :-26]
# valX = London_test[:, :-26]

# %%
for i in tqdm(range(13)):
    trainX = np.concatenate((train_data[:,2*i:2*(i+1)],train_data[:,26:265],train_data[:,265+144*i:265+144*(i+1)],train_data[:,-34:-26]),axis = 1)
    valX = np.concatenate((val_data[:,2*i:2*(i+1)],val_data[:,26:265],val_data[:,265+144*i:265+144*(i+1)],val_data[:,-34:-26]),axis = 1)
    trainY = train_data[:, -26+2*i]
    valY = val_data[:, -26+2*i]
    
#     trainY = London_train[:, -26+2*i]
#     valY = London_test[:, -26+2*i]
    print(trainX.shape)
    print(valX.shape)

    params={
    'booster':'gbtree',
    'objective': 'reg:gamma', #多分类的问题
    # 'num_class':2, # 类别数，与 multisoftmax 并用
    'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':5, # 构建树的深度，越大越容易过拟合
    'lambda':1000,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':0.7, # 随机采样训练样本
    'colsample_bytree':0.1, # 生成树时进行的列采样
    'min_child_weight':1, 
    # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
    #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
    #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
    'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
    'eta': 0.05, # 如同学习率
    'seed':1000,
    'nthread':-1,# cpu 线程数
#     'eval_metric': 'rmse'
    }

    plst = list(params.items())
    num_rounds = 10000 # 迭代次数
    xgb_train = xgb.DMatrix(trainX, label= trainY)
    xgb_val = xgb.DMatrix(valX, label= valY)
    watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
    #训练模型并保存
    # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
    model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval = 1000,feval=sMAPE)
    model_PM10.save_model('/home/lifuzhen/KDD2018/model/London48_drop1/'+ str(i) +'_PM2.5.model') # 用于存储训练出的模型
#     model_PM10.save_model('/home/lifuzhen/KDD2018/model/London72/'+ str(i) +'_PM2.5.model')
#     model_PM10.save_model('/home/lifuzhen/KDD2018/model/London168/'+ str(i) +'_PM2.5.model')

# %% [markdown]
# # PM10

# %%
for i in tqdm(range(13)):
    trainX = np.concatenate((train_data[:,2*i:2*(i+1)],train_data[:,26:265],train_data[:,265+144*i:265+144*(i+1)],train_data[:,-34:-26]),axis = 1)
    valX = np.concatenate((val_data[:,2*i:2*(i+1)],val_data[:,26:265],val_data[:,265+144*i:265+144*(i+1)],val_data[:,-34:-26]),axis = 1)
    trainY = train_data[:, -26+2*i+1]
    valY = val_data[:, -26+2*i+1]
    
#     trainY = London_train[:, -26+2*i+1]
#     valY = London_test[:, -26+2*i+1]
    print(trainX.shape)
    print(valX.shape)

    params={
    'booster':'gbtree',
    'objective': 'reg:gamma', #多分类的问题
    # 'num_class':2, # 类别数，与 multisoftmax 并用
    'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':5, # 构建树的深度，越大越容易过拟合
    'lambda':1000,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':0.7, # 随机采样训练样本
    'colsample_bytree':0.1, # 生成树时进行的列采样
    'min_child_weight':1, 
    # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
    #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
    #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
    'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
    'eta': 0.05, # 如同学习率
    'seed':1000,
    'nthread':-1,# cpu 线程数
#     'eval_metric': 'rmse'
    }

    plst = list(params.items())
    num_rounds = 10000 # 迭代次数
    xgb_train = xgb.DMatrix(trainX, label= trainY)
    xgb_val = xgb.DMatrix(valX, label= valY)
    watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
    #训练模型并保存
    # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
    model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=1000,feval=sMAPE)
    model_PM10.save_model('/home/lifuzhen/KDD2018/model/London48_drop1/'+ str(i) +'_PM10.model') # 用于存储训练出的模型
#     model_PM10.save_model('/home/lifuzhen/KDD2018/model/London72/'+ str(i) +'_PM10.model')
#     model_PM10.save_model('/home/lifuzhen/KDD2018/model/London168/'+ str(i) +'_PM10.model')
