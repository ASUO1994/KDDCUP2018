# %% [markdown]
# # beijing

# %%
import requests
start = '2018-04-11-0'
end   = '2018-05-09-23'
url = 'https://biendata.com/competition/airquality/bj/'+start +'/'+end+'/2k0d1d8'
respones= requests.get(url)
with open ('/home/lifuzhen/KDD2018/Mini_train/bj_airquality_'+start +'_'+end+'.csv','w') as f:
    f.write(respones.text)
print('aq finished!')
url = 'https://biendata.com/competition/meteorology/bj/'+start +'/'+end+'/2k0d1d8'
respones= requests.get(url)
with open ('/home/lifuzhen/KDD2018/Mini_train/bj_meteorology_'+start +'_'+end+'.csv','w') as f:
    f.write(respones.text)
print('meo finished!')
url = 'https://biendata.com/competition/meteorology/bj_grid/'+start +'/'+end+'/2k0d1d8'
respones= requests.get(url)
with open ('/home/lifuzhen/KDD2018/Mini_train/bj_grid_meteorology_'+start +'_'+end+'.csv','w') as f:
    f.write(respones.text)
print('grid finished!')

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from datetime import timedelta
from datetime import datetime
from datetime import date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import copy

def gen_dates(b_date, count):
    hour = timedelta(hours=1)
    for i in range(count+1):
        yield b_date + hour*i


def get_date_list(start=None, end=None):
    """
    获取日期列表
    :param start: 开始日期
    :param end: 结束日期
    :return:
    """
    if start is None:
        start = datetime.strptime("2000-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")
    if end is None:
        end = datetime.now()
    data = []
    for d in gen_dates(start, int((end-start).total_seconds()/3600)):
        data.append(str(d))
    return data


Medium_PM10 = 88
Medium_PM25 = 59
Medium_O3   = 56
Medium_NO2  = 46
Medium_CO   = 1
Medium_SO2  = 9
def to_timedict_bj(start, end):
    "输入时间和表格，返回字典"
    aq = pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/bj_airquality_'+str(start).split(' ')[0]+'-'+str(int(str(start).split(' ')[1].split(':')[0])) +'_'+str(end).split(' ')[0]+'-'+str(int(str(end).split(' ')[1].split(':')[0]))+'.csv')
    meo = pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/bj_meteorology_'+str(start).split(' ')[0]+'-'+str(int(str(start).split(' ')[1].split(':')[0])) +'_'+str(end).split(' ')[0]+'-'+str(int(str(end).split(' ')[1].split(':')[0]))+'.csv')
    meo_grid = pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/bj_grid_meteorology_'+str(start).split(' ')[0]+'-'+str(int(str(start).split(' ')[1].split(':')[0])) +'_'+str(end).split(' ')[0]+'-'+str(int(str(end).split(' ')[1].split(':')[0]))+'.csv')
    
    alt_list = get_date_list(Start , End)
    alt_dict = {}
    recons = pd.DataFrame(columns=('stationId','utc_time','PM2.5','PM10','NO2','CO','O3','SO2'))
    
    for i in alt_list:
        alt_dict[i] = []
    alt = np.array(aq[['station_id','time','PM25_Concentration','PM10_Concentration','NO2_Concentration','CO_Concentration','O3_Concentration','SO2_Concentration']]).tolist()
    for i in tqdm(['aotizhongxin', 'badaling', 'beibuxinqu', 'daxing', 'dingling', 'donggaocun', 'dongsi','dongsihuan','fangshan', 'fengtaihuayuan', 'guanyuan', 'gucheng','huairou', 'liulihe', 'mentougou', 'miyun', 'miyunshuiku', 'nansanhuan', 'nongzhanguan', 'pingchang', 'pinggu','qianmen','shunyi','tiantan','tongzhou','wanliu','wanshouxigong','xizhimenbei','yanqin','yizhuang','yongdingmennei','yongledian','yufa','yungang']):
        count = 0
        for j in aq['station_id']:
            if j.split('_')[0] == i:
                recons.loc[count] = alt[count]
            count += 1 
#     print(recons)
    recons.reset_index(drop=True,inplace=True)
#     recons.loc[recons['stationId'] == 'zhiwuyuan_aq',['PM2.5','PM10','NO2','CO','O3','SO2']] = [Medium_PM25,Medium_PM10,Medium_NO2,Medium_CO,Medium_O3,Medium_SO2]

#     print(recons.loc[recons['stationId'] == 'zhiwuyuan_aq'])
    recons.interpolate(inplace = True)
#     print(recons.loc[recons['stationId'] == 'zhiwuyuan_aq'])
    recons['PM2.5'].fillna(Medium_PM25, inplace = True)
    recons['PM10'].fillna(Medium_PM10, inplace = True)
    recons['NO2'].fillna(Medium_NO2, inplace = True)
    recons['CO'].fillna(Medium_CO, inplace = True)
    recons['O3'].fillna(Medium_O3, inplace = True)
    recons['SO2'].fillna(Medium_SO2, inplace = True)
    
    recons['lon'] = 0 ##经度
    recons['lat'] = 0  ##纬度
    recons.loc[recons['stationId']=='dongsi_aq',['lon','lat']] = [116.417,39.929]
    recons.loc[recons['stationId']=='tiantan_aq',['lon','lat']] = [116.407,39.886]
    recons.loc[recons['stationId']=='guanyuan_aq',['lon','lat']] = [116.339,39.929]
    recons.loc[recons['stationId']=='wanshouxigong_aq',['lon','lat']] = [116.352,39.878]
    recons.loc[recons['stationId']=='aotizhongxin_aq',['lon','lat']] = [116.397,39.982]
    recons.loc[recons['stationId']=='nongzhanguan_aq',['lon','lat']] = [116.461,39.937]
    recons.loc[recons['stationId']=='wanliu_aq',['lon','lat']] = [116.287,39.987]
    recons.loc[recons['stationId']=='beibuxinqu_aq',['lon','lat']] = [116.174,40.09]
    recons.loc[recons['stationId']=='zhiwuyuan_aq',['lon','lat']] = [116.207,40.002]
    recons.loc[recons['stationId']=='fengtaihuayuan_aq',['lon','lat']] = [116.279,39.863]
    recons.loc[recons['stationId']=='yungang_aq',['lon','lat']] = [116.146,39.824]
    recons.loc[recons['stationId']=='gucheng_aq',['lon','lat']] = [116.184,39.914]
    recons.loc[recons['stationId']=='fangshan_aq',['lon','lat']] = [116.136,39.742]
    recons.loc[recons['stationId']=='daxing_aq',['lon','lat']] = [116.404,39.718]
    recons.loc[recons['stationId']=='yizhuang_aq',['lon','lat']] = [116.506,39.795]
    recons.loc[recons['stationId']=='tongzhou_aq',['lon','lat']] = [116.663,39.886]
    recons.loc[recons['stationId']=='shunyi_aq',['lon','lat']] = [116.655,40.127]
    recons.loc[recons['stationId']=='pingchang_aq',['lon','lat']] = [116.23,40.217]
    recons.loc[recons['stationId']=='mentougou_aq',['lon','lat']] = [116.106,39.937]
    recons.loc[recons['stationId']=='pinggu_aq',['lon','lat']] = [117.1,40.143]
    recons.loc[recons['stationId']=='hureconsou_aq',['lon','lat']] = [116.628,40.328]
    recons.loc[recons['stationId']=='miyun_aq',['lon','lat']] = [116.832,40.37]
    recons.loc[recons['stationId']=='yanqin_aq',['lon','lat']] = [115.972,40.453]
    recons.loc[recons['stationId']=='dingling_aq',['lon','lat']] = [116.22,40.292]
    recons.loc[recons['stationId']=='badaling_aq',['lon','lat']] = [115.988,40.365]
    recons.loc[recons['stationId']=='miyunshuiku_aq',['lon','lat']] = [116.911,40.499]
    recons.loc[recons['stationId']=='donggaocun_aq',['lon','lat']] = [117.12,40.1]
    recons.loc[recons['stationId']=='yongledian_aq',['lon','lat']] = [116.783,39.712]
    recons.loc[recons['stationId']=='yufa_aq',['lon','lat']] = [116.3,39.52]
    recons.loc[recons['stationId']=='liulihe_aq',['lon','lat']] = [116,39.58]
    recons.loc[recons['stationId']=='qianmen_aq',['lon','lat']] = [116.395,39.899]
    recons.loc[recons['stationId']=='yongdingmennei_aq',['lon','lat']] = [116.394,39.876]
    recons.loc[recons['stationId']=='xizhimenbei_aq',['lon','lat']] = [116.349,39.954]
    recons.loc[recons['stationId']=='nansanhuan_aq',['lon','lat']] = [116.368,39.856]
    recons.loc[recons['stationId']=='dongsihuan_aq',['lon','lat']] = [116.483,39.939]
    count = 0
    Idx = 0  ####索引记录####
    recons_list = np.array(recons[['lon','lat']]).tolist()
    for i in tqdm(np.array(recons['utc_time']).tolist()):
        if i in alt_dict.keys():
            alt_dict[i].extend(recons_list[Idx])

        Idx += 1
    
    count = 0
    Idx = 0  ####索引记录####
    recons_list = np.array(recons[['PM2.5','PM10','NO2','CO','O3','SO2']]).tolist()
    for i in tqdm(np.array(recons['utc_time']).tolist()):
        if i in alt_dict.keys():
            alt_dict[i].extend(recons_list[Idx])

        Idx += 1
        
    for k,v in alt_dict.items():
        if len(v) == 0:
            if int(k.split(' ')[1].split(':')[0]) != 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
            else:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
    for k,v in alt_dict.items():
        if len(v) == 0:
            if int(k.split(' ')[1].split(':')[0]) != 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
            else:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) == 272:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
#     print(recons)
    ######################处理缺失时间点完毕#####################shunyi_meo


    recons_meo = pd.DataFrame(columns=('station_id','time','temperature','pressure','humidity','wind_direction','wind_speed','weather'))

    alt = np.array(meo[['station_id','time','temperature','pressure','humidity','wind_direction','wind_speed','weather']]).tolist()
    for i in tqdm(['shunyi_meo','hadian_meo','yanqing_meo','miyun_meo','huairou_meo','shangdianzi_meo','pinggu_meo','tongzhou_meo','chaoyang_meo','pingchang_meo','zhaitang_meo','mentougou_meo','beijing_meo','shijingshan_meo','fengtai_meo','daxing_meo','fangshan_meo','xiayunling_meo']):
        count = 0
        for j in meo['station_id']:
            if j == i:
                recons_meo.loc[count] = alt[count]
            count += 1 
    
    for i in range(len(recons_meo['wind_speed'])):
        if recons_meo['wind_speed'][i] == 999017:
            recons_meo.loc[i,'wind_speed'] = recons_meo.loc[i-1,'wind_speed']
    recons_meo['longitude'] = 0 ##经度
    recons_meo['latitude'] = 0  ##纬度
    recons_meo.loc[recons_meo['station_id']=='shunyi_meo',['longitude','latitude']] = [116.6153,40.12667]
    recons_meo.loc[recons_meo['station_id']=='haidian_meo',['longitude','latitude']] = [116.2906,39.98694]
    recons_meo.loc[recons_meo['station_id']=='yanqing_meo',['longitude','latitude']] = [115.9689,40.44944]
    recons_meo.loc[recons_meo['station_id']=='miyun_meo',['longitude','latitude']] = [116.8642,40.3775]
    recons_meo.loc[recons_meo['station_id']=='huairou_meo',['longitude','latitude']] = [116.6269,40.35778]
    recons_meo.loc[recons_meo['station_id']=='shangdianzi_meo',['longitude','latitude']] = [117.1117,40.65889]
    recons_meo.loc[recons_meo['station_id']=='pinggu_meo',['longitude','latitude']] = [117.1178,40.16944]
    recons_meo.loc[recons_meo['station_id']=='tongzhou_meo',['longitude','latitude']] = [116.7567,39.8475]
    recons_meo.loc[recons_meo['station_id']=='chaoyang_meo',['longitude','latitude']] = [116.5008,39.9525]
    recons_meo.loc[recons_meo['station_id']=='pingchang_meo',['longitude','latitude']] = [116.2117,40.22333]
    recons_meo.loc[recons_meo['station_id']=='zhaitang_meo',['longitude','latitude']] = [115.6922,39.97389]
    recons_meo.loc[recons_meo['station_id']=='mentougou_meo',['longitude','latitude']] = [116.1564,39.88778]
    recons_meo.loc[recons_meo['station_id']=='beijing_meo',['longitude','latitude']] = [116.4694,39.80611]
    recons_meo.loc[recons_meo['station_id']=='shijingshan_meo',['longitude','latitude']] = [116.2053,39.9425]
    recons_meo.loc[recons_meo['station_id']=='fengtai_meo',['longitude','latitude']] = [116.2453,39.87028]
    recons_meo.loc[recons_meo['station_id']=='daxing_meo',['longitude','latitude']] = [116.3544,39.71861]
    recons_meo.loc[recons_meo['station_id']=='fangshan_meo',['longitude','latitude']] = [116.1942,39.77306]
    recons_meo.loc[recons_meo['station_id']=='xiayunling_meo',['longitude','latitude']] = [115.7406,39.72861]

    recons_meo.loc[meo['weather'] == 'Sunny/clear' , 'weather'] = 0
    recons_meo.loc[meo['weather'] == 'Snow' , 'weather'] = 1
    recons_meo.loc[meo['weather'] == 'Sleet' , 'weather'] = 2
    recons_meo.loc[meo['weather'] == 'Sand' , 'weather'] = 3
    recons_meo.loc[meo['weather'] == 'Rain/Snow with Hail' , 'weather'] = 4
    recons_meo.loc[meo['weather'] == 'Rain with Hail' , 'weather'] = 5
    recons_meo.loc[meo['weather'] == 'Rain' , 'weather'] = 6
    recons_meo.loc[meo['weather'] == 'Haze' , 'weather'] = 7
    recons_meo.loc[meo['weather'] == 'Fog' , 'weather'] = 8
    recons_meo.loc[meo['weather'] == 'Dust' , 'weather'] = 9
    recons_meo.loc[meo['weather'] == 'Hail' , 'weather'] = 4
    recons_meo.loc[meo['weather'] == 'Cloudy' , 'weather'] = 0
    recons_meo.loc[meo['weather'] == 'Overcast' , 'weather'] = 0
    recons_meo.loc[meo['weather'] == 'Thundershower' , 'weather'] = 6
    def div5(x):
        return int(x/5)
    def div15(x):
        return int(x/15)
    def div05(x):
        return int(x/0.5)
    recons_meo['temperature'] = recons_meo['temperature'].apply(div5)
    recons_meo['pressure'] = recons_meo['pressure'].apply(div5)
    recons_meo['humidity'] = recons_meo['humidity'].apply(div5)
    recons_meo['wind_direction'] = recons_meo['wind_direction'].apply(div15)
    recons_meo['wind_speed/kph'] = recons_meo['wind_speed'].apply(div05)
    #############wether量化###############

    #############处理缺失时间点##########
    count = 0
    Idx = 0  ####索引记录####
    meo_list = np.array(recons_meo[['temperature','pressure','humidity','wind_direction','wind_speed','weather']]).tolist()
    

    for i in tqdm(np.array(recons_meo['time']).tolist()):
        if i in alt_dict.keys():
            alt_dict[i].extend(meo_list[Idx])

        Idx += 1
        
    length = []  
    
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 416:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))  
    
    for i in range(3):
        for k,v in alt_dict.items():
            if len(v) < max(length):
                if int(k.split(' ')[1].split(':')[0]) != 0:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
                else:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
                
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 416:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))  
    ######################处理缺失时间点完毕#####################
    meo_grid['longitude'] = 0 ##经度
    meo_grid['latitude'] = 0  ##纬度
    count = 0
    for i in range(1150,1181,1):
        for j in range(390,411,1):
            if (i >= 1156 and i <= 1172) and (j >= 395 and j <= 407):
                meo_grid.loc[meo_grid['station_id']=='beijing_grid_'+str(count).zfill(3),['longitude','latitude']] = [i/10.0,j/10.0]
#                 print([i,j])
            count += 1
    
    meo_grid.drop(meo_grid[meo_grid['longitude'] < 115.6].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['longitude'] > 117.2].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['latitude']  < 39.5].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['latitude']  > 40.7].index.tolist(),inplace= True)
    meo_grid.drop('id',axis = 1)
    meo_grid.drop_duplicates(inplace=True)
    meo_grid.reset_index(drop=True,inplace=True)
#     print(meo_grid.head(100))
    def div5(x):
        return int(x/5)
    def div15(x):
        return int(x/15)
    def div05(x):
        return int(x/0.5)
    meo_grid['temperature'] = meo_grid['temperature'].apply(div5)
    meo_grid['pressure'] = meo_grid['pressure'].apply(div5)
    meo_grid['humidity'] = meo_grid['humidity'].apply(div5)
    meo_grid['wind_direction'] = meo_grid['wind_direction'].apply(div15)
    meo_grid['wind_speed/kph'] = meo_grid['wind_speed'].apply(div05)
    
    
    
    
    count = 1
    Idx = 0  ####索引记录####

    meo_grid_list = np.array(meo_grid[['temperature','pressure','humidity','wind_direction','wind_speed']]).tolist()
    for i in tqdm(meo_grid['time']):
        if i in alt_dict.keys():
            if Idx > 0:
                count = int(meo_grid['station_id'][Idx].split('_')[2]) - int(meo_grid['station_id'][Idx-1].split('_')[2])
                
            if count > 1 and count < 9:
                for j in range(count-1):
                    alt_dict[i].extend(meo_grid_list[Idx-1])
            if count > 9:
                for j in range(count-9):
                    alt_dict[i].extend(meo_grid_list[Idx+1])
            alt_dict[i].extend(meo_grid_list[Idx])
        Idx += 1
        
        
        
        
        
        
        
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 1963:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    for i in range(3):
        for k,v in alt_dict.items():
            if len(v) != 1485:
                if int(k.split(' ')[1].split(':')[0]) != 0:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
                else:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
                
            
            
        
        
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 1963:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    pop_list = []
    for k in tqdm(alt_dict.keys()):
        weather_fore = pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/bj_grid_meteorology_forecast_48_hours_'+k.split(' ')[0]+'-'+str(int(k.split(' ')[1].split(':')[0]))+'.csv')
        if np.array(weather_fore).tolist() == []:
            pop_list.append(k)
            continue
        weather_fore['weather'].replace(['CLEAR_DAY','CLEAR_NIGHT','CLOUDY','PARTLY_CLOUDY_DAY','PARTLY_CLOUDY_NIGHT','RAIN','SNOW','WIND','HAZE'],[0,1,2,3,4,5,6,7,8],inplace = True)
        weather_fore['longitude'] = 0 ##经度
        weather_fore['latitude'] = 0  ##纬度
        count = 0
#         print(k)
        for i in range(1150,1181,1):
            for j in range(390,411,1):
                if (i >= 1156 and i <= 1172) and (j >= 395 and j <= 407):
                    weather_fore.loc[weather_fore['station_id']=='beijing_grid_'+str(count).zfill(3),['longitude','latitude']] = [i/10.0,j/10.0]
#                     print([i,j])
                count += 1

        weather_fore.drop(weather_fore[weather_fore['longitude'] < 115.6].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['longitude'] > 117.2].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['latitude']  < 39.5].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['latitude']  > 40.7].index.tolist(),inplace= True)
        weather_fore.reset_index(drop=True,inplace=True)
        
        weather_fore_array = np.array(weather_fore['weather'])
        alt_dict[k].extend(weather_fore_array.tolist())
#         print(len(alt_dict[k]))
        if len(alt_dict[k]) != 12093:
            pop_list.append(k)
    print(pop_list)
    for i in pop_list:
        alt_dict[i].extend(np.zeros(12093-len(alt_dict[i])).tolist())
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 1963:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    
    alt_frame = pd.DataFrame.from_dict(alt_dict).T
    count = 0
    for i in list(alt_frame.index):
        if i in pop_list:
            alt_frame.iloc[count,list(range(1485,12093))] = copy.deepcopy(alt_frame.iloc[count-1,list(range(1485,12093))])
            alt_dict[i][1485:12093] = copy.deepcopy(alt_frame.iloc[count-1,list(range(1485,12093))]).tolist()
        count += 1
    ##########提取aq 48小时滑窗##########
    win = 48
#     win = 72
#     win = 16
#     win = 168
    
    for i in tqdm(range(68,272)):  
        count = 0
        for j in alt_frame[i]:
            if count >= win:
                alt_dict[alt_frame.index[count]].extend([np.mean(alt_frame[i][count-win:count]),np.std(alt_frame[i][count-win:count])])
                if i == 271:
                    if date.isoweekday(datetime.strptime(alt_frame.index[count], "%Y-%m-%d %H:%M:%S")) == 3 or date.isoweekday(datetime.strptime(alt_frame.index[count], "%Y-%m-%d %H:%M:%S")) == 4: ###要预测的是周末
                        alt_dict[alt_frame.index[count]].extend([1])
                    else:
                        alt_dict[alt_frame.index[count]].extend([0])
                    if int(alt_frame.index[count].split(' ')[1].split(':')[0]) in [0,1,2,10,11,12]: #####是否为早晚高峰时段（北京转utc时间）
                        alt_dict[alt_frame.index[count]].extend([2])
                    elif int(alt_frame.index[count].split(' ')[1].split(':')[0]) in [16,17,18,19,20]:
                        alt_dict[alt_frame.index[count]].extend([1])
                    else:
                        alt_dict[alt_frame.index[count]].extend([0])
                    alt_dict[alt_frame.index[count]].append(int(alt_frame.index[count].split(' ')[1].split(':')[0]))
            count += 1
            
    hour_last = ''
    count = 0
    for k in tqdm(list(alt_frame.index)):
        for i in range(0,6):
            SUM = 0
            for j in range(0,34):
                SUM += alt_dict[k][68+j*6+i]
            alt_dict[k].append(SUM)

        if count == 0:
            alt_dict[k].extend([0,0,0,0,0,0])
        else:
            for m,n in zip(alt_dict[k][-6:] ,alt_dict[hour_last][-12:-6]):
                alt_dict[k].append(m-n)

        hour_last = k
        count += 1
    ##########标签值 PM10 PM2.5 O3##########
    step = 72  ####预测间隔
    for i in tqdm(range(68,272)):  ##训练数据
        count = 0
        for j in alt_frame[i]:
            if count+step < len(alt_frame[i]) and ((i-68)%6 == 0 or (i-68)%6 == 1 or (i-68)%6 == 4):
                alt_dict[alt_frame.index[count]].append(np.array(alt_frame[i][count+step]).tolist())
            count += 1
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) < 4973:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    
    pop_list = []
    for i in alt_dict.keys():
        if len(alt_dict[i]) <  max(length):
            pop_list.append(i)
    for i in pop_list:
        alt_dict.pop(i)
        
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) == 4960:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    
    return alt_dict

# %%
Start = datetime.strptime("2018-04-11 00:00:00", "%Y-%m-%d %H:%M:%S")
End = datetime.strptime("2018-05-09 23:00:00", "%Y-%m-%d %H:%M:%S")

pre_dict_bj = to_timedict_bj(start = Start, end = End)
pre_frame_bj = pd.DataFrame.from_dict(pre_dict_bj).T
pre_list_bj = np.array(pre_frame_bj)
# Out:
# 100%|██████████| 34/34 [00:58<00:00,  1.73s/it]
# 100%|██████████| 22542/22542 [00:00<00:00, 1845127.06it/s]
# 100%|██████████| 22542/22542 [00:00<00:00, 1687483.28it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# 272
# 272
# 100%|██████████| 18/18 [00:37<00:00,  2.07s/it]
# 100%|██████████| 12061/12061 [00:00<00:00, 1719610.46it/s]
# 380
# 272
# 380
# 380
# 100%|██████████| 151820/151820 [00:03<00:00, 41575.63it/s]
#   0%|          | 0/696 [00:00<?, ?it/s]
# 1490
# 380
# 1485
# 1485
# 100%|██████████| 696/696 [12:06<00:00,  1.04s/it]
# ['2018-04-22 10:00:00', '2018-05-05 21:00:00', '2018-05-05 18:00:00', '2018-05-03 18:00:00', '2018-04-19 06:00:00', '2018-05-05 19:00:00', '2018-05-05 11:00:00', '2018-05-05 13:00:00', '2018-05-05 14:00:00', '2018-04-18 10:00:00', '2018-04-19 07:00:00', '2018-05-05 23:00:00', '2018-05-07 09:00:00', '2018-05-03 20:00:00', '2018-05-05 16:00:00', '2018-04-12 04:00:00', '2018-05-05 15:00:00', '2018-05-05 17:00:00', '2018-05-03 19:00:00', '2018-04-15 11:00:00', '2018-04-12 05:00:00', '2018-05-05 22:00:00', '2018-05-05 12:00:00', '2018-04-19 12:00:00', '2018-05-05 20:00:00', '2018-05-05 10:00:00', '2018-04-15 13:00:00']
# 12093
# 1485
# 100%|██████████| 204/204 [00:52<00:00,  3.89it/s]
# 100%|██████████| 696/696 [00:00<00:00, 36574.11it/s]
# 100%|██████████| 204/204 [00:01<00:00, 125.69it/s]
# 12618
# 12207
# 12618
# 12618

# %%
pre_list_bj.shape
# Out:
# (576, 12618)

# %%
pre_frame_bj.index
# Out:
# Index(['2018-04-13 00:00:00', '2018-04-13 01:00:00', '2018-04-13 02:00:00',
#        '2018-04-13 03:00:00', '2018-04-13 04:00:00', '2018-04-13 05:00:00',
#        '2018-04-13 06:00:00', '2018-04-13 07:00:00', '2018-04-13 08:00:00',
#        '2018-04-13 09:00:00',
#        ...
#        '2018-05-06 14:00:00', '2018-05-06 15:00:00', '2018-05-06 16:00:00',
#        '2018-05-06 17:00:00', '2018-05-06 18:00:00', '2018-05-06 19:00:00',
#        '2018-05-06 20:00:00', '2018-05-06 21:00:00', '2018-05-06 22:00:00',
#        '2018-05-06 23:00:00'],
#       dtype='object', length=576)

# %%
pre_frame_bj.to_csv('/home/lifuzhen/KDD2018/Mini_train/traindata/bj_mean_std.csv')

# %% [markdown]
# # London

# %%
start = '2018-04-12-0'
end   = '2018-05-09-23'
url = 'https://biendata.com/competition/airquality/ld/'+start +'/'+end+'/2k0d1d8'
respones= requests.get(url)
with open ('/home/lifuzhen/KDD2018/Mini_train/ld_airquality_'+start +'_'+end+'.csv','w') as f:
    f.write(respones.text)
print('aq finished!')

url = 'https://biendata.com/competition/meteorology/ld_grid/'+start +'/'+end+'/2k0d1d8'
respones= requests.get(url)
with open ('/home/lifuzhen/KDD2018/Mini_train/ld_grid_meteorology_'+start +'_'+end+'.csv','w') as f:
    f.write(respones.text)
print('grid finished!')
# Out:
# aq finished!
# grid finished!

# %%
Medium_PM10 = 13.437369
Medium_PM25 = 20.921357
Medium_O3   = 43.428245

def to_timedict_ld(start, end):
    "输入时间和表格，返回字典"
    aq = pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/ld_airquality_'+str(start).split(' ')[0]+'-'+str(int(str(start).split(' ')[1].split(':')[0])) +'_'+str(end).split(' ')[0]+'-'+str(int(str(end).split(' ')[1].split(':')[0]))+'.csv')
    meo_grid = pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/ld_grid_meteorology_'+str(start).split(' ')[0]+'-'+str(int(str(start).split(' ')[1].split(':')[0])) +'_'+str(end).split(' ')[0]+'-'+str(int(str(end).split(' ')[1].split(':')[0]))+'.csv')
    meo_grid.drop('id',axis=1, inplace = True)
    meo_grid.drop_duplicates(inplace = True)
    meo_grid.reset_index(drop = True, inplace =True)
    alt_list = get_date_list(Start , End)
    alt_dict = {}
    recons = pd.DataFrame(columns=('station_id','MeasurementDateGMT','PM2.5 (ug/m3)','PM10 (ug/m3)','NO2 (ug/m3)'))
    
    for i in alt_list:
        alt_dict[i] = []
    alt = np.array(aq[['station_id','time','PM25_Concentration','PM10_Concentration','NO2_Concentration']]).tolist()
    for i in tqdm(['CD1','BL0','GR4','MY7','HV1','GN3','GR9','LW2','GN0','KF1','CD9','ST5','TH4']):
        count = 0
        for j in aq['station_id']:
            if j.split('_')[0] == i:
                recons.loc[count] = alt[count]
            count += 1 
#     print(recons)
    recons.drop_duplicates(inplace = True)
    recons.reset_index(drop=True,inplace=True)
    recons.interpolate(inplace = True)
#     print(recons.loc[recons['station_id'] == 'TH4' , 'NO2 (ug/m3)'])
    recons['PM2.5 (ug/m3)'].fillna(Medium_PM25, inplace = True)
    recons['PM10 (ug/m3)'].fillna(Medium_PM10, inplace = True)
    recons['NO2 (ug/m3)'].fillna(Medium_NO2, inplace = True)

    recons['lon'] = 0 ##经度
    recons['lat'] = 0  ##纬度
    recons.loc[recons['station_id']=='BL0',['lon','lat']] = [-0.125848,51.522287]
    recons.loc[recons['station_id']=='CD9',['lon','lat']] = [-0.129053205,51.52770662]
    recons.loc[recons['station_id']=='CD1',['lon','lat']] = [-0.175284,51.544219]
    recons.loc[recons['station_id']=='GN0',['lon','lat']] = [0.074003,51.490532]
    recons.loc[recons['station_id']=='GR4',['lon','lat']] = [0.070766,51.45258]
    recons.loc[recons['station_id']=='GN3',['lon','lat']] = [0.095111,51.486957]
    recons.loc[recons['station_id']=='GR9',['lon','lat']] = [0.040725,51.456357]
    recons.loc[recons['station_id']=='HV1',['lon','lat']] = [0.205460706,51.52078746]
    recons.loc[recons['station_id']=='KF1',['lon','lat']] = [-0.21349214,51.52104675]
    recons.loc[recons['station_id']=='LW2',['lon','lat']] = [-0.039641,51.474954]
    recons.loc[recons['station_id']=='ST5',['lon','lat']] = [-0.141661525,51.3892869]
    recons.loc[recons['station_id']=='TH4',['lon','lat']] = [-0.008418493,51.51504617]
    recons.loc[recons['station_id']=='MY7',['lon','lat']] = [-0.125848,51.522287]
    recons.loc[recons['station_id']=='BL0',['lon','lat']] = [-0.15459,51.52254]
        
    count = 0
    Idx = 0  ####索引记录####
    recons_list = np.array(recons[['lon','lat']]).tolist()
    for i in tqdm(np.array(recons['MeasurementDateGMT']).tolist()):
        if i in alt_dict.keys():
            alt_dict[i].extend(recons_list[Idx])

        Idx += 1
    
    count = 0
    Idx = 0  ####索引记录####
    recons_list = np.array(recons[['PM2.5 (ug/m3)','PM10 (ug/m3)','NO2 (ug/m3)']]).tolist()
    for i in tqdm(np.array(recons['MeasurementDateGMT']).tolist()):
        if i in alt_dict.keys():
            alt_dict[i].extend(recons_list[Idx])

        Idx += 1
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) <65:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))

    for k,v in alt_dict.items():
        if len(v) < max(length):
            if int(k.split(' ')[1].split(':')[0])!= 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
                if len(alt_dict[k]) < max(length):
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
            if int(k.split(' ')[1].split(':')[0]) == 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
    for k,v in alt_dict.items():
        if len(v) < max(length):
            if int(k.split(' ')[1].split(':')[0])!= 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
                if len(alt_dict[k]) < max(length):
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
            if int(k.split(' ')[1].split(':')[0]) == 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) <65:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
#     print(recons)
    
    meo_grid['longitude'] = 0 ##经度
    meo_grid['latitude'] = 0  ##纬度
    count = 0
    for i in range(-20,21,1):
        for j in range(505,526,1):
            if (i >= -4 and i <=3) and (j >= 513 and j <= 517):
                meo_grid.loc[meo_grid['station_id']=='london_grid_'+str(count).zfill(3),['longitude','latitude']] = [i/10.0,j/10.0]
            count += 1
#     print(meo_grid)
    meo_grid.drop(meo_grid[meo_grid['longitude'] < -0.4].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['longitude'] >  0.3].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['latitude']  < 51.3].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['latitude']  > 51.7].index.tolist(),inplace= True)
    meo_grid.reset_index(drop = True,inplace = True)
    def div5(x):
        return int(x/5)
    def div15(x):
        return int(x/15)
    def div05(x):
        return int(x/0.5)
    meo_grid['temperature'] = meo_grid['temperature'].apply(div5)
    meo_grid['pressure'] = meo_grid['pressure'].apply(div5)
    meo_grid['humidity'] = meo_grid['humidity'].apply(div5)
    meo_grid['wind_direction'] = meo_grid['wind_direction'].apply(div15)
    meo_grid['wind_speed/kph'] = meo_grid['wind_speed'].apply(div05)
#     print(meo_grid)
    count = 1
    Idx = 0  ####索引记录####
#     print(meo_grid['station_id'][15561])
    meo_grid_list = np.array(meo_grid[['temperature','pressure','humidity','wind_direction','wind_speed']]).tolist()
    for i in tqdm(meo_grid['time']):
        if i in alt_dict.keys():
            
            if Idx > 0:
                count = int(meo_grid['station_id'][Idx].split('_')[2]) - int(meo_grid['station_id'][Idx-1].split('_')[2])
                
            if count > 1 and count < 17:
                for j in range(count-1):
                    alt_dict[i].extend(meo_grid_list[Idx-1]) 
            if count > 17:
                for j in range(count-17):
                    alt_dict[i].extend(meo_grid_list[Idx+1]) 
            alt_dict[i].extend(meo_grid_list[Idx])
        Idx += 1
        
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) == 2217:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    for i in range(3):
        for k,v in alt_dict.items():
            if len(v) < max(length):
                if int(k.split(' ')[1].split(':')[0])!= 0:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
                else:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
    
    pop_list = []
    for k in tqdm(alt_dict.keys()):
        weather_fore = pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/ld_grid_meteorology_forecast_48_hours_'+k.split(' ')[0]+'-'+str(int(k.split(' ')[1].split(':')[0]))+'.csv')
        if np.array(weather_fore).tolist() == []:
            pop_list.append(k)
            continue
        weather_fore['weather'].replace(['CLEAR_DAY','CLEAR_NIGHT','CLOUDY','PARTLY_CLOUDY_DAY','PARTLY_CLOUDY_NIGHT','RAIN','SNOW','WIND','HAZE'],[0,1,2,3,4,5,6,7,8],inplace=True)
        weather_fore['longitude'] = 0 ##经度
        weather_fore['latitude'] = 0  ##纬度
        count = 0
#         print(k)
        for i in range(-20,21,1):
            for j in range(505,526,1):
                if (i >= -4 and i <= 3) and (j >= 513 and j <= 517):
                    weather_fore.loc[weather_fore['station_id']=='london_grid_'+str(count).zfill(3),['longitude','latitude']] = [i/10.0,j/10.0]
#                     print([i,j])
                count += 1

        weather_fore.drop(weather_fore[weather_fore['longitude'] < -0.4].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['longitude'] > 0.3].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['latitude']  < 51.3].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['latitude']  > 51.7].index.tolist(),inplace= True)
        weather_fore.reset_index(drop=True,inplace=True)
        
        weather_fore_array = np.array(weather_fore['weather'])
        alt_dict[k].extend(weather_fore_array.tolist())
#         print(len(alt_dict[k]))
        if len(alt_dict[k]) != 2185:
            pop_list.append(k)
    for i in pop_list:
        alt_dict[i].extend(np.zeros(2185-len(alt_dict[i])).tolist())
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 1963:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    
    alt_frame = pd.DataFrame.from_dict(alt_dict).T
    count = 0
    for i in list(alt_frame.index):
        if i in pop_list:
            alt_frame.iloc[count,list(range(265,2185))] = copy.deepcopy(alt_frame.iloc[count-1,list(range(265,2185))])
            alt_dict[i][265:2185] = copy.deepcopy(alt_frame.iloc[count-1,list(range(265,2185))]).tolist()
        count += 1
#     print(alt_frame[62])
    ##########提取aq 48小时滑窗##########
    win = 48
#     win = 72
#     win = 168

    for i in tqdm(range(26,65)):  
        count = 0
        for j in alt_frame[i]:
            if count >= win:
                alt_dict[alt_frame.index[count]].extend([np.mean(alt_frame[i][count-win:count]),np.std(alt_frame[i][count-win:count])])
                if i == 64:
                    if date.isoweekday(datetime.strptime(alt_frame.index[count], "%Y-%m-%d %H:%M:%S")) == 3 or date.isoweekday(datetime.strptime(alt_frame.index[count], "%Y-%m-%d %H:%M:%S")) == 4: ###要预测的是周末
                        alt_dict[alt_frame.index[count]].extend([1])
                    else:
                        alt_dict[alt_frame.index[count]].extend([0])
#                     if int(alt_frame.index[count].split(' ')[1].split(':')[0]) in [8,9,10,18,19,20]: #####是否为早晚高峰时段（北京转utc时间）
#                         alt_dict[alt_frame.index[count]].extend([2])
#                     elif int(alt_frame.index[count].split(' ')[1].split(':')[0]) in [0,1,2,3,4,5]:
#                         alt_dict[alt_frame.index[count]].extend([1])
#                     else:
#                         alt_dict[alt_frame.index[count]].extend([0])
                    alt_dict[alt_frame.index[count]].append(int(alt_frame.index[count].split(' ')[1].split(':')[0]))
            count += 1
            
    hour_last = ''
    count = 0
    for k in tqdm(list(alt_frame.index)):
        for i in range(0,3):
            SUM = 0
            for j in range(0,13):
                SUM += alt_dict[k][26+j*3+i]
            alt_dict[k].append(SUM)

        if count == 0:
            alt_dict[k].extend([0,0,0])
        else:
            for m,n in zip(alt_dict[k][-3:] ,alt_dict[hour_last][-6:-3]):
                alt_dict[k].append(m-n)
        hour_last = k
        count += 1
    ##########标签值 PM10 PM2.5 O3##########
    step = 72
    for i in tqdm(range(26,65)):  ##训练数据
        count = 0
        for j in alt_frame[i]:
            if count+step < len(alt_frame[i]) and ((i-26)%3 == 0 or (i-26)%3 == 1):
                alt_dict[alt_frame.index[count]].append(np.array(alt_frame[i][count+step]).tolist())
            count += 1
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) < 6092:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
            
    pop_list = []
    for i in alt_dict.keys():
        if len(alt_dict[i])<max(length):
            pop_list.append(i)
    for i in pop_list:
        alt_dict.pop(i)
        
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) == 4960:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    
    return alt_dict

# %%
Start = datetime.strptime("2018-04-12 00:00:00", "%Y-%m-%d %H:%M:%S")
End = datetime.strptime("2018-05-09 23:00:00", "%Y-%m-%d %H:%M:%S")
pre_dict_ld = to_timedict_ld(start = Start, end = End)
pre_frame_ld = pd.DataFrame.from_dict(pre_dict_ld).T
pre_list_ld = np.array(pre_frame_ld)
# Out:
# 100%|██████████| 13/13 [00:18<00:00,  1.39s/it]
# 100%|██████████| 8584/8584 [00:00<00:00, 1947420.25it/s]
# 100%|██████████| 8584/8584 [00:00<00:00, 1889869.59it/s]
# 65
# 0
# 65
# 65
# 100%|██████████| 26480/26480 [00:00<00:00, 42124.97it/s]
#   0%|          | 0/672 [00:00<?, ?it/s]
# 265
# 65
# 100%|██████████| 672/672 [03:39<00:00,  3.06it/s]
#   0%|          | 0/39 [00:00<?, ?it/s]
# 2185
# 65
# 100%|██████████| 39/39 [00:09<00:00,  4.12it/s]
# 100%|██████████| 672/672 [00:00<00:00, 124566.77it/s]
# 100%|██████████| 39/39 [00:00<00:00, 126.55it/s]
# 2297
# 2217
# 2297
# 2297

# %%
pre_list_ld.shape
# Out:
# (552, 2297)

# %%
pre_frame_ld.index
# Out:
# Index(['2018-04-14 00:00:00', '2018-04-14 01:00:00', '2018-04-14 02:00:00',
#        '2018-04-14 03:00:00', '2018-04-14 04:00:00', '2018-04-14 05:00:00',
#        '2018-04-14 06:00:00', '2018-04-14 07:00:00', '2018-04-14 08:00:00',
#        '2018-04-14 09:00:00',
#        ...
#        '2018-05-06 14:00:00', '2018-05-06 15:00:00', '2018-05-06 16:00:00',
#        '2018-05-06 17:00:00', '2018-05-06 18:00:00', '2018-05-06 19:00:00',
#        '2018-05-06 20:00:00', '2018-05-06 21:00:00', '2018-05-06 22:00:00',
#        '2018-05-06 23:00:00'],
#       dtype='object', length=552)

# %%
pre_frame_ld.to_csv('/home/lifuzhen/KDD2018/Mini_train/traindata/ld_mean_std.csv')

# %%
import pandas as pd
import numpy as np
beijing_train = np.array(pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/traindata/bj_mean_std.csv'))[:,1:]
London_train = np.array(pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/traindata/ld_mean_std.csv'))[:,1:]
def sMAPE(preds, xgb_train):   
    s = 0
    label = xgb_train.get_label()
    length = len(label)
    for i in range(length):
        s += float(np.abs(preds[i] - label[i]))/ (float(np.abs(preds[i]) + np.abs(label[i])) / 2.)
    sMAPE = s/float(length)
    return 'sMAPE',float(sMAPE)

# %% [markdown]
# # MODEL BJ

# %%
import xgboost as xgb
from sklearn.cross_validation import train_test_split
from tqdm import tqdm
import matplotlib.pyplot as plt
# train_data, val_data = train_test_split(beijing_train, test_size = 0.3, random_state = 1)###随机数原始为1
train_data, val_data = beijing_train[:-48,:], beijing_train[-48:,:]###随机数原始为1
# Out:
# /home/lifuzhen/virtual_pytorch_py3.5/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # PM2.5

# %%
for i in tqdm(range(34)):
    trainX = np.concatenate((train_data[:,2*i:2*(i+1)],train_data[:,68:12093],train_data[:,12093+12*i:12093+12*(i+1)],train_data[:,-117:-115],train_data[:,-114:-102]),axis = 1)
    valX = np.concatenate((val_data[:,2*i:2*(i+1)],val_data[:,68:12093],val_data[:,12093+12*i:12093+12*(i+1)],val_data[:,-117:-115],val_data[:,-114:-102]),axis = 1)
    trainY = train_data[:, -102+3*i]
    valY = val_data[:, -102+3*i]
#     trainY = beijing_train[:, -105+3*i]
#     valY = beijing_test[:, -105+3*i]
    print(trainX.shape)
    print(valX.shape)

    params={
    'booster':'gbtree',
    'objective': 'reg:gamma', #多分类的问题
    # 'num_class':2, # 类别数，与 multisoftmax 并用
    'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':2, # 构建树的深度，越大越容易过拟合
    'lambda':1,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':0.9, # 随机采样训练样本
    'colsample_bytree':0.2, # 生成树时进行的列采样
    'min_child_weight':1, 
    # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
    #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
    #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
    'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
    'eta': 0.05, # 如同学习率
    'seed':1000,
    'nthread':-1,# cpu 线程数
#     'eval_metric':['mae','rmse']
    }

    plst = list(params.items())
    num_rounds = 600 # 迭代次数
    xgb_train = xgb.DMatrix(trainX, label= trainY)
    xgb_val = xgb.DMatrix(valX, label= valY)
    watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
    #训练模型并保存
    # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
    model_PM10 = xgb.train(plst ,xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=100,feval=sMAPE)
    plt.plot(model_PM10.predict(xgb.DMatrix(valX)),'g')
    plt.plot(valY,'r')
    plt.show()
    model_PM10.save_model('/home/lifuzhen/KDD2018/Mini_train/bj_mean_std/'+ str(i) +'_PM2.5.model') # 用于存储训练出的模型
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
# (528, 12053)
# (48, 12053)
# [0]	train-gamma-nloglik:126.051	val-gamma-nloglik:92.2527	train-sMAPE:1.93338	val-sMAPE:1.95376
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/home/lifuzhen/virtual_pytorch_py3.5/lib/python3.5/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/lifuzhen/virtual_pytorch_py3.5/lib/python3.5/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# [100]	train-gamma-nloglik:5.23052	val-gamma-nloglik:5.01076	train-sMAPE:0.537798	val-sMAPE:0.456176
# [200]	train-gamma-nloglik:4.89035	val-gamma-nloglik:4.87621	train-sMAPE:0.194686	val-sMAPE:0.178501
# Stopping. Best iteration:
# [187]	train-gamma-nloglik:4.89456	val-gamma-nloglik:4.8753	train-sMAPE:0.209395	val-sMAPE:0.172901
#   3%|▎         | 1/34 [00:11<06:14, 11.36s/it]
# (528, 12053)
# (48, 12053)
# [0]	train-gamma-nloglik:123.524	val-gamma-nloglik:97.171	train-sMAPE:1.93172	val-sMAPE:1.95702
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.20447	val-gamma-nloglik:5.11719	train-sMAPE:0.516246	val-sMAPE:0.505586
# [200]	train-gamma-nloglik:4.85681	val-gamma-nloglik:4.94649	train-sMAPE:0.1892	val-sMAPE:0.190862
# Stopping. Best iteration:
# [154]	train-gamma-nloglik:4.88132	val-gamma-nloglik:4.94617	train-sMAPE:0.254562	val-sMAPE:0.18524
#   6%|▌         | 2/34 [00:21<05:37, 10.54s/it]
# (528, 12053)
# (48, 12053)
# [0]	train-gamma-nloglik:115.356	val-gamma-nloglik:65.0763	train-sMAPE:1.91866	val-sMAPE:1.93605
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.06172	val-gamma-nloglik:4.54289	train-sMAPE:0.526216	val-sMAPE:0.221197
# Stopping. Best iteration:
# [111]	train-gamma-nloglik:4.90606	val-gamma-nloglik:4.53812	train-sMAPE:0.428971	val-sMAPE:0.197277
#   9%|▉         | 3/34 [00:29<05:00,  9.68s/it]
# (528, 12053)
# (48, 12053)
# [0]	train-gamma-nloglik:118.522	val-gamma-nloglik:81.3514	train-sMAPE:1.93216	val-sMAPE:1.94317
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.16343	val-gamma-nloglik:5.0464	train-sMAPE:0.52808	val-sMAPE:0.585937
# Stopping. Best iteration:
# [127]	train-gamma-nloglik:4.91699	val-gamma-nloglik:4.91704	train-sMAPE:0.335136	val-sMAPE:0.538552
#  12%|█▏        | 4/34 [00:37<04:42,  9.41s/it]
# (528, 12053)
# (48, 12053)
# [0]	train-gamma-nloglik:115.257	val-gamma-nloglik:54.6622	train-sMAPE:1.9015	val-sMAPE:1.91197
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.06198	val-gamma-nloglik:4.33408	train-sMAPE:0.607412	val-sMAPE:0.314297
# Stopping. Best iteration:
# [100]	train-gamma-nloglik:5.06198	val-gamma-nloglik:4.33408	train-sMAPE:0.607412	val-sMAPE:0.314297
#  15%|█▍        | 5/34 [00:45<04:21,  9.03s/it]
# (528, 12053)
# (48, 12053)
# [0]	train-gamma-nloglik:110.318	val-gamma-nloglik:74.4963	train-sMAPE:1.90388	val-sMAPE:1.93682
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.

# %% [markdown]
# # PM10

# %%
for i in tqdm(range(34)):
    trainX = np.concatenate((train_data[:,2*i:2*(i+1)],train_data[:,68:12093],train_data[:,12093+12*i:12093+12*(i+1)],train_data[:,-117:-102]),axis = 1)
    valX = np.concatenate((val_data[:,2*i:2*(i+1)],val_data[:,68:12093],val_data[:,12093+12*i:12093+12*(i+1)],val_data[:,-117:-102]),axis = 1)
    trainY = train_data[:, -102+3*i+1]
    valY = val_data[:, -102+3*i+1]
#     trainY = beijing_train[:, -105+3*i]
#     valY = beijing_test[:, -105+3*i]
    print(trainX.shape)
    print(valX.shape)

    params={
    'booster':'gbtree',
    'objective': 'reg:gamma', #多分类的问题
    # 'num_class':2, # 类别数，与 multisoftmax 并用
    'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':2, # 构建树的深度，越大越容易过拟合
    'lambda':100,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':0.9, # 随机采样训练样本
    'colsample_bytree':0.1, # 生成树时进行的列采样
    'min_child_weight':1, 
    # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
    #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
    #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
    'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
    'eta': 0.05, # 如同学习率
    'seed':1000,
    'nthread':-1,# cpu 线程数
#     'eval_metric':['mae','rmse']
    }

    plst = list(params.items())
    num_rounds = 600 # 迭代次数
    xgb_train = xgb.DMatrix(trainX, label= trainY)
    xgb_val = xgb.DMatrix(valX, label= valY)
    watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
    #训练模型并保存
    # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
    model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=100,feval=sMAPE)
    plt.plot(model_PM10.predict(xgb.DMatrix(valX)),'g')
    plt.plot(valY,'r')
    plt.show()
    model_PM10.save_model('/home/lifuzhen/KDD2018/Mini_train/bj_mean_std/'+ str(i) +'_PM10.model') # 用于存储训练出的模型
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
# (528, 12054)
# (48, 12054)
# [0]	train-gamma-nloglik:221.077	val-gamma-nloglik:166.896	train-sMAPE:1.96463	val-sMAPE:1.97453
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:6.3571	val-gamma-nloglik:5.75954	train-sMAPE:0.771365	val-sMAPE:0.601908
# [200]	train-gamma-nloglik:5.53423	val-gamma-nloglik:5.4713	train-sMAPE:0.235705	val-sMAPE:0.197947
# [300]	train-gamma-nloglik:5.50992	val-gamma-nloglik:5.47173	train-sMAPE:0.175932	val-sMAPE:0.190117
# Stopping. Best iteration:
# [325]	train-gamma-nloglik:5.50649	val-gamma-nloglik:5.47132	train-sMAPE:0.166237	val-sMAPE:0.187786
#   3%|▎         | 1/34 [00:14<07:59, 14.52s/it]
# (528, 12054)
# (48, 12054)
# [0]	train-gamma-nloglik:304.586	val-gamma-nloglik:238.557	train-sMAPE:1.9725	val-sMAPE:1.98236
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:7.06306	val-gamma-nloglik:6.39971	train-sMAPE:0.842709	val-sMAPE:0.816401
# [200]	train-gamma-nloglik:5.837	val-gamma-nloglik:5.83634	train-sMAPE:0.265862	val-sMAPE:0.189346
# Stopping. Best iteration:
# [177]	train-gamma-nloglik:5.85664	val-gamma-nloglik:5.8367	train-sMAPE:0.286623	val-sMAPE:0.187721
#   6%|▌         | 2/34 [00:23<06:20, 11.88s/it]
# (528, 12054)
# (48, 12054)
# [0]	train-gamma-nloglik:292.379	val-gamma-nloglik:215.675	train-sMAPE:1.97121	val-sMAPE:1.98124
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:6.95116	val-gamma-nloglik:6.17696	train-sMAPE:0.879316	val-sMAPE:0.761688
# [200]	train-gamma-nloglik:5.80339	val-gamma-nloglik:5.73775	train-sMAPE:0.22657	val-sMAPE:0.135948
# Stopping. Best iteration:
# [205]	train-gamma-nloglik:5.80165	val-gamma-nloglik:5.73707	train-sMAPE:0.222383	val-sMAPE:0.132715
#   9%|▉         | 3/34 [00:34<05:55, 11.47s/it]
# (528, 12054)
# (48, 12054)
# [0]	train-gamma-nloglik:287.583	val-gamma-nloglik:225.041	train-sMAPE:1.97349	val-sMAPE:1.98137
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:6.91916	val-gamma-nloglik:6.29413	train-sMAPE:0.859674	val-sMAPE:0.784591
# [200]	train-gamma-nloglik:5.80863	val-gamma-nloglik:5.79511	train-sMAPE:0.204704	val-sMAPE:0.2382
# Stopping. Best iteration:
# [191]	train-gamma-nloglik:5.81312	val-gamma-nloglik:5.79362	train-sMAPE:0.214744	val-sMAPE:0.235174
#  12%|█▏        | 4/34 [00:44<05:31, 11.06s/it]
# (528, 12054)
# (48, 12054)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-ad3c40c614d4> in <module>()
#      32     plst = list(params.items())
#      33     num_rounds = 600 # 迭代次数
# ---> 34     xgb_train = xgb.DMatrix(trainX, label= trainY)
#      35     xgb_val = xgb.DMatrix(valX, label= valY)
#      36     watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
#
# ~/virtual_pytorch_py3.5/lib/python3.5/site-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     278             self._init_from_csc(data)
#     279         elif isinstance(data, np.ndarray):
# --> 280             self._init_from_npy2d(data, missing, nthread)
#     281         else:
#     282             try:
#
# ~/virtual_pytorch_py3.5/lib/python3.5/site-packages/xgboost/core.py in _init_from_npy2d(self, mat, missing, nthread)
#     346         # we try to avoid data copies if possible (reshape returns a view when possible
#     347         # and we explicitly tell np.array to try and avoid copying)
# --> 348         data = np.array(mat.reshape(mat.size), copy=False, dtype=np.float32)
#     349         self.handle = ctypes.c_void_p()
#     350         missing = missing if missing is not None else np.nan
#
# KeyboardInterrupt:

# %% [markdown]
# # O3 小维度

# %%
for i in tqdm(range(34)):
    trainX = np.concatenate((train_data[:,68+6*i+4:68+6*i+5],train_data[:,-115:-114],train_data[:,-110:-109],train_data[:,-104:-103]),axis = 1)
    valX = np.concatenate((val_data[:,68+6*i+4:68+6*i+5],val_data[:,-115:-114],val_data[:,-110:-109],val_data[:,-104:-103]),axis = 1)
    trainY = train_data[:, -102+3*i+2]
    valY = val_data[:, -102+3*i+2]
#     trainY = beijing_train[:, -105+3*i]
#     valY = beijing_test[:, -105+3*i]
    print(trainX.shape)
    print(valX.shape)
    print(min(valY))
    
    params={
    'booster':'gbtree',
    'objective': 'reg:gamma', #多分类的问题
    # 'num_class':2, # 类别数，与 multisoftmax 并用
    'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':2, # 构建树的深度，越大越容易过拟合
    'lambda':1,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':0.8, # 随机采样训练样本
    'colsample_bytree':1, # 生成树时进行的列采样
    'min_child_weight':1, 
    # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
    #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
    #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
    'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
    'eta': 0.1, # 如同学习率
    'seed':1000,
    'nthread':-1,# cpu 线程数
#     'eval_metric':['mae','rmse']
    }

    plst = list(params.items())
    num_rounds = 600 # 迭代次数
    xgb_train = xgb.DMatrix(trainX, label= trainY)
    xgb_val = xgb.DMatrix(valX, label= valY)
    watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
    #训练模型并保存
    # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
    model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=100,feval=sMAPE)
    plt.plot(model_PM10.predict(xgb.DMatrix(valX)),'g')
    plt.plot(valY,'r')
    plt.show()
    model_PM10.save_model('/home/lifuzhen/KDD2018/Mini_train/bj_mean_std/'+ str(i) +'_O3.model') # 用于存储训练出的模型
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:154.215	val-gamma-nloglik:167.579	train-sMAPE:1.87851	val-sMAPE:1.81557
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.22264	val-gamma-nloglik:5.10352	train-sMAPE:0.484861	val-sMAPE:0.56699
# Stopping. Best iteration:
# [105]	train-gamma-nloglik:5.21855	val-gamma-nloglik:5.08911	train-sMAPE:0.479859	val-sMAPE:0.557938
#   3%|▎         | 1/34 [00:00<00:21,  1.50it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:135.354	val-gamma-nloglik:168.77	train-sMAPE:1.88759	val-sMAPE:1.8938
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.00043	val-gamma-nloglik:5.4128	train-sMAPE:0.459383	val-sMAPE:0.484589
# [200]	train-gamma-nloglik:4.94831	val-gamma-nloglik:5.42481	train-sMAPE:0.38548	val-sMAPE:0.479214
# Stopping. Best iteration:
# [165]	train-gamma-nloglik:4.96259	val-gamma-nloglik:5.40591	train-sMAPE:0.404388	val-sMAPE:0.466412
#   6%|▌         | 2/34 [00:01<00:23,  1.39it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:132.131	val-gamma-nloglik:153.273	train-sMAPE:1.82363	val-sMAPE:1.87408
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.887	val-gamma-nloglik:5.08182	train-sMAPE:0.505245	val-sMAPE:0.432782
# [200]	train-gamma-nloglik:4.83052	val-gamma-nloglik:5.15179	train-sMAPE:0.434733	val-sMAPE:0.442126
# Stopping. Best iteration:
# [167]	train-gamma-nloglik:4.84497	val-gamma-nloglik:5.12657	train-sMAPE:0.45275	val-sMAPE:0.423472
#   9%|▉         | 3/34 [00:02<00:22,  1.38it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:159.416	val-gamma-nloglik:172.479	train-sMAPE:1.8957	val-sMAPE:1.89092
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.25973	val-gamma-nloglik:5.24373	train-sMAPE:0.460345	val-sMAPE:0.383503
# [200]	train-gamma-nloglik:5.20289	val-gamma-nloglik:5.29656	train-sMAPE:0.40024	val-sMAPE:0.350904
# Stopping. Best iteration:
# [184]	train-gamma-nloglik:5.2097	val-gamma-nloglik:5.27312	train-sMAPE:0.407982	val-sMAPE:0.341623
#  12%|█▏        | 4/34 [00:02<00:22,  1.35it/s]
# (528, 4)
# (48, 4)
# 18.0
# [0]	train-gamma-nloglik:163.422	val-gamma-nloglik:201.202	train-sMAPE:1.9695	val-sMAPE:1.97452
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.4441	val-gamma-nloglik:5.65677	train-sMAPE:0.2503	val-sMAPE:0.249837
# [200]	train-gamma-nloglik:5.43211	val-gamma-nloglik:5.6542	train-sMAPE:0.218185	val-sMAPE:0.238598
# Stopping. Best iteration:
# [168]	train-gamma-nloglik:5.43468	val-gamma-nloglik:5.65204	train-sMAPE:0.22577	val-sMAPE:0.234564
#  15%|█▍        | 5/34 [00:03<00:21,  1.36it/s]
# (528, 4)
# (48, 4)
# 27.0
# [0]	train-gamma-nloglik:200.938	val-gamma-nloglik:217.363	train-sMAPE:1.97566	val-sMAPE:1.97762
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.65395	val-gamma-nloglik:5.75119	train-sMAPE:0.246278	val-sMAPE:0.229562
# Stopping. Best iteration:
# [144]	train-gamma-nloglik:5.64645	val-gamma-nloglik:5.74913	train-sMAPE:0.223333	val-sMAPE:0.218376
#  18%|█▊        | 6/34 [00:04<00:20,  1.38it/s]
# (528, 4)
# (48, 4)
# 3.0
# [0]	train-gamma-nloglik:163.65	val-gamma-nloglik:175.231	train-sMAPE:1.92374	val-sMAPE:1.93097
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.34485	val-gamma-nloglik:5.33304	train-sMAPE:0.382266	val-sMAPE:0.33409
# Stopping. Best iteration:
# [115]	train-gamma-nloglik:5.33766	val-gamma-nloglik:5.33382	train-sMAPE:0.374523	val-sMAPE:0.318874
#  21%|██        | 7/34 [00:04<00:18,  1.42it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:110.56	val-gamma-nloglik:118.174	train-sMAPE:1.78626	val-sMAPE:1.68017
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.63108	val-gamma-nloglik:4.40565	train-sMAPE:0.534795	val-sMAPE:0.519679
# [200]	train-gamma-nloglik:4.56706	val-gamma-nloglik:4.35284	train-sMAPE:0.460947	val-sMAPE:0.443944
# Stopping. Best iteration:
# [236]	train-gamma-nloglik:4.55264	val-gamma-nloglik:4.34067	train-sMAPE:0.442712	val-sMAPE:0.43238
#  24%|██▎       | 8/34 [00:05<00:18,  1.37it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:165.618	val-gamma-nloglik:196.298	train-sMAPE:1.91195	val-sMAPE:1.93415
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.28782	val-gamma-nloglik:5.62228	train-sMAPE:0.406711	val-sMAPE:0.382292
# [200]	train-gamma-nloglik:5.243	val-gamma-nloglik:5.682	train-sMAPE:0.346227	val-sMAPE:0.369544
# Stopping. Best iteration:
# [161]	train-gamma-nloglik:5.25482	val-gamma-nloglik:5.63674	train-sMAPE:0.363528	val-sMAPE:0.35422
#  26%|██▋       | 9/34 [00:06<00:18,  1.37it/s]
# (528, 4)
# (48, 4)
# 4.0
# [0]	train-gamma-nloglik:152.16	val-gamma-nloglik:178.935	train-sMAPE:1.8886	val-sMAPE:1.9523
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.21232	val-gamma-nloglik:5.5836	train-sMAPE:0.459796	val-sMAPE:0.387885
# Stopping. Best iteration:
# [113]	train-gamma-nloglik:5.20371	val-gamma-nloglik:5.58496	train-sMAPE:0.449157	val-sMAPE:0.384253
# Exception in thread Thread-368:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/home/lifuzhen/virtual_pytorch_py3.5/lib/python3.5/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/lifuzhen/virtual_pytorch_py3.5/lib/python3.5/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
#  29%|██▉       | 10/34 [00:07<00:17,  1.40it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:168.942	val-gamma-nloglik:184.244	train-sMAPE:1.92236	val-sMAPE:1.93206
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.36033	val-gamma-nloglik:5.52463	train-sMAPE:0.391821	val-sMAPE:0.381544
# [200]	train-gamma-nloglik:5.31814	val-gamma-nloglik:5.56801	train-sMAPE:0.337209	val-sMAPE:0.351586
# Stopping. Best iteration:
# [191]	train-gamma-nloglik:5.32084	val-gamma-nloglik:5.5619	train-sMAPE:0.341441	val-sMAPE:0.349462
#  32%|███▏      | 11/34 [00:07<00:16,  1.38it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:155.024	val-gamma-nloglik:157.468	train-sMAPE:1.88901	val-sMAPE:1.82671
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.24795	val-gamma-nloglik:5.05235	train-sMAPE:0.447104	val-sMAPE:0.497607
# [200]	train-gamma-nloglik:5.20172	val-gamma-nloglik:5.02379	train-sMAPE:0.397986	val-sMAPE:0.462713
# Stopping. Best iteration:
# [233]	train-gamma-nloglik:5.19106	val-gamma-nloglik:5.01729	train-sMAPE:0.388134	val-sMAPE:0.460019
#  35%|███▌      | 12/34 [00:08<00:16,  1.35it/s]
# (528, 4)
# (48, 4)
# 29.0
# [0]	train-gamma-nloglik:180.643	val-gamma-nloglik:176.221	train-sMAPE:1.97175	val-sMAPE:1.97153
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.53577	val-gamma-nloglik:5.50569	train-sMAPE:0.253592	val-sMAPE:0.20854
# Stopping. Best iteration:
# [93]	train-gamma-nloglik:5.53769	val-gamma-nloglik:5.50455	train-sMAPE:0.258406	val-sMAPE:0.205016
#  38%|███▊      | 13/34 [00:09<00:15,  1.38it/s]
# (528, 4)
# (48, 4)
# 15.0
# [0]	train-gamma-nloglik:143.972	val-gamma-nloglik:188.524	train-sMAPE:1.91215	val-sMAPE:1.96359
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.1604	val-gamma-nloglik:5.54153	train-sMAPE:0.407389	val-sMAPE:0.340354
# [200]	train-gamma-nloglik:5.11343	val-gamma-nloglik:5.57291	train-sMAPE:0.354997	val-sMAPE:0.327137
# Stopping. Best iteration:
# [172]	train-gamma-nloglik:5.12314	val-gamma-nloglik:5.559	train-sMAPE:0.367568	val-sMAPE:0.319957
#  41%|████      | 14/34 [00:10<00:14,  1.35it/s]
# (528, 4)
# (48, 4)
# 20.0
# [0]	train-gamma-nloglik:171.634	val-gamma-nloglik:194.993	train-sMAPE:1.96409	val-sMAPE:1.96998
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.4657	val-gamma-nloglik:5.59127	train-sMAPE:0.299012	val-sMAPE:0.341834
# [200]	train-gamma-nloglik:5.44757	val-gamma-nloglik:5.5785	train-sMAPE:0.257821	val-sMAPE:0.291256
# Stopping. Best iteration:
# [199]	train-gamma-nloglik:5.44767	val-gamma-nloglik:5.57809	train-sMAPE:0.25834	val-sMAPE:0.290404
#  44%|████▍     | 15/34 [00:11<00:14,  1.33it/s]
# (528, 4)
# (48, 4)
# 29.0
# [0]	train-gamma-nloglik:182.748	val-gamma-nloglik:193.439	train-sMAPE:1.94068	val-sMAPE:1.97044
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.48097	val-gamma-nloglik:5.57467	train-sMAPE:0.420622	val-sMAPE:0.276905
# Stopping. Best iteration:
# [139]	train-gamma-nloglik:5.46159	val-gamma-nloglik:5.58307	train-sMAPE:0.39605	val-sMAPE:0.272202
#  47%|████▋     | 16/34 [00:11<00:13,  1.34it/s]
# (528, 4)
# (48, 4)
# 59.0
# [0]	train-gamma-nloglik:217.118	val-gamma-nloglik:242.268	train-sMAPE:1.97809	val-sMAPE:1.98107
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.73526	val-gamma-nloglik:5.84759	train-sMAPE:0.220747	val-sMAPE:0.167475
# [200]	train-gamma-nloglik:5.72563	val-gamma-nloglik:5.84599	train-sMAPE:0.186977	val-sMAPE:0.152689
# Stopping. Best iteration:
# [188]	train-gamma-nloglik:5.72628	val-gamma-nloglik:5.84569	train-sMAPE:0.189325	val-sMAPE:0.151199
#  50%|█████     | 17/34 [00:12<00:12,  1.33it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:98.9195	val-gamma-nloglik:108.237	train-sMAPE:1.86181	val-sMAPE:1.81469
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.78881	val-gamma-nloglik:4.63909	train-sMAPE:0.461857	val-sMAPE:0.469225
# [200]	train-gamma-nloglik:4.74246	val-gamma-nloglik:4.60618	train-sMAPE:0.405703	val-sMAPE:0.421587
# [300]	train-gamma-nloglik:4.71719	val-gamma-nloglik:4.59575	train-sMAPE:0.370363	val-sMAPE:0.409872
# [400]	train-gamma-nloglik:4.6985	val-gamma-nloglik:4.58774	train-sMAPE:0.343969	val-sMAPE:0.388455
# Stopping. Best iteration:
# [435]	train-gamma-nloglik:4.69341	val-gamma-nloglik:4.58131	train-sMAPE:0.336241	val-sMAPE:0.369703
#  53%|█████▎    | 18/34 [00:14<00:12,  1.27it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:140.734	val-gamma-nloglik:157.157	train-sMAPE:1.87334	val-sMAPE:1.85143
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.1235	val-gamma-nloglik:5.07604	train-sMAPE:0.458377	val-sMAPE:0.413096
# Stopping. Best iteration:
# [105]	train-gamma-nloglik:5.12145	val-gamma-nloglik:5.07025	train-sMAPE:0.457415	val-sMAPE:0.40133
#  56%|█████▌    | 19/34 [00:14<00:11,  1.28it/s]
# (528, 4)
# (48, 4)
# 12.0
# [0]	train-gamma-nloglik:166.895	val-gamma-nloglik:192.844	train-sMAPE:1.9539	val-sMAPE:1.97002
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.41124	val-gamma-nloglik:5.57133	train-sMAPE:0.319744	val-sMAPE:0.268841
# [200]	train-gamma-nloglik:5.38861	val-gamma-nloglik:5.57418	train-sMAPE:0.28007	val-sMAPE:0.263861
# Stopping. Best iteration:
# [167]	train-gamma-nloglik:5.3947	val-gamma-nloglik:5.57119	train-sMAPE:0.290374	val-sMAPE:0.257446
#  59%|█████▉    | 20/34 [00:15<00:10,  1.29it/s]
# (528, 4)
# (48, 4)
# 43.0
# [0]	train-gamma-nloglik:195.662	val-gamma-nloglik:234.754	train-sMAPE:1.9701	val-sMAPE:1.9794
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.60044	val-gamma-nloglik:5.82264	train-sMAPE:0.290164	val-sMAPE:0.246784
# Stopping. Best iteration:
# [130]	train-gamma-nloglik:5.59236	val-gamma-nloglik:5.8159	train-sMAPE:0.271061	val-sMAPE:0.237376
#  62%|██████▏   | 21/34 [00:16<00:10,  1.28it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:139.608	val-gamma-nloglik:152.461	train-sMAPE:1.90016	val-sMAPE:1.91707
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.14551	val-gamma-nloglik:5.0897	train-sMAPE:0.426579	val-sMAPE:0.282381
# Stopping. Best iteration:
# [113]	train-gamma-nloglik:5.13821	val-gamma-nloglik:5.08623	train-sMAPE:0.417642	val-sMAPE:0.278514
#  65%|██████▍   | 22/34 [00:17<00:09,  1.29it/s]
# (528, 4)
# (48, 4)
# 18.0
# [0]	train-gamma-nloglik:171.478	val-gamma-nloglik:180.772	train-sMAPE:1.93178	val-sMAPE:1.96379
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.42779	val-gamma-nloglik:5.45698	train-sMAPE:0.393019	val-sMAPE:0.303198
# Stopping. Best iteration:
# [114]	train-gamma-nloglik:5.4211	val-gamma-nloglik:5.45398	train-sMAPE:0.382297	val-sMAPE:0.294701
#  68%|██████▊   | 23/34 [00:17<00:08,  1.30it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:139.72	val-gamma-nloglik:142.087	train-sMAPE:1.89268	val-sMAPE:1.8884
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.1186	val-gamma-nloglik:4.96007	train-sMAPE:0.446168	val-sMAPE:0.317439
# Stopping. Best iteration:
# [124]	train-gamma-nloglik:5.10718	val-gamma-nloglik:4.95248	train-sMAPE:0.430162	val-sMAPE:0.307858
#  71%|███████   | 24/34 [00:18<00:07,  1.31it/s]
# (528, 4)
# (48, 4)
# 4.0
# [0]	train-gamma-nloglik:157.545	val-gamma-nloglik:153.639	train-sMAPE:1.9045	val-sMAPE:1.91054
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.24706	val-gamma-nloglik:5.03291	train-sMAPE:0.442213	val-sMAPE:0.33245
# [200]	train-gamma-nloglik:5.19855	val-gamma-nloglik:5.02895	train-sMAPE:0.380522	val-sMAPE:0.316263
# Stopping. Best iteration:
# [227]	train-gamma-nloglik:5.19065	val-gamma-nloglik:5.02492	train-sMAPE:0.369784	val-sMAPE:0.30603
#  74%|███████▎  | 25/34 [00:19<00:06,  1.30it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:151.045	val-gamma-nloglik:163.386	train-sMAPE:1.87949	val-sMAPE:1.92004
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.15616	val-gamma-nloglik:5.23467	train-sMAPE:0.452569	val-sMAPE:0.427675
# Stopping. Best iteration:
# [104]	train-gamma-nloglik:5.15276	val-gamma-nloglik:5.2375	train-sMAPE:0.448419	val-sMAPE:0.42631
#  76%|███████▋  | 26/34 [00:19<00:06,  1.31it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:147.868	val-gamma-nloglik:152.003	train-sMAPE:1.91385	val-sMAPE:1.88514
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.23185	val-gamma-nloglik:5.02546	train-sMAPE:0.384845	val-sMAPE:0.358961
# [200]	train-gamma-nloglik:5.19674	val-gamma-nloglik:5.00941	train-sMAPE:0.345789	val-sMAPE:0.336801
# Stopping. Best iteration:
# [158]	train-gamma-nloglik:5.20745	val-gamma-nloglik:5.00846	train-sMAPE:0.358959	val-sMAPE:0.332192
#  79%|███████▉  | 27/34 [00:20<00:05,  1.31it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:124.702	val-gamma-nloglik:134.664	train-sMAPE:1.88218	val-sMAPE:1.87019
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.02237	val-gamma-nloglik:5.01216	train-sMAPE:0.442274	val-sMAPE:0.476322
# Stopping. Best iteration:
# [126]	train-gamma-nloglik:5.00474	val-gamma-nloglik:5.01739	train-sMAPE:0.426045	val-sMAPE:0.472209
#  82%|████████▏ | 28/34 [00:21<00:04,  1.33it/s]
# (528, 4)
# (48, 4)
# 33.0
# [0]	train-gamma-nloglik:155.303	val-gamma-nloglik:224.162	train-sMAPE:1.89608	val-sMAPE:1.97898
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.27834	val-gamma-nloglik:6.39475	train-sMAPE:0.433243	val-sMAPE:0.476102
# Stopping. Best iteration:
# [111]	train-gamma-nloglik:5.27146	val-gamma-nloglik:6.43962	train-sMAPE:0.424123	val-sMAPE:0.469261
#  85%|████████▌ | 29/34 [00:21<00:03,  1.34it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:154.947	val-gamma-nloglik:181.197	train-sMAPE:1.90244	val-sMAPE:1.91332
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.24392	val-gamma-nloglik:5.55246	train-sMAPE:0.401052	val-sMAPE:0.409141
# Stopping. Best iteration:
# [110]	train-gamma-nloglik:5.23777	val-gamma-nloglik:5.56266	train-sMAPE:0.395939	val-sMAPE:0.40238
#  88%|████████▊ | 30/34 [00:22<00:02,  1.35it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:153.313	val-gamma-nloglik:126.121	train-sMAPE:1.87319	val-sMAPE:1.78504
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.18492	val-gamma-nloglik:4.75619	train-sMAPE:0.483555	val-sMAPE:0.539143
# [200]	train-gamma-nloglik:5.12782	val-gamma-nloglik:4.72277	train-sMAPE:0.425522	val-sMAPE:0.504528
# [300]	train-gamma-nloglik:5.09678	val-gamma-nloglik:4.71529	train-sMAPE:0.387023	val-sMAPE:0.486023
# Stopping. Best iteration:
# [326]	train-gamma-nloglik:5.09064	val-gamma-nloglik:4.70576	train-sMAPE:0.378972	val-sMAPE:0.471482
#  91%|█████████ | 31/34 [00:23<00:02,  1.33it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:165.733	val-gamma-nloglik:161.481	train-sMAPE:1.86609	val-sMAPE:1.84585
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.23571	val-gamma-nloglik:5.09548	train-sMAPE:0.501677	val-sMAPE:0.4458
# Stopping. Best iteration:
# [94]	train-gamma-nloglik:5.24352	val-gamma-nloglik:5.09148	train-sMAPE:0.509581	val-sMAPE:0.436304
#  94%|█████████▍| 32/34 [00:23<00:01,  1.34it/s]
# (528, 4)
# (48, 4)
# 2.0
# [0]	train-gamma-nloglik:162.62	val-gamma-nloglik:187.718	train-sMAPE:1.93327	val-sMAPE:1.91331
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.3423	val-gamma-nloglik:5.59482	train-sMAPE:0.354954	val-sMAPE:0.412999
# Stopping. Best iteration:
# [141]	train-gamma-nloglik:5.32241	val-gamma-nloglik:5.62789	train-sMAPE:0.326533	val-sMAPE:0.382016
#  97%|█████████▋| 33/34 [00:24<00:00,  1.34it/s]
# (528, 4)
# (48, 4)
# 12.0
# [0]	train-gamma-nloglik:181.288	val-gamma-nloglik:195.741	train-sMAPE:1.96442	val-sMAPE:1.96104
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.50003	val-gamma-nloglik:5.51734	train-sMAPE:0.293543	val-sMAPE:0.294106
# [200]	train-gamma-nloglik:5.47593	val-gamma-nloglik:5.48446	train-sMAPE:0.245494	val-sMAPE:0.23115
# Stopping. Best iteration:
# [191]	train-gamma-nloglik:5.47792	val-gamma-nloglik:5.48601	train-sMAPE:0.248929	val-sMAPE:0.229667
# 100%|██████████| 34/34 [00:25<00:00,  1.34it/s]

# %% [markdown]
# # O3大维度

# %%
# for i in tqdm(range(34)):
#     trainX = np.concatenate((train_data[:,2*i:2*(i+1)],train_data[:,68:12093],train_data[:,12093+12*i:12093+12*(i+1)],train_data[:,-117:-116],train_data[:,-115:-102]),axis = 1)
#     valX = np.concatenate((val_data[:,2*i:2*(i+1)],val_data[:,68:12093],val_data[:,12093+12*i:12093+12*(i+1)],val_data[:,-117:-116],val_data[:,-115:-102]),axis = 1)
#     trainY = train_data[:, -102+3*i+2]
#     valY = val_data[:, -102+3*i+2]
# #     trainY = beijing_train[:, -105+3*i]
# #     valY = beijing_test[:, -105+3*i]
#     print(trainX.shape)
#     print(valX.shape)
#     print(min(valY))
    
#     params={
#     'booster':'gbtree',
#     'objective': 'reg:gamma', #多分类的问题
#     # 'num_class':2, # 类别数，与 multisoftmax 并用
#     'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
#     'max_depth':2, # 构建树的深度，越大越容易过拟合
#     'lambda':1,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
#     'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
#     'subsample':0.8, # 随机采样训练样本
#     'colsample_bytree':1, # 生成树时进行的列采样
#     'min_child_weight':1, 
#     # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
#     #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
#     #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
#     'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
#     'eta': 0.05, # 如同学习率
#     'seed':1000,
#     'nthread':-1,# cpu 线程数
# #     'eval_metric':['mae','rmse']
#     }

#     plst = list(params.items())
#     num_rounds = 600 # 迭代次数
#     xgb_train = xgb.DMatrix(trainX, label= trainY)
#     xgb_val = xgb.DMatrix(valX, label= valY)
#     watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
#     #训练模型并保存
#     # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
#     model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=100,feval=sMAPE)
#     plt.plot(model_PM10.predict(xgb.DMatrix(valX)),'g')
#     plt.plot(valY,'r')
#     plt.show()
#     model_PM10.save_model('/home/lifuzhen/KDD2018/Mini_train/beijing/'+ str(i) +'_O3.model') # 用于存储训练出的模型
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
# (528, 12329)
# (48, 12329)
# 2.0
# [0]	train-gamma-nloglik:162.065	val-gamma-nloglik:176.112	train-sMAPE:1.88353	val-sMAPE:1.82294
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.71369	val-gamma-nloglik:6.13154	train-sMAPE:0.82028	val-sMAPE:1.10504
# Exception in thread Thread-364:
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/threading.py", line 914, in _bootstrap_inner
#     self.run()
#   File "/home/lifuzhen/virtual_pytorch_py3.5/lib/python3.5/site-packages/tqdm/_tqdm.py", line 144, in run
#     for instance in self.tqdm_cls._instances:
#   File "/home/lifuzhen/virtual_pytorch_py3.5/lib/python3.5/_weakrefset.py", line 60, in __iter__
#     for itemref in self.data:
# RuntimeError: Set changed size during iteration
# [200]	train-gamma-nloglik:5.04652	val-gamma-nloglik:5.29275	train-sMAPE:0.239828	val-sMAPE:0.744212
# [300]	train-gamma-nloglik:5.00669	val-gamma-nloglik:5.25665	train-sMAPE:0.144661	val-sMAPE:0.716031
# [400]	train-gamma-nloglik:4.99102	val-gamma-nloglik:5.24288	train-sMAPE:0.096942	val-sMAPE:0.706811
# Stopping. Best iteration:
# [444]	train-gamma-nloglik:4.98702	val-gamma-nloglik:5.24139	train-sMAPE:0.083588	val-sMAPE:0.704989
#   3%|▎         | 1/34 [00:25<13:53, 25.27s/it]
# (528, 12329)
# (48, 12329)
# 2.0
# [0]	train-gamma-nloglik:142.235	val-gamma-nloglik:177.35	train-sMAPE:1.89234	val-sMAPE:1.89804
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.44687	val-gamma-nloglik:6.25054	train-sMAPE:0.71935	val-sMAPE:1.01396
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-331-4c66dd8853e5> in <module>()
#      38     #训练模型并保存
#      39     # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
# ---> 40     model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=100,feval=sMAPE)
#      41     plt.plot(model_PM10.predict(xgb.DMatrix(valX)),'g')
#      42     plt.plot(valY,'r')
#
# ~/virtual_pytorch_py3.5/lib/python3.5/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     202                            evals=evals,
#     203                            obj=obj, feval=feval,
# --> 204                            xgb_model=xgb_model, callbacks=callbacks)
#     205
#     206
#
# ~/virtual_pytorch_py3.5/lib/python3.5/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      72         # Skip the first update if it is a recovery step.
#      73         if version % 2 == 0:
# ---> 74             bst.update(dtrain, i, obj)
#      75             bst.save_rabit_checkpoint()
#      76             version += 1
#
# ~/virtual_pytorch_py3.5/lib/python3.5/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#     896         if fobj is None:
#     897             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle, ctypes.c_int(iteration),
# --> 898                                                     dtrain.handle))
#     899         else:
#     900             pred = self.predict(dtrain)
#
# KeyboardInterrupt:

# %% [markdown]
# # London

# %%
import xgboost as xgb
from sklearn.cross_validation import train_test_split
train_data, val_data = train_test_split(London_train, test_size = 0.3, random_state = 1)
# train_data, val_data = London_train[:-48,:], London_train[-48:,:]###随机数原始为1

# %% [markdown]
# # PM2.5

# %%
for i in tqdm(range(13)):
    trainX = np.concatenate((train_data[:,2*i:2*(i+1)],train_data[:,26:2185],train_data[:,2185+6*i:2185+6*(i+1)],train_data[:,-34:-26]),axis = 1)
    valX = np.concatenate((val_data[:,2*i:2*(i+1)],val_data[:,26:2185],val_data[:,2185+6*i:2185+6*(i+1)],val_data[:,-34:-26]),axis = 1)
    trainY = train_data[:, -26+2*i]
    valY = val_data[:, -26+2*i]
    trainY[trainY <= 0] = 0.1
    valY[valY <= 0] = 0.1
#     trainY = London_train[:, -26+2*i]
#     valY = London_test[:, -26+2*i]
    print(trainX.shape)
    print(valX.shape)

    params={
    'booster':'gbtree',
    'objective': 'reg:gamma', #多分类的问题
    # 'num_class':2, # 类别数，与 multisoftmax 并用
    'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':2, # 构建树的深度，越大越容易过拟合
    'lambda':1000,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':0.9, # 随机采样训练样本
    'colsample_bytree':0.2, # 生成树时进行的列采样
    'min_child_weight':1, 
    # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
    #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
    #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
    'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
    'eta': 0.05, # 如同学习率
    'seed':1000,
    'nthread':-1,# cpu 线程数
#     'eval_metric':['mae','rmse']
    }

    plst = list(params.items())
    num_rounds = 600 # 迭代次数
    xgb_train = xgb.DMatrix(trainX, label= trainY)
    xgb_val = xgb.DMatrix(valX, label= valY)
    watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
    #训练模型并保存
    # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
    model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval = 100,feval=sMAPE)
    model_PM10.save_model('/home/lifuzhen/KDD2018/Mini_train/ld_mean_std/'+ str(i) +'_PM2.5.model') # 用于存储训练出的模型
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:21.1863	val-gamma-nloglik:19.0097	train-sMAPE:1.53299	val-sMAPE:1.50724
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:3.49592	val-gamma-nloglik:3.31454	train-sMAPE:0.63237	val-sMAPE:0.642012
# [200]	train-gamma-nloglik:3.10886	val-gamma-nloglik:3.00479	train-sMAPE:0.449232	val-sMAPE:0.47766
# [300]	train-gamma-nloglik:3.03231	val-gamma-nloglik:2.9499	train-sMAPE:0.394225	val-sMAPE:0.430804
# [400]	train-gamma-nloglik:2.99607	val-gamma-nloglik:2.92392	train-sMAPE:0.355681	val-sMAPE:0.398741
# [500]	train-gamma-nloglik:2.97344	val-gamma-nloglik:2.90737	train-sMAPE:0.323573	val-sMAPE:0.373014
# [599]	train-gamma-nloglik:2.95843	val-gamma-nloglik:2.8964	train-sMAPE:0.298819	val-sMAPE:0.355454
#   8%|▊         | 1/13 [00:06<01:14,  6.22s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:22.4329	val-gamma-nloglik:20.504	train-sMAPE:1.57429	val-sMAPE:1.59711
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:3.63339	val-gamma-nloglik:3.54251	train-sMAPE:0.690391	val-sMAPE:0.679337
# [200]	train-gamma-nloglik:3.17303	val-gamma-nloglik:3.16799	train-sMAPE:0.52235	val-sMAPE:0.513223
# [300]	train-gamma-nloglik:3.07995	val-gamma-nloglik:3.10023	train-sMAPE:0.444991	val-sMAPE:0.467687
# [400]	train-gamma-nloglik:3.04043	val-gamma-nloglik:3.07147	train-sMAPE:0.39497	val-sMAPE:0.432637
# [500]	train-gamma-nloglik:3.01725	val-gamma-nloglik:3.05574	train-sMAPE:0.360821	val-sMAPE:0.410577
# [599]	train-gamma-nloglik:3.00096	val-gamma-nloglik:3.04468	train-sMAPE:0.334411	val-sMAPE:0.396645
#  15%|█▌        | 2/13 [00:12<01:06,  6.02s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:24.9341	val-gamma-nloglik:23.5746	train-sMAPE:1.71494	val-sMAPE:1.71642
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:3.86055	val-gamma-nloglik:3.7953	train-sMAPE:0.588892	val-sMAPE:0.609032
# [200]	train-gamma-nloglik:3.42677	val-gamma-nloglik:3.42238	train-sMAPE:0.421313	val-sMAPE:0.436387
# [300]	train-gamma-nloglik:3.34836	val-gamma-nloglik:3.36443	train-sMAPE:0.363516	val-sMAPE:0.401847
# [400]	train-gamma-nloglik:3.31676	val-gamma-nloglik:3.3409	train-sMAPE:0.329379	val-sMAPE:0.377939
# [500]	train-gamma-nloglik:3.29696	val-gamma-nloglik:3.3248	train-sMAPE:0.298717	val-sMAPE:0.356447
# [599]	train-gamma-nloglik:3.28436	val-gamma-nloglik:3.31398	train-sMAPE:0.276631	val-sMAPE:0.337814
#  23%|██▎       | 3/13 [00:17<00:59,  5.95s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:31.541	val-gamma-nloglik:31.5184	train-sMAPE:1.82929	val-sMAPE:1.84428
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.19662	val-gamma-nloglik:4.21765	train-sMAPE:0.665756	val-sMAPE:0.646128
# [200]	train-gamma-nloglik:3.78435	val-gamma-nloglik:3.81816	train-sMAPE:0.387833	val-sMAPE:0.381072
# [300]	train-gamma-nloglik:3.73217	val-gamma-nloglik:3.77474	train-sMAPE:0.319594	val-sMAPE:0.324582
# [400]	train-gamma-nloglik:3.71189	val-gamma-nloglik:3.75989	train-sMAPE:0.279265	val-sMAPE:0.294739
# [500]	train-gamma-nloglik:3.70114	val-gamma-nloglik:3.75213	train-sMAPE:0.254105	val-sMAPE:0.275291
# [599]	train-gamma-nloglik:3.69471	val-gamma-nloglik:3.74762	train-sMAPE:0.236947	val-sMAPE:0.262633
#  31%|███       | 4/13 [00:23<00:53,  5.92s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:27.9331	val-gamma-nloglik:24.6361	train-sMAPE:1.73465	val-sMAPE:1.73035
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.00714	val-gamma-nloglik:3.80359	train-sMAPE:0.641617	val-sMAPE:0.655513
# [200]	train-gamma-nloglik:3.55932	val-gamma-nloglik:3.47013	train-sMAPE:0.46753	val-sMAPE:0.528483
# [300]	train-gamma-nloglik:3.4833	val-gamma-nloglik:3.42408	train-sMAPE:0.41019	val-sMAPE:0.496651
# [400]	train-gamma-nloglik:3.45232	val-gamma-nloglik:3.40618	train-sMAPE:0.37859	val-sMAPE:0.481638
# [500]	train-gamma-nloglik:3.43434	val-gamma-nloglik:3.39466	train-sMAPE:0.355437	val-sMAPE:0.46839
# [599]	train-gamma-nloglik:3.42228	val-gamma-nloglik:3.38599	train-sMAPE:0.337196	val-sMAPE:0.456197
#  38%|███▊      | 5/13 [00:29<00:47,  5.89s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:29.7355	val-gamma-nloglik:28.3409	train-sMAPE:1.77053	val-sMAPE:1.76728
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.09224	val-gamma-nloglik:4.02806	train-sMAPE:0.576592	val-sMAPE:0.577002
# [200]	train-gamma-nloglik:3.61597	val-gamma-nloglik:3.60696	train-sMAPE:0.418902	val-sMAPE:0.454689
# [300]	train-gamma-nloglik:3.53521	val-gamma-nloglik:3.54478	train-sMAPE:0.348881	val-sMAPE:0.410467
# [400]	train-gamma-nloglik:3.5029	val-gamma-nloglik:3.51922	train-sMAPE:0.307004	val-sMAPE:0.380861
# [500]	train-gamma-nloglik:3.48423	val-gamma-nloglik:3.50207	train-sMAPE:0.274793	val-sMAPE:0.355274
# [599]	train-gamma-nloglik:3.47202	val-gamma-nloglik:3.48954	train-sMAPE:0.251507	val-sMAPE:0.334827
#  46%|████▌     | 6/13 [00:35<00:41,  5.87s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:26.9574	val-gamma-nloglik:25.2619	train-sMAPE:1.68721	val-sMAPE:1.68818
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:3.92145	val-gamma-nloglik:3.84569	train-sMAPE:0.660297	val-sMAPE:0.673772
# [200]	train-gamma-nloglik:3.43798	val-gamma-nloglik:3.44585	train-sMAPE:0.501197	val-sMAPE:0.537512
# [300]	train-gamma-nloglik:3.34744	val-gamma-nloglik:3.38033	train-sMAPE:0.423985	val-sMAPE:0.484673
# [400]	train-gamma-nloglik:3.30967	val-gamma-nloglik:3.35288	train-sMAPE:0.376576	val-sMAPE:0.457257
# [500]	train-gamma-nloglik:3.28658	val-gamma-nloglik:3.33455	train-sMAPE:0.339732	val-sMAPE:0.433055
# [599]	train-gamma-nloglik:3.27147	val-gamma-nloglik:3.32177	train-sMAPE:0.312724	val-sMAPE:0.416097
#  54%|█████▍    | 7/13 [00:41<00:35,  5.86s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:33.8288	val-gamma-nloglik:32.1276	train-sMAPE:1.82176	val-sMAPE:1.81184
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.28229	val-gamma-nloglik:4.18915	train-sMAPE:0.61301	val-sMAPE:0.627481
# [200]	train-gamma-nloglik:3.82317	val-gamma-nloglik:3.78809	train-sMAPE:0.41292	val-sMAPE:0.423694
# [300]	train-gamma-nloglik:3.7567	val-gamma-nloglik:3.73751	train-sMAPE:0.355114	val-sMAPE:0.381811
# [400]	train-gamma-nloglik:3.73025	val-gamma-nloglik:3.71881	train-sMAPE:0.321223	val-sMAPE:0.358019
# [500]	train-gamma-nloglik:3.71583	val-gamma-nloglik:3.70775	train-sMAPE:0.296312	val-sMAPE:0.339125
# [599]	train-gamma-nloglik:3.70644	val-gamma-nloglik:3.70077	train-sMAPE:0.277033	val-sMAPE:0.326702
#  62%|██████▏   | 8/13 [00:46<00:29,  5.85s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:36.8393	val-gamma-nloglik:38.3031	train-sMAPE:1.75511	val-sMAPE:1.78545
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.33671	val-gamma-nloglik:4.45925	train-sMAPE:0.728895	val-sMAPE:0.741875
# [200]	train-gamma-nloglik:3.78185	val-gamma-nloglik:3.86833	train-sMAPE:0.523076	val-sMAPE:0.557469
# [300]	train-gamma-nloglik:3.68889	val-gamma-nloglik:3.77345	train-sMAPE:0.424875	val-sMAPE:0.45842
# [400]	train-gamma-nloglik:3.65341	val-gamma-nloglik:3.73771	train-sMAPE:0.363578	val-sMAPE:0.39413
# [500]	train-gamma-nloglik:3.63569	val-gamma-nloglik:3.72067	train-sMAPE:0.323939	val-sMAPE:0.353715
# [599]	train-gamma-nloglik:3.62481	val-gamma-nloglik:3.71143	train-sMAPE:0.29761	val-sMAPE:0.332498
#  69%|██████▉   | 9/13 [00:52<00:23,  5.87s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:24.6931	val-gamma-nloglik:24.4862	train-sMAPE:1.7425	val-sMAPE:1.75622
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:3.85366	val-gamma-nloglik:3.85174	train-sMAPE:0.54297	val-sMAPE:0.552112
# [200]	train-gamma-nloglik:3.42121	val-gamma-nloglik:3.45014	train-sMAPE:0.37282	val-sMAPE:0.387908
# [300]	train-gamma-nloglik:3.34417	val-gamma-nloglik:3.38293	train-sMAPE:0.291039	val-sMAPE:0.307481
# [400]	train-gamma-nloglik:3.3167	val-gamma-nloglik:3.36009	train-sMAPE:0.240673	val-sMAPE:0.266255
# [500]	train-gamma-nloglik:3.3037	val-gamma-nloglik:3.34975	train-sMAPE:0.20761	val-sMAPE:0.241754
# [599]	train-gamma-nloglik:3.29601	val-gamma-nloglik:3.34407	train-sMAPE:0.183646	val-sMAPE:0.22578
#  77%|███████▋  | 10/13 [00:58<00:17,  5.87s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:57.855	val-gamma-nloglik:56.3092	train-sMAPE:1.88813	val-sMAPE:1.8892
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:5.00234	val-gamma-nloglik:4.94938	train-sMAPE:0.659799	val-sMAPE:0.658623
# [200]	train-gamma-nloglik:4.29494	val-gamma-nloglik:4.27721	train-sMAPE:0.348639	val-sMAPE:0.347029
# [300]	train-gamma-nloglik:4.21961	val-gamma-nloglik:4.2118	train-sMAPE:0.244139	val-sMAPE:0.250765
# [400]	train-gamma-nloglik:4.19678	val-gamma-nloglik:4.1927	train-sMAPE:0.201407	val-sMAPE:0.209191
# [500]	train-gamma-nloglik:4.18606	val-gamma-nloglik:4.18422	train-sMAPE:0.177537	val-sMAPE:0.19499
# [599]	train-gamma-nloglik:4.17995	val-gamma-nloglik:4.179	train-sMAPE:0.159324	val-sMAPE:0.183672
#  85%|████████▍ | 11/13 [01:04<00:11,  5.87s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:25.9233	val-gamma-nloglik:24.2069	train-sMAPE:1.77342	val-sMAPE:1.78628
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:3.94392	val-gamma-nloglik:3.82411	train-sMAPE:0.550928	val-sMAPE:0.527796
# [200]	train-gamma-nloglik:3.54697	val-gamma-nloglik:3.50421	train-sMAPE:0.370706	val-sMAPE:0.335178
# [300]	train-gamma-nloglik:3.48252	val-gamma-nloglik:3.46521	train-sMAPE:0.32328	val-sMAPE:0.308142
# [400]	train-gamma-nloglik:3.45583	val-gamma-nloglik:3.4512	train-sMAPE:0.293207	val-sMAPE:0.295428
# [500]	train-gamma-nloglik:3.44086	val-gamma-nloglik:3.44423	train-sMAPE:0.270502	val-sMAPE:0.285824
# [599]	train-gamma-nloglik:3.43097	val-gamma-nloglik:3.43926	train-sMAPE:0.253049	val-sMAPE:0.276399
#  92%|█████████▏| 12/13 [01:10<00:05,  5.86s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:34.8479	val-gamma-nloglik:35.0504	train-sMAPE:1.8165	val-sMAPE:1.82683
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.30759	val-gamma-nloglik:4.33449	train-sMAPE:0.58116	val-sMAPE:0.59916
# [200]	train-gamma-nloglik:3.79263	val-gamma-nloglik:3.82548	train-sMAPE:0.35836	val-sMAPE:0.364665
# [300]	train-gamma-nloglik:3.71811	val-gamma-nloglik:3.76153	train-sMAPE:0.303493	val-sMAPE:0.317336
# [400]	train-gamma-nloglik:3.69148	val-gamma-nloglik:3.7399	train-sMAPE:0.275864	val-sMAPE:0.294017
# [500]	train-gamma-nloglik:3.67739	val-gamma-nloglik:3.72879	train-sMAPE:0.25673	val-sMAPE:0.277579
# [599]	train-gamma-nloglik:3.66827	val-gamma-nloglik:3.72141	train-sMAPE:0.241077	val-sMAPE:0.264951
# 100%|██████████| 13/13 [01:16<00:00,  5.87s/it]

# %% [markdown]
# # PM10

# %%
for i in tqdm(range(13)):
    trainX = np.concatenate((train_data[:,2*i:2*(i+1)],train_data[:,26:2185],train_data[:,2185+6*i:2185+6*(i+1)],train_data[:,-34:-26]),axis = 1)
    valX = np.concatenate((val_data[:,2*i:2*(i+1)],val_data[:,26:2185],val_data[:,2185+6*i:2185+6*(i+1)],val_data[:,-34:-26]),axis = 1)
    trainY = train_data[:, -26+2*i+1]
    valY = val_data[:, -26+2*i+1]
    trainY[trainY <= 0] = 0.1
    valY[valY <= 0] = 0.1
#     trainY = London_train[:, -26+2*i+1]
#     valY = London_test[:, -26+2*i+1]
    print(trainX.shape)
    print(valX.shape)

    params={
    'booster':'gbtree',
    'objective': 'reg:gamma', #多分类的问题
    # 'num_class':2, # 类别数，与 multisoftmax 并用
    'gamma':0,  # 用于控制是否后剪枝的参数,越大越保守，一般0.1、0.2这样子。
    'max_depth':2, # 构建树的深度，越大越容易过拟合
    'lambda':100,  # 控制模型复杂度的权重值的L2正则化项参数，参数越大，模型越不容易过拟合。
    'alpha':0,      # 控制模型复杂度的权重值的L1正则化项参数，参数越大，模型越不容易过拟合。
    'subsample':0.9, # 随机采样训练样本
    'colsample_bytree':0.2, # 生成树时进行的列采样
    'min_child_weight':1, 
    # 这个参数默认是 1，是每个叶子里面 h 的和至少是多少，对正负样本不均衡时的 0-1 分类而言
    #，假设 h 在 0.01 附近，min_child_weight 为 1 意味着叶子节点中最少需要包含 100 个样本。
    #这个参数非常影响结果，控制叶子节点中二阶导的和的最小值，该参数值越小，越容易 overfitting。 
    'silent':0 ,#设置成1则没有运行信息输出，最好是设置为0.
    'eta': 0.05, # 如同学习率
    'seed':1000,
    'nthread':-1,# cpu 线程数
#     'eval_metric':['mae','rmse']
    }

    plst = list(params.items())
    num_rounds = 600 # 迭代次数
    xgb_train = xgb.DMatrix(trainX, label= trainY)
    xgb_val = xgb.DMatrix(valX, label= valY)
    watchlist = [(xgb_train, 'train'),(xgb_val, 'val')]
    #训练模型并保存
    # early_stopping_rounds 当设置的迭代次数较大时，early_stopping_rounds 可在一定的迭代次数内准确率没有提升就停止训练
    model_PM10 = xgb.train(plst, xgb_train, num_rounds, watchlist, early_stopping_rounds=50,verbose_eval=100,feval=sMAPE)
    model_PM10.save_model('/home/lifuzhen/KDD2018/Mini_train/ld_mean_std/'+ str(i) +'_PM10.model') # 用于存储训练出的模型
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:44.6298	val-gamma-nloglik:41.7411	train-sMAPE:1.87627	val-sMAPE:1.87378
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.16871	val-gamma-nloglik:4.11218	train-sMAPE:0.389203	val-sMAPE:0.398497
# [200]	train-gamma-nloglik:4.01229	val-gamma-nloglik:4.00313	train-sMAPE:0.193563	val-sMAPE:0.272478
# [300]	train-gamma-nloglik:3.99905	val-gamma-nloglik:3.99385	train-sMAPE:0.157107	val-sMAPE:0.252033
# [400]	train-gamma-nloglik:3.99347	val-gamma-nloglik:3.99065	train-sMAPE:0.134129	val-sMAPE:0.241203
# [500]	train-gamma-nloglik:3.99005	val-gamma-nloglik:3.98844	train-sMAPE:0.117851	val-sMAPE:0.233291
# [599]	train-gamma-nloglik:3.98774	val-gamma-nloglik:3.98693	train-sMAPE:0.105577	val-sMAPE:0.228204
#   8%|▊         | 1/13 [00:05<01:09,  5.80s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:39.0082	val-gamma-nloglik:36.7598	train-sMAPE:1.8401	val-sMAPE:1.84847
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:3.98	val-gamma-nloglik:3.9574	train-sMAPE:0.389014	val-sMAPE:0.396515
# [200]	train-gamma-nloglik:3.82568	val-gamma-nloglik:3.84769	train-sMAPE:0.208405	val-sMAPE:0.278522
# [300]	train-gamma-nloglik:3.80992	val-gamma-nloglik:3.83711	train-sMAPE:0.166257	val-sMAPE:0.253512
# [400]	train-gamma-nloglik:3.8032	val-gamma-nloglik:3.83229	train-sMAPE:0.142042	val-sMAPE:0.242336
# [500]	train-gamma-nloglik:3.79901	val-gamma-nloglik:3.82885	train-sMAPE:0.124181	val-sMAPE:0.232678
# [599]	train-gamma-nloglik:3.79616	val-gamma-nloglik:3.82677	train-sMAPE:0.109602	val-sMAPE:0.226652
#  15%|█▌        | 2/13 [00:11<01:03,  5.75s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:36.9681	val-gamma-nloglik:35.1161	train-sMAPE:1.81257	val-sMAPE:1.82736
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:3.89627	val-gamma-nloglik:3.89389	train-sMAPE:0.432969	val-sMAPE:0.445531
# [200]	train-gamma-nloglik:3.73601	val-gamma-nloglik:3.77883	train-sMAPE:0.252438	val-sMAPE:0.331249
# [300]	train-gamma-nloglik:3.71717	val-gamma-nloglik:3.76589	train-sMAPE:0.207048	val-sMAPE:0.31036
# [400]	train-gamma-nloglik:3.70854	val-gamma-nloglik:3.76043	train-sMAPE:0.182173	val-sMAPE:0.298136
# [500]	train-gamma-nloglik:3.70247	val-gamma-nloglik:3.75671	train-sMAPE:0.165123	val-sMAPE:0.290253
# [599]	train-gamma-nloglik:3.69802	val-gamma-nloglik:3.75414	train-sMAPE:0.151416	val-sMAPE:0.286407
#  23%|██▎       | 3/13 [00:17<00:57,  5.74s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:52.8963	val-gamma-nloglik:53.8905	train-sMAPE:1.89819	val-sMAPE:1.91036
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.38839	val-gamma-nloglik:4.4577	train-sMAPE:0.469952	val-sMAPE:0.439535
# [200]	train-gamma-nloglik:4.23552	val-gamma-nloglik:4.30852	train-sMAPE:0.203675	val-sMAPE:0.22609
# [300]	train-gamma-nloglik:4.22202	val-gamma-nloglik:4.29963	train-sMAPE:0.164356	val-sMAPE:0.206446
# [400]	train-gamma-nloglik:4.21539	val-gamma-nloglik:4.29839	train-sMAPE:0.143137	val-sMAPE:0.201159
# [500]	train-gamma-nloglik:4.21068	val-gamma-nloglik:4.29848	train-sMAPE:0.126557	val-sMAPE:0.196859
# [599]	train-gamma-nloglik:4.20738	val-gamma-nloglik:4.29841	train-sMAPE:0.114387	val-sMAPE:0.192211
#  31%|███       | 4/13 [00:22<00:51,  5.73s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:42.5714	val-gamma-nloglik:40.1154	train-sMAPE:1.85848	val-sMAPE:1.85119
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.10756	val-gamma-nloglik:4.05407	train-sMAPE:0.439753	val-sMAPE:0.4601
# [200]	train-gamma-nloglik:3.96303	val-gamma-nloglik:3.95243	train-sMAPE:0.263366	val-sMAPE:0.330261
# [300]	train-gamma-nloglik:3.94494	val-gamma-nloglik:3.94203	train-sMAPE:0.217798	val-sMAPE:0.31165
# [400]	train-gamma-nloglik:3.93562	val-gamma-nloglik:3.93671	train-sMAPE:0.189331	val-sMAPE:0.301568
# [500]	train-gamma-nloglik:3.92898	val-gamma-nloglik:3.9324	train-sMAPE:0.166777	val-sMAPE:0.292381
# [599]	train-gamma-nloglik:3.92422	val-gamma-nloglik:3.92958	train-sMAPE:0.149438	val-sMAPE:0.286654
#  38%|███▊      | 5/13 [00:28<00:46,  5.78s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:43.105	val-gamma-nloglik:42.5794	train-sMAPE:1.86496	val-sMAPE:1.86693
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.10432	val-gamma-nloglik:4.13248	train-sMAPE:0.383068	val-sMAPE:0.409918
# [200]	train-gamma-nloglik:3.93794	val-gamma-nloglik:3.98489	train-sMAPE:0.192945	val-sMAPE:0.27055
# [300]	train-gamma-nloglik:3.92344	val-gamma-nloglik:3.97087	train-sMAPE:0.150985	val-sMAPE:0.244481
# [400]	train-gamma-nloglik:3.9179	val-gamma-nloglik:3.96462	train-sMAPE:0.127798	val-sMAPE:0.229078
# [500]	train-gamma-nloglik:3.91473	val-gamma-nloglik:3.96108	train-sMAPE:0.11171	val-sMAPE:0.221602
# [599]	train-gamma-nloglik:3.91267	val-gamma-nloglik:3.95854	train-sMAPE:0.099985	val-sMAPE:0.214942
#  46%|████▌     | 6/13 [00:34<00:40,  5.77s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:43.7013	val-gamma-nloglik:42.4651	train-sMAPE:1.86095	val-sMAPE:1.86914
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.11098	val-gamma-nloglik:4.11943	train-sMAPE:0.408583	val-sMAPE:0.409263
# [200]	train-gamma-nloglik:3.93926	val-gamma-nloglik:3.98825	train-sMAPE:0.207597	val-sMAPE:0.262588
# [300]	train-gamma-nloglik:3.9247	val-gamma-nloglik:3.97703	train-sMAPE:0.16186	val-sMAPE:0.241851
# [400]	train-gamma-nloglik:3.91905	val-gamma-nloglik:3.97277	train-sMAPE:0.136115	val-sMAPE:0.232748
# [500]	train-gamma-nloglik:3.91555	val-gamma-nloglik:3.96984	train-sMAPE:0.12028	val-sMAPE:0.225074
# [599]	train-gamma-nloglik:3.91307	val-gamma-nloglik:3.96791	train-sMAPE:0.108088	val-sMAPE:0.219548
#  54%|█████▍    | 7/13 [00:40<00:34,  5.76s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:44.9219	val-gamma-nloglik:44.1155	train-sMAPE:1.87719	val-sMAPE:1.88081
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.17836	val-gamma-nloglik:4.17739	train-sMAPE:0.389858	val-sMAPE:0.393645
# [200]	train-gamma-nloglik:4.02642	val-gamma-nloglik:4.04619	train-sMAPE:0.219899	val-sMAPE:0.264368
# [300]	train-gamma-nloglik:4.01264	val-gamma-nloglik:4.03674	train-sMAPE:0.177325	val-sMAPE:0.244184
# [400]	train-gamma-nloglik:4.00627	val-gamma-nloglik:4.03261	train-sMAPE:0.152777	val-sMAPE:0.232813
# [500]	train-gamma-nloglik:4.00195	val-gamma-nloglik:4.02976	train-sMAPE:0.134085	val-sMAPE:0.224575
# [599]	train-gamma-nloglik:3.99888	val-gamma-nloglik:4.02788	train-sMAPE:0.118776	val-sMAPE:0.218118
#  62%|██████▏   | 8/13 [00:46<00:28,  5.76s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:37.1377	val-gamma-nloglik:35.6706	train-sMAPE:1.83943	val-sMAPE:1.83487
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:3.93379	val-gamma-nloglik:3.91824	train-sMAPE:0.38444	val-sMAPE:0.412559
# [200]	train-gamma-nloglik:3.78775	val-gamma-nloglik:3.80484	train-sMAPE:0.221983	val-sMAPE:0.300321
# [300]	train-gamma-nloglik:3.77232	val-gamma-nloglik:3.79163	train-sMAPE:0.179743	val-sMAPE:0.274519
# [400]	train-gamma-nloglik:3.76543	val-gamma-nloglik:3.78548	train-sMAPE:0.15442	val-sMAPE:0.261066
# [500]	train-gamma-nloglik:3.76123	val-gamma-nloglik:3.78213	train-sMAPE:0.13732	val-sMAPE:0.254757
# [599]	train-gamma-nloglik:3.75816	val-gamma-nloglik:3.77991	train-sMAPE:0.124052	val-sMAPE:0.249696
#  69%|██████▉   | 9/13 [00:52<00:23,  5.78s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:35.2003	val-gamma-nloglik:34.8561	train-sMAPE:1.83633	val-sMAPE:1.84713
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:3.85195	val-gamma-nloglik:3.87561	train-sMAPE:0.332427	val-sMAPE:0.340422
# [200]	train-gamma-nloglik:3.71969	val-gamma-nloglik:3.76723	train-sMAPE:0.141038	val-sMAPE:0.188515
# [300]	train-gamma-nloglik:3.7103	val-gamma-nloglik:3.75898	train-sMAPE:0.098817	val-sMAPE:0.153305
# [400]	train-gamma-nloglik:3.70696	val-gamma-nloglik:3.75594	train-sMAPE:0.080449	val-sMAPE:0.139998
# [500]	train-gamma-nloglik:3.70514	val-gamma-nloglik:3.75389	train-sMAPE:0.068464	val-sMAPE:0.132357
# [599]	train-gamma-nloglik:3.70398	val-gamma-nloglik:3.75246	train-sMAPE:0.059593	val-sMAPE:0.126767
#  77%|███████▋  | 10/13 [00:58<00:17,  5.81s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:65.5404	val-gamma-nloglik:64.4956	train-sMAPE:1.91552	val-sMAPE:1.91632
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.5868	val-gamma-nloglik:4.57652	train-sMAPE:0.430543	val-sMAPE:0.436237
# [200]	train-gamma-nloglik:4.38089	val-gamma-nloglik:4.38534	train-sMAPE:0.129003	val-sMAPE:0.155818
# [300]	train-gamma-nloglik:4.37316	val-gamma-nloglik:4.37874	train-sMAPE:0.08641	val-sMAPE:0.129799
# [400]	train-gamma-nloglik:4.37071	val-gamma-nloglik:4.37652	train-sMAPE:0.06868	val-sMAPE:0.118852
# [500]	train-gamma-nloglik:4.36946	val-gamma-nloglik:4.37554	train-sMAPE:0.059144	val-sMAPE:0.113948
# [599]	train-gamma-nloglik:4.36864	val-gamma-nloglik:4.37475	train-sMAPE:0.051651	val-sMAPE:0.109627
#  85%|████████▍ | 11/13 [01:03<00:11,  5.80s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:50.8615	val-gamma-nloglik:47.2286	train-sMAPE:1.89712	val-sMAPE:1.89801
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.34013	val-gamma-nloglik:4.25942	train-sMAPE:0.410934	val-sMAPE:0.377124
# [200]	train-gamma-nloglik:4.18649	val-gamma-nloglik:4.16475	train-sMAPE:0.237459	val-sMAPE:0.254761
# [300]	train-gamma-nloglik:4.17079	val-gamma-nloglik:4.16067	train-sMAPE:0.192356	val-sMAPE:0.24433
# [400]	train-gamma-nloglik:4.16304	val-gamma-nloglik:4.15756	train-sMAPE:0.164075	val-sMAPE:0.235533
# [500]	train-gamma-nloglik:4.15804	val-gamma-nloglik:4.15482	train-sMAPE:0.143602	val-sMAPE:0.22825
# [599]	train-gamma-nloglik:4.15466	val-gamma-nloglik:4.15273	train-sMAPE:0.128146	val-sMAPE:0.222795
#  92%|█████████▏| 12/13 [01:09<00:05,  5.79s/it]
# (386, 2313)
# (166, 2313)
# [0]	train-gamma-nloglik:60.1559	val-gamma-nloglik:61.3947	train-sMAPE:1.91091	val-sMAPE:1.91208
# Multiple eval metrics have been passed: 'val-sMAPE' will be used for early stopping.
#
# Will train until val-sMAPE hasn't improved in 50 rounds.
# [100]	train-gamma-nloglik:4.52664	val-gamma-nloglik:4.56526	train-sMAPE:0.411748	val-sMAPE:0.438382
# [200]	train-gamma-nloglik:4.33452	val-gamma-nloglik:4.37901	train-sMAPE:0.206692	val-sMAPE:0.267509
# [300]	train-gamma-nloglik:4.31881	val-gamma-nloglik:4.36523	train-sMAPE:0.161424	val-sMAPE:0.234069
# [400]	train-gamma-nloglik:4.3122	val-gamma-nloglik:4.35934	train-sMAPE:0.134618	val-sMAPE:0.21653
# [500]	train-gamma-nloglik:4.30829	val-gamma-nloglik:4.35636	train-sMAPE:0.116605	val-sMAPE:0.205778
# [599]	train-gamma-nloglik:4.30566	val-gamma-nloglik:4.35434	train-sMAPE:0.103624	val-sMAPE:0.198764
# 100%|██████████| 13/13 [01:15<00:00,  5.78s/it]

# %% [markdown]
# # predict

# %%
import requests
for i in range(9,10):
    for j in range(0,24):
        end   = '2018-05-'+str(i).zfill(2)+'-'+str(j)
        url = 'http://kdd.caiyunapp.com/competition/forecast/bj/'+end+'/2k0d1d8'
        respones= requests.get(url)
        with open ('/home/lifuzhen/KDD2018/Mini_train/bj_grid_meteorology_forecast_48_hours'+'_'+end+'.csv','w') as f:
            f.write(respones.text)
        print('finished!')

for i in range(9,10):
    for j in range(0,24):
        end   = '2018-05-'+str(i).zfill(2)+'-'+str(j)
        url = 'http://kdd.caiyunapp.com/competition/forecast/ld/'+end+'/2k0d1d8'
        respones= requests.get(url)
        with open ('/home/lifuzhen/KDD2018/Mini_train/ld_grid_meteorology_forecast_48_hours'+'_'+end+'.csv','w') as f:
            f.write(respones.text)
        print('finished')
# Out:
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished!
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished
# finished

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from datetime import timedelta
from datetime import datetime
from datetime import date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
import copy

def gen_dates(b_date, count):
    hour = timedelta(hours=1)
    for i in range(count+1):
        yield b_date + hour*i


def get_date_list(start=None, end=None):
    """
    获取日期列表
    :param start: 开始日期
    :param end: 结束日期
    :return:
    """
    if start is None:
        start = datetime.strptime("2000-01-01 00:00:00", "%Y-%m-%d %H:%M:%S")
    if end is None:
        end = datetime.now()
    data = []
    for d in gen_dates(start, int((end-start).total_seconds()/3600)):
        data.append(str(d))
    return data


Medium_PM10 = 88
Medium_PM25 = 59
Medium_O3   = 56
Medium_NO2  = 46
Medium_CO   = 1
Medium_SO2  = 9
def to_timedict_bj(start, end):
    "输入时间和表格，返回字典"
    aq = pd.read_csv('/home/lifuzhen/KDD2018/Predict/bj_airquality_'+str(start).split(' ')[0]+'-'+str(int(str(start).split(' ')[1].split(':')[0])) +'_'+str(end).split(' ')[0]+'-'+str(int(str(end).split(' ')[1].split(':')[0]))+'.csv')
    meo = pd.read_csv('/home/lifuzhen/KDD2018/Predict/bj_meteorology_'+str(start).split(' ')[0]+'-'+str(int(str(start).split(' ')[1].split(':')[0])) +'_'+str(end).split(' ')[0]+'-'+str(int(str(end).split(' ')[1].split(':')[0]))+'.csv')
    meo_grid = pd.read_csv('/home/lifuzhen/KDD2018/Predict/bj_grid_meteorology_'+str(start).split(' ')[0]+'-'+str(int(str(start).split(' ')[1].split(':')[0])) +'_'+str(end).split(' ')[0]+'-'+str(int(str(end).split(' ')[1].split(':')[0]))+'.csv')
    
    alt_list = get_date_list(Start , End)
    alt_dict = {}
    recons = pd.DataFrame(columns=('stationId','utc_time','PM2.5','PM10','NO2','CO','O3','SO2'))
    
    for i in alt_list:
        alt_dict[i] = []
    alt = np.array(aq[['station_id','time','PM25_Concentration','PM10_Concentration','NO2_Concentration','CO_Concentration','O3_Concentration','SO2_Concentration']]).tolist()
    for i in tqdm(['aotizhongxin', 'badaling', 'beibuxinqu', 'daxing', 'dingling', 'donggaocun', 'dongsi','dongsihuan','fangshan', 'fengtaihuayuan', 'guanyuan', 'gucheng','huairou', 'liulihe', 'mentougou', 'miyun', 'miyunshuiku', 'nansanhuan', 'nongzhanguan', 'pingchang', 'pinggu','qianmen','shunyi','tiantan','tongzhou','wanliu','wanshouxigong','xizhimenbei','yanqin','yizhuang','yongdingmennei','yongledian','yufa','yungang']):
        count = 0
        for j in aq['station_id']:
            if j.split('_')[0] == i:
                recons.loc[count] = alt[count]
            count += 1 
#     print(recons)
    recons.reset_index(drop=True,inplace=True)
#     recons.loc[recons['stationId'] == 'zhiwuyuan_aq',['PM2.5','PM10','NO2','CO','O3','SO2']] = [Medium_PM25,Medium_PM10,Medium_NO2,Medium_CO,Medium_O3,Medium_SO2]

#     print(recons.loc[recons['stationId'] == 'zhiwuyuan_aq'])
    recons.interpolate(inplace = True)
#     print(recons.loc[recons['stationId'] == 'zhiwuyuan_aq'])
    recons['PM2.5'].fillna(Medium_PM25, inplace = True)
    recons['PM10'].fillna(Medium_PM10, inplace = True)
    recons['NO2'].fillna(Medium_NO2, inplace = True)
    recons['CO'].fillna(Medium_CO, inplace = True)
    recons['O3'].fillna(Medium_O3, inplace = True)
    recons['SO2'].fillna(Medium_SO2, inplace = True)
    
    recons['lon'] = 0 ##经度
    recons['lat'] = 0  ##纬度
    recons.loc[recons['stationId']=='dongsi_aq',['lon','lat']] = [116.417,39.929]
    recons.loc[recons['stationId']=='tiantan_aq',['lon','lat']] = [116.407,39.886]
    recons.loc[recons['stationId']=='guanyuan_aq',['lon','lat']] = [116.339,39.929]
    recons.loc[recons['stationId']=='wanshouxigong_aq',['lon','lat']] = [116.352,39.878]
    recons.loc[recons['stationId']=='aotizhongxin_aq',['lon','lat']] = [116.397,39.982]
    recons.loc[recons['stationId']=='nongzhanguan_aq',['lon','lat']] = [116.461,39.937]
    recons.loc[recons['stationId']=='wanliu_aq',['lon','lat']] = [116.287,39.987]
    recons.loc[recons['stationId']=='beibuxinqu_aq',['lon','lat']] = [116.174,40.09]
    recons.loc[recons['stationId']=='zhiwuyuan_aq',['lon','lat']] = [116.207,40.002]
    recons.loc[recons['stationId']=='fengtaihuayuan_aq',['lon','lat']] = [116.279,39.863]
    recons.loc[recons['stationId']=='yungang_aq',['lon','lat']] = [116.146,39.824]
    recons.loc[recons['stationId']=='gucheng_aq',['lon','lat']] = [116.184,39.914]
    recons.loc[recons['stationId']=='fangshan_aq',['lon','lat']] = [116.136,39.742]
    recons.loc[recons['stationId']=='daxing_aq',['lon','lat']] = [116.404,39.718]
    recons.loc[recons['stationId']=='yizhuang_aq',['lon','lat']] = [116.506,39.795]
    recons.loc[recons['stationId']=='tongzhou_aq',['lon','lat']] = [116.663,39.886]
    recons.loc[recons['stationId']=='shunyi_aq',['lon','lat']] = [116.655,40.127]
    recons.loc[recons['stationId']=='pingchang_aq',['lon','lat']] = [116.23,40.217]
    recons.loc[recons['stationId']=='mentougou_aq',['lon','lat']] = [116.106,39.937]
    recons.loc[recons['stationId']=='pinggu_aq',['lon','lat']] = [117.1,40.143]
    recons.loc[recons['stationId']=='hureconsou_aq',['lon','lat']] = [116.628,40.328]
    recons.loc[recons['stationId']=='miyun_aq',['lon','lat']] = [116.832,40.37]
    recons.loc[recons['stationId']=='yanqin_aq',['lon','lat']] = [115.972,40.453]
    recons.loc[recons['stationId']=='dingling_aq',['lon','lat']] = [116.22,40.292]
    recons.loc[recons['stationId']=='badaling_aq',['lon','lat']] = [115.988,40.365]
    recons.loc[recons['stationId']=='miyunshuiku_aq',['lon','lat']] = [116.911,40.499]
    recons.loc[recons['stationId']=='donggaocun_aq',['lon','lat']] = [117.12,40.1]
    recons.loc[recons['stationId']=='yongledian_aq',['lon','lat']] = [116.783,39.712]
    recons.loc[recons['stationId']=='yufa_aq',['lon','lat']] = [116.3,39.52]
    recons.loc[recons['stationId']=='liulihe_aq',['lon','lat']] = [116,39.58]
    recons.loc[recons['stationId']=='qianmen_aq',['lon','lat']] = [116.395,39.899]
    recons.loc[recons['stationId']=='yongdingmennei_aq',['lon','lat']] = [116.394,39.876]
    recons.loc[recons['stationId']=='xizhimenbei_aq',['lon','lat']] = [116.349,39.954]
    recons.loc[recons['stationId']=='nansanhuan_aq',['lon','lat']] = [116.368,39.856]
    recons.loc[recons['stationId']=='dongsihuan_aq',['lon','lat']] = [116.483,39.939]
        
    count = 0
    Idx = 0  ####索引记录####
    recons_list = np.array(recons[['lon','lat']]).tolist()
    for i in tqdm(np.array(recons['utc_time']).tolist()):
        if i in alt_dict.keys():
            alt_dict[i].extend(recons_list[Idx])

        Idx += 1
    
    count = 0
    Idx = 0  ####索引记录####
    recons_list = np.array(recons[['PM2.5','PM10','NO2','CO','O3','SO2']]).tolist()
    for i in tqdm(np.array(recons['utc_time']).tolist()):
        if i in alt_dict.keys():
            alt_dict[i].extend(recons_list[Idx])

        Idx += 1
        
    for k,v in alt_dict.items():
        if len(v) == 0:
            if int(k.split(' ')[1].split(':')[0]) != 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
            else:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
    for k,v in alt_dict.items():
        if len(v) == 0:
            if int(k.split(' ')[1].split(':')[0]) != 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
            else:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) == 272:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
#     print(recons)
    ######################处理缺失时间点完毕#####################shunyi_meo


    recons_meo = pd.DataFrame(columns=('station_id','time','temperature','pressure','humidity','wind_direction','wind_speed','weather'))

    alt = np.array(meo[['station_id','time','temperature','pressure','humidity','wind_direction','wind_speed','weather']]).tolist()
    for i in tqdm(['shunyi_meo','hadian_meo','yanqing_meo','miyun_meo','huairou_meo','shangdianzi_meo','pinggu_meo','tongzhou_meo','chaoyang_meo','pingchang_meo','zhaitang_meo','mentougou_meo','beijing_meo','shijingshan_meo','fengtai_meo','daxing_meo','fangshan_meo','xiayunling_meo']):
        count = 0
        for j in meo['station_id']:
            if j == i:
                recons_meo.loc[count] = alt[count]
            count += 1 
    
    for i in range(len(recons_meo['wind_speed'])):
        if recons_meo['wind_speed'][i] == 999017:
            recons_meo.loc[i,'wind_speed'] = recons_meo.loc[i-1,'wind_speed']
    recons_meo['longitude'] = 0 ##经度
    recons_meo['latitude'] = 0  ##纬度
    recons_meo.loc[recons_meo['station_id']=='shunyi_meo',['longitude','latitude']] = [116.6153,40.12667]
    recons_meo.loc[recons_meo['station_id']=='haidian_meo',['longitude','latitude']] = [116.2906,39.98694]
    recons_meo.loc[recons_meo['station_id']=='yanqing_meo',['longitude','latitude']] = [115.9689,40.44944]
    recons_meo.loc[recons_meo['station_id']=='miyun_meo',['longitude','latitude']] = [116.8642,40.3775]
    recons_meo.loc[recons_meo['station_id']=='huairou_meo',['longitude','latitude']] = [116.6269,40.35778]
    recons_meo.loc[recons_meo['station_id']=='shangdianzi_meo',['longitude','latitude']] = [117.1117,40.65889]
    recons_meo.loc[recons_meo['station_id']=='pinggu_meo',['longitude','latitude']] = [117.1178,40.16944]
    recons_meo.loc[recons_meo['station_id']=='tongzhou_meo',['longitude','latitude']] = [116.7567,39.8475]
    recons_meo.loc[recons_meo['station_id']=='chaoyang_meo',['longitude','latitude']] = [116.5008,39.9525]
    recons_meo.loc[recons_meo['station_id']=='pingchang_meo',['longitude','latitude']] = [116.2117,40.22333]
    recons_meo.loc[recons_meo['station_id']=='zhaitang_meo',['longitude','latitude']] = [115.6922,39.97389]
    recons_meo.loc[recons_meo['station_id']=='mentougou_meo',['longitude','latitude']] = [116.1564,39.88778]
    recons_meo.loc[recons_meo['station_id']=='beijing_meo',['longitude','latitude']] = [116.4694,39.80611]
    recons_meo.loc[recons_meo['station_id']=='shijingshan_meo',['longitude','latitude']] = [116.2053,39.9425]
    recons_meo.loc[recons_meo['station_id']=='fengtai_meo',['longitude','latitude']] = [116.2453,39.87028]
    recons_meo.loc[recons_meo['station_id']=='daxing_meo',['longitude','latitude']] = [116.3544,39.71861]
    recons_meo.loc[recons_meo['station_id']=='fangshan_meo',['longitude','latitude']] = [116.1942,39.77306]
    recons_meo.loc[recons_meo['station_id']=='xiayunling_meo',['longitude','latitude']] = [115.7406,39.72861]

    recons_meo.loc[meo['weather'] == 'Sunny/clear' , 'weather'] = 0
    recons_meo.loc[meo['weather'] == 'Snow' , 'weather'] = 1
    recons_meo.loc[meo['weather'] == 'Sleet' , 'weather'] = 2
    recons_meo.loc[meo['weather'] == 'Sand' , 'weather'] = 3
    recons_meo.loc[meo['weather'] == 'Rain/Snow with Hail' , 'weather'] = 4
    recons_meo.loc[meo['weather'] == 'Rain with Hail' , 'weather'] = 5
    recons_meo.loc[meo['weather'] == 'Rain' , 'weather'] = 6
    recons_meo.loc[meo['weather'] == 'Haze' , 'weather'] = 7
    recons_meo.loc[meo['weather'] == 'Fog' , 'weather'] = 8
    recons_meo.loc[meo['weather'] == 'Dust' , 'weather'] = 9
    recons_meo.loc[meo['weather'] == 'Hail' , 'weather'] = 4
    recons_meo.loc[meo['weather'] == 'Cloudy' , 'weather'] = 0
    recons_meo.loc[meo['weather'] == 'Overcast' , 'weather'] = 0
    recons_meo.loc[meo['weather'] == 'Thundershower' , 'weather'] = 6
    def div5(x):
        return int(x/5)
    def div15(x):
        return int(x/15)
    def div05(x):
        return int(x/0.5)
    recons_meo['temperature'] = recons_meo['temperature'].apply(div5)
    recons_meo['pressure'] = recons_meo['pressure'].apply(div5)
    recons_meo['humidity'] = recons_meo['humidity'].apply(div5)
    recons_meo['wind_direction'] = recons_meo['wind_direction'].apply(div15)
    recons_meo['wind_speed/kph'] = recons_meo['wind_speed'].apply(div05)
    #############wether量化###############

    #############处理缺失时间点##########
    count = 0
    Idx = 0  ####索引记录####
    meo_list = np.array(recons_meo[['temperature','pressure','humidity','wind_direction','wind_speed','weather']]).tolist()
    

    for i in tqdm(np.array(recons_meo['time']).tolist()):
        if i in alt_dict.keys():
            alt_dict[i].extend(meo_list[Idx])

        Idx += 1
        
    length = []  
    
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 416:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))  
    
    for i in range(3):
        for k,v in alt_dict.items():
            if len(v) < max(length):
                if int(k.split(' ')[1].split(':')[0]) != 0:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
                else:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
                
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 416:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))  
    ######################处理缺失时间点完毕#####################
    meo_grid['longitude'] = 0 ##经度
    meo_grid['latitude'] = 0  ##纬度
    count = 0
    for i in range(1150,1181,1):
        for j in range(390,411,1):
            if (i >= 1156 and i <= 1172) and (j >= 395 and j <= 407):
                meo_grid.loc[meo_grid['station_id']=='beijing_grid_'+str(count).zfill(3),['longitude','latitude']] = [i/10.0,j/10.0]
#                 print([i,j])
            count += 1
    
    meo_grid.drop(meo_grid[meo_grid['longitude'] < 115.6].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['longitude'] > 117.2].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['latitude']  < 39.5].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['latitude']  > 40.7].index.tolist(),inplace= True)
    meo_grid.drop('id',axis = 1)
    meo_grid.drop_duplicates(inplace=True)
    meo_grid.reset_index(drop=True,inplace=True)
#     print(meo_grid.head(100))
    def div5(x):
        return int(x/5)
    def div15(x):
        return int(x/15)
    def div05(x):
        return int(x/0.5)
    meo_grid['temperature'] = meo_grid['temperature'].apply(div5)
    meo_grid['pressure'] = meo_grid['pressure'].apply(div5)
    meo_grid['humidity'] = meo_grid['humidity'].apply(div5)
    meo_grid['wind_direction'] = meo_grid['wind_direction'].apply(div15)
    meo_grid['wind_speed/kph'] = meo_grid['wind_speed'].apply(div05)
    
    
    
    
    count = 1
    Idx = 0  ####索引记录####

    meo_grid_list = np.array(meo_grid[['temperature','pressure','humidity','wind_direction','wind_speed']]).tolist()
    for i in tqdm(meo_grid['time']):
        if i in alt_dict.keys():
            if Idx > 0:
                count = int(meo_grid['station_id'][Idx].split('_')[2]) - int(meo_grid['station_id'][Idx-1].split('_')[2])
                
            if count > 1 and count < 9:
                for j in range(count-1):
                    alt_dict[i].extend(meo_grid_list[Idx-1])
            if count > 9:
                for j in range(count-9):
                    alt_dict[i].extend(meo_grid_list[Idx+1])
            alt_dict[i].extend(meo_grid_list[Idx])
        Idx += 1
        
        
        
        
        
        
        
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 1485:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    for i in range(3):
        for k,v in alt_dict.items():
            if len(v) != 1485:
                if int(k.split(' ')[1].split(':')[0]) != 0:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
                else:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
                
            
            
        
        
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 1963:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    pop_list = []
    for k in tqdm(alt_dict.keys()):
        weather_fore = pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/bj_grid_meteorology_forecast_48_hours_'+k.split(' ')[0]+'-'+str(int(k.split(' ')[1].split(':')[0]))+'.csv')
        if np.array(weather_fore).tolist() == []:
            pop_list.append(k)
            continue
        weather_fore['weather'].replace(['CLEAR_DAY','CLEAR_NIGHT','CLOUDY','PARTLY_CLOUDY_DAY','PARTLY_CLOUDY_NIGHT','RAIN','SNOW','WIND','HAZE'],[0,1,2,3,4,5,6,7,8],inplace = True)
        weather_fore['longitude'] = 0 ##经度
        weather_fore['latitude'] = 0  ##纬度
        count = 0
#         print(k)
        for i in range(1150,1181,1):
            for j in range(390,411,1):
                if (i >= 1156 and i <= 1172) and (j >= 395 and j <= 407):
                    weather_fore.loc[weather_fore['station_id']=='beijing_grid_'+str(count).zfill(3),['longitude','latitude']] = [i/10.0,j/10.0]
#                     print([i,j])
                count += 1

        weather_fore.drop(weather_fore[weather_fore['longitude'] < 115.6].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['longitude'] > 117.2].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['latitude']  < 39.5].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['latitude']  > 40.7].index.tolist(),inplace= True)
        weather_fore.reset_index(drop=True,inplace=True)
        
        weather_fore_array = np.array(weather_fore['weather'])
        alt_dict[k].extend(weather_fore_array.tolist())
#         print(len(alt_dict[k]))
        if len(alt_dict[k]) != 12093:
            pop_list.append(k)
    for i in pop_list:
        alt_dict[i].extend(np.zeros(12093-len(alt_dict[i])).tolist())
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 1963:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    
    alt_frame = pd.DataFrame.from_dict(alt_dict).T
    count = 0
    for i in list(alt_frame.index):
        if i in pop_list:
            alt_frame.iloc[count,list(range(1485,12093))] = copy.deepcopy(alt_frame.iloc[count-1,list(range(1485,12093))])
            alt_dict[i][1485:12093] = copy.deepcopy(alt_frame.iloc[count-1,list(range(1485,12093))]).tolist()
        count += 1
    ##########提取aq 48小时滑窗##########
    win = 48
#     win = 72
#     win = 16
#     win = 168
    
    for i in tqdm(range(68,272)):  
        count = 0
        for j in alt_frame[i]:
            if count >= win:
                alt_dict[alt_frame.index[count]].extend([np.mean(alt_frame[i][count-win:count]),np.std(alt_frame[i][count-win:count])])
                if i == 271:
                    if date.isoweekday(datetime.strptime(alt_frame.index[count], "%Y-%m-%d %H:%M:%S")) == 3 or date.isoweekday(datetime.strptime(alt_frame.index[count], "%Y-%m-%d %H:%M:%S")) == 4: ###要预测的是周末
                        alt_dict[alt_frame.index[count]].extend([1])
                    else:
                        alt_dict[alt_frame.index[count]].extend([0])
                    if int(alt_frame.index[count].split(' ')[1].split(':')[0]) in [0,1,2,10,11,12]: #####是否为早晚高峰时段（北京转utc时间）
                        alt_dict[alt_frame.index[count]].extend([2])
                    elif int(alt_frame.index[count].split(' ')[1].split(':')[0]) in [16,17,18,19,20]:
                        alt_dict[alt_frame.index[count]].extend([1])
                    else:
                        alt_dict[alt_frame.index[count]].extend([0])
                    alt_dict[alt_frame.index[count]].append(int(alt_frame.index[count].split(' ')[1].split(':')[0]))
            count += 1
            
    hour_last = ''
    count = 0
    for k in tqdm(list(alt_frame.index)):
        for i in range(0,6):
            SUM = 0
            for j in range(0,34):
                SUM += alt_dict[k][68+j*6+i]
            alt_dict[k].append(SUM)

        if count == 0:
            alt_dict[k].extend([0,0,0,0,0,0])
        else:
            for m,n in zip(alt_dict[k][-6:] ,alt_dict[hour_last][-12:-6]):
                alt_dict[k].append(m-n)

        hour_last = k
        count += 1
#     ##########标签值 PM10 PM2.5 O3##########
#     step = 72  ####预测间隔
#     for i in tqdm(range(272)):  ##训练数据
#         count = 0
#         for j in alt_frame[i]:
#             if count+step < len(alt_frame[i]) and (i%8 == 0 or i%8 == 1 or i%8 == 4):
#                 alt_dict[alt_frame.index[count]].append(np.array(alt_frame[i][count+step]).tolist())
#             count += 1
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) < 4973:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    
    pop_list = []
    for i in alt_dict.keys():
        if len(alt_dict[i]) <  max(length):
            pop_list.append(i)
    for i in pop_list:
        alt_dict.pop(i)
        
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) == 4960:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    
    return alt_dict

# %%
Start = datetime.strptime("2018-05-06 00:00:00", "%Y-%m-%d %H:%M:%S")
End = datetime.strptime("2018-05-09 23:00:00", "%Y-%m-%d %H:%M:%S")

pre_dict_bj = to_timedict_bj(start = Start, end = End)
pre_frame_bj = pd.DataFrame.from_dict(pre_dict_bj).T
pre_list_bj = np.array(pre_frame_bj)
# Out:
# 100%|██████████| 34/34 [00:07<00:00,  4.75it/s]
# 100%|██████████| 3230/3230 [00:00<00:00, 1799628.31it/s]
# 100%|██████████| 3230/3230 [00:00<00:00, 716804.33it/s]
#   0%|          | 0/18 [00:00<?, ?it/s]
# 272
# 272
# 100%|██████████| 18/18 [00:04<00:00,  3.66it/s]
# 100%|██████████| 1692/1692 [00:00<00:00, 1524546.16it/s]
# 380
# 272
# 380
# 380
# 100%|██████████| 20995/20995 [00:00<00:00, 40746.61it/s]
#   0%|          | 0/96 [00:00<?, ?it/s]
# 1485
# 380
# 1485
# 1485
# 100%|██████████| 96/96 [01:50<00:00,  1.15s/it]
#   0%|          | 0/204 [00:00<?, ?it/s]
# 12093
# 1485
# 100%|██████████| 204/204 [00:00<00:00, 250.10it/s]
# 100%|██████████| 96/96 [00:00<00:00, 34201.41it/s]
# 21900
# 12105
# 21900
# 21900

# %%
pre_list_bj.shape
# Out:
# (48, 21900)

# %% [markdown]
# # LondonPre

# %%
Medium_PM10 = 13.437369
Medium_PM25 = 20.921357
Medium_O3   = 43.428245

def to_timedict_ld(start, end):
    "输入时间和表格，返回字典"
    aq = pd.read_csv('/home/lifuzhen/KDD2018/Predict/ld_airquality_'+str(start).split(' ')[0]+'-'+str(int(str(start).split(' ')[1].split(':')[0])) +'_'+str(end).split(' ')[0]+'-'+str(int(str(end).split(' ')[1].split(':')[0]))+'.csv')
    meo_grid = pd.read_csv('/home/lifuzhen/KDD2018/Predict/ld_grid_meteorology_'+str(start).split(' ')[0]+'-'+str(int(str(start).split(' ')[1].split(':')[0])) +'_'+str(end).split(' ')[0]+'-'+str(int(str(end).split(' ')[1].split(':')[0]))+'.csv')
    meo_grid.drop('id',axis=1, inplace = True)
    meo_grid.drop_duplicates(inplace = True)
    meo_grid.reset_index(drop = True, inplace =True)
    alt_list = get_date_list(Start , End)
    alt_dict = {}
    recons = pd.DataFrame(columns=('station_id','MeasurementDateGMT','PM2.5 (ug/m3)','PM10 (ug/m3)','NO2 (ug/m3)'))
    
    for i in alt_list:
        alt_dict[i] = []
    alt = np.array(aq[['station_id','time','PM25_Concentration','PM10_Concentration','NO2_Concentration']]).tolist()
    for i in tqdm(['CD1','BL0','GR4','MY7','HV1','GN3','GR9','LW2','GN0','KF1','CD9','ST5','TH4']):
        count = 0
        for j in aq['station_id']:
            if j.split('_')[0] == i:
                recons.loc[count] = alt[count]
            count += 1 
#     print(recons)
    recons.drop_duplicates(inplace = True)
    recons.reset_index(drop=True,inplace=True)
    recons.interpolate(inplace = True)
#     print(recons.loc[recons['station_id'] == 'TH4' , 'NO2 (ug/m3)'])
    recons['PM2.5 (ug/m3)'].fillna(Medium_PM25, inplace = True)
    recons['PM10 (ug/m3)'].fillna(Medium_PM10, inplace = True)
    recons['NO2 (ug/m3)'].fillna(Medium_NO2, inplace = True)

    recons['lon'] = 0 ##经度
    recons['lat'] = 0  ##纬度
    recons.loc[recons['station_id']=='BL0',['lon','lat']] = [-0.125848,51.522287]
    recons.loc[recons['station_id']=='CD9',['lon','lat']] = [-0.129053205,51.52770662]
    recons.loc[recons['station_id']=='CD1',['lon','lat']] = [-0.175284,51.544219]
    recons.loc[recons['station_id']=='GN0',['lon','lat']] = [0.074003,51.490532]
    recons.loc[recons['station_id']=='GR4',['lon','lat']] = [0.070766,51.45258]
    recons.loc[recons['station_id']=='GN3',['lon','lat']] = [0.095111,51.486957]
    recons.loc[recons['station_id']=='GR9',['lon','lat']] = [0.040725,51.456357]
    recons.loc[recons['station_id']=='HV1',['lon','lat']] = [0.205460706,51.52078746]
    recons.loc[recons['station_id']=='KF1',['lon','lat']] = [-0.21349214,51.52104675]
    recons.loc[recons['station_id']=='LW2',['lon','lat']] = [-0.039641,51.474954]
    recons.loc[recons['station_id']=='ST5',['lon','lat']] = [-0.141661525,51.3892869]
    recons.loc[recons['station_id']=='TH4',['lon','lat']] = [-0.008418493,51.51504617]
    recons.loc[recons['station_id']=='MY7',['lon','lat']] = [-0.125848,51.522287]
    recons.loc[recons['station_id']=='BL0',['lon','lat']] = [-0.15459,51.52254]
        
    count = 0
    Idx = 0  ####索引记录####
    recons_list = np.array(recons[['lon','lat']]).tolist()
    for i in tqdm(np.array(recons['MeasurementDateGMT']).tolist()):
        if i in alt_dict.keys():
            alt_dict[i].extend(recons_list[Idx])

        Idx += 1
    
    count = 0
    Idx = 0  ####索引记录####
    recons_list = np.array(recons[['PM2.5 (ug/m3)','PM10 (ug/m3)','NO2 (ug/m3)']]).tolist()
    for i in tqdm(np.array(recons['MeasurementDateGMT']).tolist()):
        if i in alt_dict.keys():
            alt_dict[i].extend(recons_list[Idx])

        Idx += 1
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) <65:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))

    for k,v in alt_dict.items():
        if len(v) < max(length):
            if int(k.split(' ')[1].split(':')[0])!= 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
                if len(alt_dict[k]) < max(length):
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
            if int(k.split(' ')[1].split(':')[0]) == 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
    for k,v in alt_dict.items():
        if len(v) < max(length):
            if int(k.split(' ')[1].split(':')[0])!= 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
                if len(alt_dict[k]) < max(length):
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
            if int(k.split(' ')[1].split(':')[0]) == 0:
                alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) <65:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
#     print(recons)
    
    meo_grid['longitude'] = 0 ##经度
    meo_grid['latitude'] = 0  ##纬度
    count = 0
    for i in range(-20,21,1):
        for j in range(505,526,1):
            if (i >= -4 and i <=3) and (j >= 513 and j <= 517):
                meo_grid.loc[meo_grid['station_id']=='london_grid_'+str(count).zfill(3),['longitude','latitude']] = [i/10.0,j/10.0]
            count += 1
    print(meo_grid)
    meo_grid.drop(meo_grid[meo_grid['longitude'] < -0.4].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['longitude'] >  0.3].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['latitude']  < 51.3].index.tolist(),inplace= True)
    meo_grid.drop(meo_grid[meo_grid['latitude']  > 51.7].index.tolist(),inplace= True)
    meo_grid.reset_index(drop = True,inplace = True)
    def div5(x):
        return int(x/5)
    def div15(x):
        return int(x/15)
    def div05(x):
        return int(x/0.5)
    meo_grid['temperature'] = meo_grid['temperature'].apply(div5)
    meo_grid['pressure'] = meo_grid['pressure'].apply(div5)
    meo_grid['humidity'] = meo_grid['humidity'].apply(div5)
    meo_grid['wind_direction'] = meo_grid['wind_direction'].apply(div15)
    meo_grid['wind_speed/kph'] = meo_grid['wind_speed'].apply(div05)
    print(meo_grid)
    count = 1
    Idx = 0  ####索引记录####
#     print(meo_grid['station_id'][15561])
    meo_grid_list = np.array(meo_grid[['temperature','pressure','humidity','wind_direction','wind_speed']]).tolist()
    for i in tqdm(meo_grid['time']):
        if i in alt_dict.keys():
            
            if Idx > 0:
                count = int(meo_grid['station_id'][Idx].split('_')[2]) - int(meo_grid['station_id'][Idx-1].split('_')[2])
                
            if count > 1 and count < 17:
                for j in range(count-1):
                    alt_dict[i].extend(meo_grid_list[Idx-1]) 
            if count > 17:
                for j in range(count-17):
                    alt_dict[i].extend(meo_grid_list[Idx+1]) 
            alt_dict[i].extend(meo_grid_list[Idx])
        Idx += 1
        
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) == 2217:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    for i in range(3):
        for k,v in alt_dict.items():
            if len(v) < max(length):
                if int(k.split(' ')[1].split(':')[0])!= 0:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])-1).zfill(2)+':00:00'])
                else:
                    alt_dict[k] = copy.deepcopy(alt_dict[k.split(' ')[0]+' '+str(int(k.split(' ')[1].split(':')[0])+1).zfill(2)+':00:00'])
    
    pop_list = []
    for k in tqdm(alt_dict.keys()):
        weather_fore = pd.read_csv('/home/lifuzhen/KDD2018/Mini_train/ld_grid_meteorology_forecast_48_hours_'+k.split(' ')[0]+'-'+str(int(k.split(' ')[1].split(':')[0]))+'.csv')
        if np.array(weather_fore).tolist() == []:
            pop_list.append(k)
            continue
        weather_fore['weather'].replace(['CLEAR_DAY','CLEAR_NIGHT','CLOUDY','PARTLY_CLOUDY_DAY','PARTLY_CLOUDY_NIGHT','RAIN','SNOW','WIND','HAZE'],[0,1,2,3,4,5,6,7,8],inplace = True)
        weather_fore['longitude'] = 0 ##经度
        weather_fore['latitude'] = 0  ##纬度
        count = 0
#         print(k)
        for i in range(-20,21,1):
            for j in range(505,526,1):
                if (i >= -4 and i <= 3) and (j >= 513 and j <= 517):
                    weather_fore.loc[weather_fore['station_id']=='london_grid_'+str(count).zfill(3),['longitude','latitude']] = [i/10.0,j/10.0]
#                     print([i,j])
                count += 1

        weather_fore.drop(weather_fore[weather_fore['longitude'] < -0.4].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['longitude'] > 0.3].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['latitude']  < 51.3].index.tolist(),inplace= True)
        weather_fore.drop(weather_fore[weather_fore['latitude']  > 51.7].index.tolist(),inplace= True)
        weather_fore.reset_index(drop=True,inplace=True)
        
        weather_fore_array = np.array(weather_fore['weather'])
        alt_dict[k].extend(weather_fore_array.tolist())
#         print(len(alt_dict[k]))
        if len(alt_dict[k]) != 2185:
            pop_list.append(k)
    for i in pop_list:
        alt_dict[i].extend(np.zeros(2185-len(alt_dict[i])).tolist())
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) != 1963:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    
    alt_frame = pd.DataFrame.from_dict(alt_dict).T
    count = 0
    for i in list(alt_frame.index):
        if i in pop_list:
            alt_frame.iloc[count,list(range(265,2185))] = copy.deepcopy(alt_frame.iloc[count-1,list(range(265,2185))])
            alt_dict[i][265:2185] = copy.deepcopy(alt_frame.iloc[count-1,list(range(265,2185))]).tolist()
        count += 1
#     print(alt_frame[62])
    ##########提取aq 48小时滑窗##########
    win = 48
#     win = 72
#     win = 168

    for i in tqdm(range(26,65)):  
        count = 0
        for j in alt_frame[i]:
            if count >= win:
                alt_dict[alt_frame.index[count]].extend([np.mean(alt_frame[i][count-win:count]),np.std(alt_frame[i][count-win:count])])
                if i == 64:
                    if date.isoweekday(datetime.strptime(alt_frame.index[count], "%Y-%m-%d %H:%M:%S")) == 3 or date.isoweekday(datetime.strptime(alt_frame.index[count], "%Y-%m-%d %H:%M:%S")) == 4: ###要预测的是周末
                        alt_dict[alt_frame.index[count]].extend([1])
                    else:
                        alt_dict[alt_frame.index[count]].extend([0])
#                     if int(alt_frame.index[count].split(' ')[1].split(':')[0]) in [8,9,10,18,19,20]: #####是否为早晚高峰时段（北京转utc时间）
#                         alt_dict[alt_frame.index[count]].extend([2])
#                     elif int(alt_frame.index[count].split(' ')[1].split(':')[0]) in [0,1,2,3,4,5]:
#                         alt_dict[alt_frame.index[count]].extend([1])
#                     else:
#                         alt_dict[alt_frame.index[count]].extend([0])
                    alt_dict[alt_frame.index[count]].append(int(alt_frame.index[count].split(' ')[1].split(':')[0]))
            count += 1
            
    hour_last = ''
    count = 0
    for k in tqdm(list(alt_frame.index)):
        for i in range(0,3):
            SUM = 0
            for j in range(0,13):
                SUM += alt_dict[k][26+j*3+i]
            alt_dict[k].append(SUM)

        if count == 0:
            alt_dict[k].extend([0,0,0])
        else:
            for m,n in zip(alt_dict[k][-3:] ,alt_dict[hour_last][-6:-3]):
                alt_dict[k].append(m-n)
        hour_last = k
        count += 1
#     ##########标签值 PM10 PM2.5 O3##########
#     step = 72
#     for i in tqdm(range(65)):  ##训练数据
#         count = 0
#         for j in alt_frame[i]:
#             if count+step < len(alt_frame[i]) and (i%5 == 0 or i%5 == 1):
#                 alt_dict[alt_frame.index[count]].append(np.array(alt_frame[i][count+step]).tolist())
#             count += 1
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) < 6092:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
            
    pop_list = []
    for i in alt_dict.keys():
        if len(alt_dict[i])<max(length):
            pop_list.append(i)
    for i in pop_list:
        alt_dict.pop(i)
        
    length = []
    for k,v in alt_dict.items():
        length.append(len(v))
#         if len(v) == 4960:
#             print(k)
#             print(len(v))
    print(max(length))
    print(min(length))
    
    return alt_dict

# %%
pre_dict_ld = to_timedict_ld(start = Start, end = End)
pre_frame_ld = pd.DataFrame.from_dict(pre_dict_ld).T
pre_list_ld = np.array(pre_frame_ld)
# Out:
# 100%|██████████| 13/13 [00:02<00:00,  5.11it/s]
# 100%|██████████| 1245/1245 [00:00<00:00, 1690485.10it/s]
# 100%|██████████| 1245/1245 [00:00<00:00, 1673152.35it/s]
# 65
# 50
# 65
# 65
# 100%|██████████| 3760/3760 [00:00<00:00, 38144.05it/s]
#   0%|          | 0/96 [00:00<?, ?it/s]
#             station_id                 time    weather  temperature  \
# 0      london_grid_000  2018-05-06 00:00:00  CLEAR_DAY        13.21
# 1      london_grid_001  2018-05-06 00:00:00  CLEAR_DAY        12.56
# 2      london_grid_002  2018-05-06 00:00:00  CLEAR_DAY        11.91
# 3      london_grid_003  2018-05-06 00:00:00  CLEAR_DAY        11.34
# 4      london_grid_004  2018-05-06 00:00:00  CLEAR_DAY        10.86
# 5      london_grid_005  2018-05-06 00:00:00  CLEAR_DAY        10.38
# 6      london_grid_006  2018-05-06 00:00:00  CLEAR_DAY        10.41
# 7      london_grid_007  2018-05-06 00:00:00  CLEAR_DAY        10.43
# 8      london_grid_008  2018-05-06 00:00:00  CLEAR_DAY        10.54
# 9      london_grid_009  2018-05-06 00:00:00  CLEAR_DAY        10.73
# 10     london_grid_010  2018-05-06 00:00:00  CLEAR_DAY        10.91
# 11     london_grid_011  2018-05-06 00:00:00  CLEAR_DAY        10.88
# 12     london_grid_012  2018-05-06 00:00:00  CLEAR_DAY        10.85
# 13     london_grid_013  2018-05-06 00:00:00  CLEAR_DAY        10.91
# 14     london_grid_014  2018-05-06 00:00:00  CLEAR_DAY        11.05
# 15     london_grid_015  2018-05-06 00:00:00  CLEAR_DAY        11.19
# 16     london_grid_016  2018-05-06 00:00:00  CLEAR_DAY        11.43
# 17     london_grid_017  2018-05-06 00:00:00  CLEAR_DAY        11.66
# 18     london_grid_018  2018-05-06 00:00:00  CLEAR_DAY        12.20
# 19     london_grid_019  2018-05-06 00:00:00  CLEAR_DAY        13.05
# 20     london_grid_020  2018-05-06 00:00:00  CLEAR_DAY        13.90
# 21     london_grid_021  2018-05-06 00:00:00  CLEAR_DAY        13.21
# 22     london_grid_022  2018-05-06 00:00:00  CLEAR_DAY        12.58
# 23     london_grid_023  2018-05-06 00:00:00  CLEAR_DAY        11.94
# 24     london_grid_024  2018-05-06 00:00:00  CLEAR_DAY        11.39
# 25     london_grid_025  2018-05-06 00:00:00  CLEAR_DAY        10.92
# 26     london_grid_026  2018-05-06 00:00:00  CLEAR_DAY        10.45
# 27     london_grid_027  2018-05-06 00:00:00  CLEAR_DAY        10.40
# 28     london_grid_028  2018-05-06 00:00:00  CLEAR_DAY        10.35
# 29     london_grid_029  2018-05-06 00:00:00  CLEAR_DAY        10.39
# ...                ...                  ...        ...          ...
# 80854  london_grid_831  2018-05-09 23:00:00     CLOUDY        12.21
# 80855  london_grid_832  2018-05-09 23:00:00     CLOUDY        12.35
# 80856  london_grid_833  2018-05-09 23:00:00     CLOUDY        12.47
# 80857  london_grid_834  2018-05-09 23:00:00     CLOUDY        12.58
# 80858  london_grid_835  2018-05-09 23:00:00     CLOUDY        12.62
# 80859  london_grid_836  2018-05-09 23:00:00     CLOUDY        12.65
# 80860  london_grid_837  2018-05-09 23:00:00     CLOUDY        12.63
# 80861  london_grid_838  2018-05-09 23:00:00     CLOUDY        12.56
# 80862  london_grid_839  2018-05-09 23:00:00     CLOUDY        12.50
# 80863  london_grid_840  2018-05-09 23:00:00     CLOUDY         7.75
# 80864  london_grid_841  2018-05-09 23:00:00     CLOUDY         8.02
# 80865  london_grid_842  2018-05-09 23:00:00     CLOUDY         8.30
# 80866  london_grid_843  2018-05-09 23:00:00     CLOUDY         8.92
# 80867  london_grid_844  2018-05-09 23:00:00     CLOUDY         9.88
# 80868  london_grid_845  2018-05-09 23:00:00     CLOUDY        10.84
# 80869  london_grid_846  2018-05-09 23:00:00     CLOUDY        11.12
# 80870  london_grid_847  2018-05-09 23:00:00     CLOUDY        11.40
# 80871  london_grid_848  2018-05-09 23:00:00     CLOUDY        11.60
# 80872  london_grid_849  2018-05-09 23:00:00     CLOUDY        11.71
# 80873  london_grid_850  2018-05-09 23:00:00     CLOUDY        11.82
# 80874  london_grid_851  2018-05-09 23:00:00     CLOUDY        11.96
# 80875  london_grid_852  2018-05-09 23:00:00     CLOUDY        12.10
# 80876  london_grid_853  2018-05-09 23:00:00     CLOUDY        12.24
# 80877  london_grid_854  2018-05-09 23:00:00     CLOUDY        12.39
# 80878  london_grid_855  2018-05-09 23:00:00     CLOUDY        12.53
# 80879  london_grid_856  2018-05-09 23:00:00     CLOUDY        12.59
# 80880  london_grid_857  2018-05-09 23:00:00     CLOUDY        12.66
# 80881  london_grid_858  2018-05-09 23:00:00     CLOUDY        12.66
# 80882  london_grid_859  2018-05-09 23:00:00     CLOUDY        12.58
# 80883  london_grid_860  2018-05-09 23:00:00     CLOUDY        12.51
#
#         pressure  humidity  wind_direction  wind_speed  longitude  latitude
# 0      1024.1812      81.0           71.58        8.46        0.0       0.0
# 1      1023.1956      83.0           67.55        7.64        0.0       0.0
# 2      1022.2100      86.0           62.58        6.87        0.0       0.0
# 3      1019.5796      88.0           59.31        6.52        0.0       0.0
# 4      1015.3044      89.0           58.59        6.55        0.0       0.0
# 5      1011.0292      90.0           57.89        6.59        0.0       0.0
# 6      1010.4148      90.0           64.62        6.56        0.0       0.0
# 7      1009.8004      89.0           71.33        6.62        0.0       0.0
# 8      1010.1908      89.0           76.81        6.48        0.0       0.0
# 9      1011.5860      89.0           81.63        6.10        0.0       0.0
# 10     1012.9812      88.0           87.04        5.77        0.0       0.0
# 11     1011.0100      88.0           88.08        5.03        0.0       0.0
# 12     1009.0388      88.0           89.49        4.29        0.0       0.0
# 13     1008.6932      89.0           92.21        3.30        0.0       0.0
# 14     1009.9732      89.0           99.14        2.07        0.0       0.0
# 15     1011.2532      89.0          123.83        0.95        0.0       0.0
# 16     1012.3220      89.0          229.03        0.61        0.0       0.0
# 17     1013.3908      90.0          261.01        1.74        0.0       0.0
# 18     1012.6132      89.0          267.99        2.60        0.0       0.0
# 19     1009.9892      87.0          272.56        3.12        0.0       0.0
# 20     1007.3652      86.0          275.80        3.66        0.0       0.0
# 21     1024.3092      80.0           77.13        9.09        0.0       0.0
# 22     1023.4516      83.0           74.40        8.04        0.0       0.0
# 23     1022.5940      85.0           70.87        7.01        0.0       0.0
# 24     1020.3514      87.0           67.77        6.48        0.0       0.0
# 25     1016.7239      88.0           65.90        6.45        0.0       0.0
# 26     1013.0964      90.0           64.02        6.42        0.0       0.0
# 27     1011.5399      89.0           69.88        6.50        0.0       0.0
# 28     1009.9834      89.0           75.55        6.65        0.0       0.0
# 29     1009.5457      89.0           80.59        6.58        0.0       0.0
# ...          ...       ...             ...         ...        ...       ...
# 80854  1007.2352      86.0          237.02       28.36        0.0       0.0
# 80855  1007.0544      87.0          236.96       26.49        0.0       0.0
# 80856  1006.8980      87.0          237.28       23.70        0.0       0.0
# 80857  1006.7417      88.0          237.67       20.91        0.0       0.0
# 80858  1006.6349      88.0          237.13       17.95        0.0       0.0
# 80859  1006.5281      89.0          236.37       14.99        0.0       0.0
# 80860  1006.4573      89.0          234.34       12.74        0.0       0.0
# 80861  1006.4226      90.0          230.65       11.22        0.0       0.0
# 80862  1006.3879      90.0          225.83        9.77        0.0       0.0
# 80863   995.8779      96.0          255.16       12.62        0.0       0.0
# 80864   996.3000      95.0          250.99       13.71        0.0       0.0
# 80865   996.7221      94.0          247.44       14.85        0.0       0.0
# 80866   999.2860      92.0          245.26       17.14        0.0       0.0
# 80867  1003.9919      89.0          244.35       20.54        0.0       0.0
# 80868  1008.6978      86.0          243.70       23.95        0.0       0.0
# 80869  1008.5073      85.0          242.31       25.96        0.0       0.0
# 80870  1008.3169      84.0          241.13       27.98        0.0       0.0
# 80871  1008.1065      84.0          239.82       29.34        0.0       0.0
# 80872  1007.8762      84.0          238.31       30.04        0.0       0.0
# 80873  1007.6459      84.0          236.87       30.75        0.0       0.0
# 80874  1007.4497      85.0          235.96       29.89        0.0       0.0
# 80875  1007.2536      86.0          235.00       29.02        0.0       0.0
# 80876  1007.0742      87.0          234.29       27.35        0.0       0.0
# 80877  1006.9115      87.0          233.80       24.86        0.0       0.0
# 80878  1006.7488      88.0          233.21       22.37        0.0       0.0
# 80879  1006.6563      88.0          231.69       19.53        0.0       0.0
# 80880  1006.5637      88.0          229.66       16.71        0.0       0.0
# 80881  1006.5049      89.0          226.21       14.51        0.0       0.0
# 80882  1006.4799      89.0          221.13       12.99        0.0       0.0
# 80883  1006.4548      90.0          214.76       11.59        0.0       0.0
#
# [80884 rows x 10 columns]
#            station_id                 time    weather  temperature  pressure  \
# 0     london_grid_344  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 1     london_grid_345  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 2     london_grid_346  2018-05-06 00:00:00  CLEAR_DAY            2       204
# 3     london_grid_347  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 4     london_grid_348  2018-05-06 00:00:00  CLEAR_DAY            2       202
# 5     london_grid_365  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 6     london_grid_366  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 7     london_grid_367  2018-05-06 00:00:00  CLEAR_DAY            2       204
# 8     london_grid_368  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 9     london_grid_369  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 10    london_grid_386  2018-05-06 00:00:00  CLEAR_DAY            2       202
# 11    london_grid_387  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 12    london_grid_388  2018-05-06 00:00:00  CLEAR_DAY            2       204
# 13    london_grid_389  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 14    london_grid_390  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 15    london_grid_407  2018-05-06 00:00:00  CLEAR_DAY            2       202
# 16    london_grid_408  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 17    london_grid_409  2018-05-06 00:00:00  CLEAR_DAY            3       205
# 18    london_grid_410  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 19    london_grid_411  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 20    london_grid_428  2018-05-06 00:00:00  CLEAR_DAY            1       202
# 21    london_grid_429  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 22    london_grid_430  2018-05-06 00:00:00  CLEAR_DAY            2       204
# 23    london_grid_431  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 24    london_grid_432  2018-05-06 00:00:00  CLEAR_DAY            1       203
# 25    london_grid_449  2018-05-06 00:00:00  CLEAR_DAY            1       202
# 26    london_grid_450  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 27    london_grid_451  2018-05-06 00:00:00  CLEAR_DAY            2       204
# 28    london_grid_452  2018-05-06 00:00:00  CLEAR_DAY            2       203
# 29    london_grid_453  2018-05-06 00:00:00  CLEAR_DAY            1       203
# ...               ...                  ...        ...          ...       ...
# 3730  london_grid_386  2018-05-09 23:00:00     CLOUDY            2       199
# 3731  london_grid_387  2018-05-09 23:00:00     CLOUDY            2       200
# 3732  london_grid_388  2018-05-09 23:00:00     CLOUDY            2       200
# 3733  london_grid_389  2018-05-09 23:00:00     CLOUDY            2       200
# 3734  london_grid_390  2018-05-09 23:00:00       RAIN            2       199
# 3735  london_grid_407  2018-05-09 23:00:00     CLOUDY            2       199
# 3736  london_grid_408  2018-05-09 23:00:00     CLOUDY            2       200
# 3737  london_grid_409  2018-05-09 23:00:00     CLOUDY            2       200
# 3738  london_grid_410  2018-05-09 23:00:00     CLOUDY            2       200
# 3739  london_grid_411  2018-05-09 23:00:00     CLOUDY            2       200
# 3740  london_grid_428  2018-05-09 23:00:00     CLOUDY            2       199
# 3741  london_grid_429  2018-05-09 23:00:00     CLOUDY            2       200
# 3742  london_grid_430  2018-05-09 23:00:00     CLOUDY            2       200
# 3743  london_grid_431  2018-05-09 23:00:00     CLOUDY            2       200
# 3744  london_grid_432  2018-05-09 23:00:00     CLOUDY            2       200
# 3745  london_grid_449  2018-05-09 23:00:00     CLOUDY            2       199
# 3746  london_grid_450  2018-05-09 23:00:00     CLOUDY            2       200
# 3747  london_grid_451  2018-05-09 23:00:00     CLOUDY            2       200
# 3748  london_grid_452  2018-05-09 23:00:00     CLOUDY            2       200
# 3749  london_grid_453  2018-05-09 23:00:00       RAIN            2       200
# 3750  london_grid_470  2018-05-09 23:00:00     CLOUDY            2       199
# 3751  london_grid_471  2018-05-09 23:00:00     CLOUDY            2       200
# 3752  london_grid_472  2018-05-09 23:00:00     CLOUDY            2       200
# 3753  london_grid_473  2018-05-09 23:00:00     CLOUDY            2       200
# 3754  london_grid_474  2018-05-09 23:00:00       RAIN            2       200
# 3755  london_grid_491  2018-05-09 23:00:00     CLOUDY            2       199
# 3756  london_grid_492  2018-05-09 23:00:00     CLOUDY            2       200
# 3757  london_grid_493  2018-05-09 23:00:00     CLOUDY            2       200
# 3758  london_grid_494  2018-05-09 23:00:00     CLOUDY            2       200
# 3759  london_grid_495  2018-05-09 23:00:00       RAIN            2       200
#
#       humidity  wind_direction  wind_speed  longitude  latitude  \
# 0           13               4        5.99       -0.4      51.3
# 1           12               5        5.98       -0.4      51.4
# 2           10               5        6.00       -0.4      51.5
# 3           11               5        6.18       -0.4      51.6
# 4           13               6        6.69       -0.4      51.7
# 5           12               4        6.23       -0.3      51.3
# 6           10               4        6.10       -0.3      51.4
# 7           10               5        6.35       -0.3      51.5
# 8           12               5        6.55       -0.3      51.6
# 9           13               5        6.81       -0.3      51.7
# 10          13               4        6.98       -0.2      51.3
# 11          12               4        6.77       -0.2      51.4
# 12          10               5        6.60       -0.2      51.5
# 13          12               5        6.73       -0.2      51.6
# 14          13               5        6.91       -0.2      51.7
# 15          13               4        7.32       -0.1      51.3
# 16          12               4        7.01       -0.1      51.4
# 17           6               4        6.46       -0.1      51.5
# 18          12               5        6.86       -0.1      51.6
# 19          13               5        7.01       -0.1      51.7
# 20          13               4        7.67        0.0      51.3
# 21          12               4        7.27        0.0      51.4
# 22          11               4        6.91        0.0      51.5
# 23          12               4        7.00        0.0      51.6
# 24          13               5        7.13        0.0      51.7
# 25          14               3        7.73        0.1      51.3
# 26          13               4        7.23        0.1      51.4
# 27          11               4        6.77        0.1      51.5
# 28          13               4        6.89        0.1      51.6
# 29          14               4        7.04        0.1      51.7
# ...        ...             ...         ...        ...       ...
# 3730        16              16       13.00       -0.2      51.3
# 3731        15              17       13.52       -0.2      51.4
# 3732        14              17       14.08       -0.2      51.5
# 3733        15              17       13.56       -0.2      51.6
# 3734        17              17       13.05       -0.2      51.7
# 3735        16              16       13.47       -0.1      51.3
# 3736        15              17       13.81       -0.1      51.4
# 3737        14              17       14.19       -0.1      51.5
# 3738        15              17       13.71       -0.1      51.6
# 3739        17              17       13.25       -0.1      51.7
# 3740        15              17       13.95        0.0      51.3
# 3741        14              17       14.11        0.0      51.4
# 3742        13              17       14.32        0.0      51.5
# 3743        15              17       13.88        0.0      51.6
# 3744        16              17       13.49        0.0      51.7
# 3745        15              16       14.21        0.1      51.3
# 3746        14              17       14.20        0.1      51.4
# 3747        13              17       14.24        0.1      51.5
# 3748        15              17       13.81        0.1      51.6
# 3749        16              18       13.44        0.1      51.7
# 3750        15              16       14.47        0.2      51.3
# 3751        14              17       14.28        0.2      51.4
# 3752        14              17       14.16        0.2      51.5
# 3753        15              17       13.74        0.2      51.6
# 3754        17              18       13.41        0.2      51.7
# 3755        15              16       14.68        0.3      51.3
# 3756        14              17       14.39        0.3      51.4
# 3757        14              17       14.16        0.3      51.5
# 3758        15              17       13.70        0.3      51.6
# 3759        17              18       13.37        0.3      51.7
#
#       wind_speed/kph
# 0                 11
# 1                 11
# 2                 12
# 3                 12
# 4                 13
# 5                 12
# 6                 12
# 7                 12
# 8                 13
# 9                 13
# 10                13
# 11                13
# 12                13
# 13                13
# 14                13
# 15                14
# 16                14
# 17                12
# 18                13
# 19                14
# 20                15
# 21                14
# 22                13
# 23                14
# 24                14
# 25                15
# 26                14
# 27                13
# 28                13
# 29                14
# ...              ...
# 3730              26
# 3731              27
# 3732              28
# 3733              27
# 3734              26
# 3735              26
# 3736              27
# 3737              28
# 3738              27
# 3739              26
# 3740              27
# 3741              28
# 3742              28
# 3743              27
# 3744              26
# 3745              28
# 3746              28
# 3747              28
# 3748              27
# 3749              26
# 3750              28
# 3751              28
# 3752              28
# 3753              27
# 3754              26
# 3755              29
# 3756              28
# 3757              28
# 3758              27
# 3759              26
#
# [3760 rows x 11 columns]
# 265
# 65
# 100%|██████████| 96/96 [00:37<00:00,  2.55it/s]
# 100%|██████████| 39/39 [00:00<00:00, 215.62it/s]
# 100%|██████████| 96/96 [00:00<00:00, 110527.91it/s]
# 2185
# 65
# 4065
# 2191
# 4065
# 4065

# %%
pre_list_ld.shape
# Out:
# (48, 4065)

# %%
import xgboost as xgb

date_submit = '2018-5-10_big'
submit = pd.read_csv('/home/lifuzhen/KDD2018/sample_submissioin.csv')
##########北京##############
count = 0
for i in tqdm(['aotizhongx', 'badaling', 'beibuxinqu', 'daxing', 'dingling', 'donggaocun', 'dongsi','dongsihuan','fangshan', 'fengtaihua', 'guanyuan', 'gucheng','huairou', 'liulihe', 'mentougou', 'miyun', 'miyunshuik', 'nansanhuan', 'nongzhangu', 'pingchang', 'pinggu','qianmen','shunyi','tiantan','tongzhou','wanliu','wanshouxig','xizhimenbe','yanqin','yizhuang','yongdingme','yongledian','yufa','yungang']):
    for j in ['PM2.5','PM10','O3']:
        model = xgb.Booster(model_file='/home/lifuzhen/KDD2018/Mini_train/bj_mean_std/'+str(count)+'_'+j+'.model')
        if j == 'PM2.5':
            for k in range(48):
                alt = model.predict(xgb.DMatrix(np.concatenate((pre_list_bj[:,2*count:2*(count+1)],pre_list_bj[:,68:12093],pre_list_bj[:,12093+count*12:12093+(count+1)*12],pre_list_bj[:,-15:-13],pre_list_bj[:,-12:]),axis = 1)))
                submit.loc[submit['test_id'] == i + '_aq#' + str(k) , j] = alt[k]
        elif j == 'PM10':
            for k in range(48):
                alt = model.predict(xgb.DMatrix(np.concatenate((pre_list_bj[:,2*count:2*(count+1)],pre_list_bj[:,68:12093],pre_list_bj[:,12093+count*12:12093+(count+1)*12],pre_list_bj[:,-15:]),axis = 1)))
                submit.loc[submit['test_id'] == i + '_aq#' + str(k) , j] = alt[k]
        else:
            for k in range(48):
                alt = model.predict(xgb.DMatrix(np.concatenate((pre_list_bj[:,68+6*count+4:68+6*count+5],pre_list_bj[:,-13:-12],pre_list_bj[:,-8:-7],pre_list_bj[:,-2:-1]),axis = 1)))
                submit.loc[submit['test_id'] == i + '_aq#' + str(k) , j] = alt[k]
    count += 1
###########伦敦################
count = 0
for i in tqdm(['CD1','BL0','GR4','MY7','HV1','GN3','GR9','LW2','GN0','KF1','CD9','ST5','TH4']):
    for j in ['PM2.5','PM10']:
        model = xgb.Booster(model_file='/home/lifuzhen/KDD2018/Mini_train/ld_mean_std/'+str(count)+'_'+j+'.model')
        for k in range(48):
            alt = model.predict(xgb.DMatrix(np.concatenate((pre_list_ld[:,2*count:2*(count+1)],pre_list_ld[:,26:2185],pre_list_ld[:,2185+count*6:2185+(count+1)*6],pre_list_ld[:,-8:]),axis = 1)))
            submit.loc[submit['test_id'] == i + '#' + str(k) , j] = alt[k]
    count += 1
submit.to_csv('/home/lifuzhen/KDD2018/Result/result_Mini_'+date_submit+'.csv',index=False)
# Out:
# 100%|██████████| 34/34 [00:38<00:00,  1.14s/it]
# 100%|██████████| 13/13 [00:05<00:00,  2.41it/s]
